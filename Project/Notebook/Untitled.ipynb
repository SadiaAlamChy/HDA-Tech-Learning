# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('C:/Users/Administrator/HDA Intern/Prescription-Data-integration-master/wrapper/dataset/anonymized_prescription_dataset_mysoft.csv')
# Out:
# C:\Users\Administrator\.conda\envs\HDA\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (91) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    REGISTRATION_NO       REG_DATE GENDER_DATA M_STATUS_DATA       DOB  \
# 0     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 1     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 2     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 3     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 4     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
#
#          AGE BLOOD_GROUP                 ADDRESS  UPAZILA_NO  UPAZILA_NAME  \
# 0  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 1  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 2  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 3  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 4  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
#
#    ...  DOSAGE  PRES_MED_DTL_NO  HIDE_REMARKS  HIDE_DATE HIDE_BY  HIDE_FLAG  \
# ...

# %%
df_geocode = pd.read_csv('C:/Users/Administrator/HDA-Tech-Learning/Project/Notebook/constructed_geocode_.csv')
df_geocode.head()
# Out:
#               ADDRESS_geo   Geocode Upazial Division District  \
# 0   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 1   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 2   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 3   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 4   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
#
#              ADDRESS_none
# 0   ASHULIA, SAVAR, DHAKA
# 1   ASHULIA, SAVAR, DHAKA
# 2   ASHULIA, SAVAR, DHAKA
# 3   ASHULIA, SAVAR, DHAKA
# 4   ASHULIA, SAVAR, DHAKA

# %%
df = pd.concat([df,df_geocode],axis = 1,join = 'inner')

# %%
df.head()
# Out:
#    REGISTRATION_NO       REG_DATE GENDER_DATA M_STATUS_DATA       DOB  \
# 0     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 1     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 2     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 3     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 4     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
#
#          AGE BLOOD_GROUP                 ADDRESS  UPAZILA_NO  UPAZILA_NAME  \
# 0  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 1  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 2  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 3  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 4  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
#
#    ...  REQ_DATE  REQ_BY  REQ_FLAG  \
# 0  ...       NaN     NaN       NaN
# ...

# %%
# df.drop(df.columns[[0,3,5]],axis = 1,inplace=True)
# df.head(5)
df.columns
# Out:
# Index(['REGISTRATION_NO', 'REG_DATE', 'GENDER_DATA', 'M_STATUS_DATA', 'DOB',
#        'AGE', 'BLOOD_GROUP', 'ADDRESS', 'UPAZILA_NO', 'UPAZILA_NAME',
#        ...
#        'REQ_DATE', 'REQ_BY', 'REQ_FLAG', 'PIK', 'ADDRESS_geo', 'Geocode',
#        'Upazial', 'Division', 'District', 'ADDRESS_none'],
#       dtype='object', length=108)

# %%
df_n = df[['PIK','REG_DATE','GENDER_DATA','DOB','BLOOD_GROUP','ADDRESS','Geocode','Upazial','Division','District','HOSPITAL_ID','FINDINGS','FOLLOW_UP_DATE',
          'PRESCRITION_DATA','BRAND_NAME','GENERIC_NAME','MEDICINE_COMMENT','DOSAGE']]

# %%
df_n.head(5)
# Out:
#                                                  PIK       REG_DATE  \
# 0  13c282c5f44a6b2d68fcd1ecd0b71f8a1397efdeb4063c...  1/2/2022 2:54
# 1  13c282c5f44a6b2d68fcd1ecd0b71f8a1397efdeb4063c...  1/2/2022 2:54
# 2  13c282c5f44a6b2d68fcd1ecd0b71f8a1397efdeb4063c...  1/2/2022 2:54
# 3  13c282c5f44a6b2d68fcd1ecd0b71f8a1397efdeb4063c...  1/2/2022 2:54
# 4  13c282c5f44a6b2d68fcd1ecd0b71f8a1397efdeb4063c...  1/2/2022 2:54
#
#   GENDER_DATA       DOB BLOOD_GROUP                 ADDRESS   Geocode Upazial  \
# 0           M  1/2/1942         NaN   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR
# 1           M  1/2/1942         NaN   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR
# 2           M  1/2/1942         NaN   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR
# 3           M  1/2/1942         NaN   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR
# 4           M  1/2/1942         NaN   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR
#
#   Division District   HOSPITAL_ID FINDINGS FOLLOW_UP_DATE  \
# ...

# %%
# df_n.to_csv('overall.csv',index = False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10138 entries, 0 to 10137
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PIK               10138 non-null  object
#  1   REG_DATE          10138 non-null  object
#  2   GENDER_DATA       10138 non-null  object
#  3   DOB               10138 non-null  object
#  4   BLOOD_GROUP       1446 non-null   object
#  5   ADDRESS           10068 non-null  object
#  6   HOSPITAL_ID       10138 non-null  object
#  7   FINDINGS          1180 non-null   object
#  8   FOLLOW_UP_DATE    3264 non-null   object
#  9   PRESCRITION_DATA  6210 non-null   object
#  10  BRAND_NAME        3587 non-null   object
#  11  GENERIC_NAME      2956 non-null   object
#  12  MEDICINE_COMMENT  1211 non-null   object
#  13  DOSAGE            3300 non-null   object
# dtypes: object(14)
# memory usage: 1.1+ MB

# %%
# df1.to_csv('Customized_dataframe.csv',index = False)

# %%
# import requests
# geo_url = 'http://maps.googleapis.com/maps/api/geocode/json'
# my_address = {'address': 'Dhour Thurak, Dhaka, Bangladesh', 
#              'language': 'en'}
# response = requests.get(geo_url, params = my_address)
# results = response.json()['results']
# my_geo = results[0]['geometry']['location']
# print("Longitude:",my_geo['lng'],"\n","Latitude:",my_geo['lat'])

# %%
# pip install requests

# %%
pip install geopandas

# %%
pip install geopy.geocoder
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement geopy.geocoder (from versions: none)
# ERROR: No matching distribution found for geopy.geocoder

# %%
from geopy.geocoders import Nominatim
# import geopy.geocoders as gd

# %%
locator = Nominatim(user_agent="myGeocoder")
location = locator.geocode("Dhaka, Bangladesh")

# %%
print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
# Out:
# Latitude = 23.7861979, Longitude = 90.4026151

# %%
country =['Dhaka,Bangladesh','hathazari,Chittagong','Sylhet,Bangladesh']
country
# Out:
# ['Dhaka,Bangladesh', 'hathazari,Chittagong', 'Sylhet,Bangladesh']

# %%
country.append('Dhour Turag Dhaka')
country
latitude_loc=[]
longitude_loc = []

# %%
country
# Out:
# ['Dhaka,Bangladesh',
#  'hathazari,Chittagong',
#  'Sylhet,Bangladesh',
#  'BORO DEWRA, TONGI',
#  'ASHULIA, SAVAR, DHAKA',
#  'Dhour Turag Dhaka']

# %%
for i in country:
    locator = Nominatim(user_agent="myGeocoder")
    location = locator.geocode(i)
#     print(location.latitude)
#     latitude_loc.append(location.latitude)
#     longitude_loc.append(location.longitude)
    print('location for ',i)
    print(location.)
    print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
# Out:
# location for  Dhaka,Bangladesh
# Latitude = 23.7861979, Longitude = 90.4026151
# location for  hathazari,Chittagong
# Latitude = 22.5051095, Longitude = 91.8088601
# location for  Sylhet,Bangladesh
# Latitude = 24.4932874, Longitude = 91.7085743
# location for  BORO DEWRA, TONGI
# Latitude = 23.9055169, Longitude = 90.3778361
# location for  ASHULIA, SAVAR, DHAKA
# Latitude = 23.9052388, Longitude = 90.2930078473529
# location for  Dhour Turag Dhaka
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_14964/2637934907.py in <module>
#       6 #     longitude_loc.append(location.longitude)
#       7     print('location for ',i)
# ----> 8     print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
# for i in country:
#     geolocator = Nominatim()
#     location = geolocator.geocode(i)
#     time.sleep(.45)
#     print(location.address)
#     print((location.latitude, location.longitude))

# %%
pip install wrapper

# %%
import pandas as pd
path = 'C:/Users/Administrator/Downloads/New folder/pdf/Intern/dataset'
df1 = pd.read_csv(path+'/division.csv')
df1.head()
# Out:
#    division_id        name
# 0           60      SYLHET
# 1           55     RANGPUR
# 2           50    RAJSHAHI
# 3           45  MYMENSINGH
# 4           40      KHULNA

# %%
df_con = pd.read_csv('C:/Users/Administrator/HDA Intern/Prescription-Data-integration-master/wrapper/dataset/anonymized_prescription_dataset_mysoft.csv')
df_con.head()
# Out:
# C:\Users\Administrator\.conda\envs\HDA\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (91) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    REGISTRATION_NO       REG_DATE GENDER_DATA M_STATUS_DATA       DOB  \
# 0     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 1     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 2     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 3     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 4     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
#
#          AGE BLOOD_GROUP                 ADDRESS  UPAZILA_NO  UPAZILA_NAME  \
# 0  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 1  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 2  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# ...

# %%
df_address = df_con.ADDRESS
df_address.head()
# Out:
# 0     ASHULIA, SAVAR, DHAKA
# 1     ASHULIA, SAVAR, DHAKA
# 2     ASHULIA, SAVAR, DHAKA
# 3     ASHULIA, SAVAR, DHAKA
# 4     ASHULIA, SAVAR, DHAKA
# Name: ADDRESS, dtype: object

# %%
len(df_address)
# Out:
# 10138

# %%
df_new = pd.read_csv('C:/Users/Administrator/HDA Intern/Prescription-Data-integration-master/wrapper/algorithms/constructed.csv')
df_new.head()
# Out:
#     Geocode Upazial Division District
# 0  302672.0   SAVAR    DHAKA    DHAKA
# 1  302672.0   SAVAR    DHAKA    DHAKA
# 2  302672.0   SAVAR    DHAKA    DHAKA
# 3  302672.0   SAVAR    DHAKA    DHAKA
# 4  302672.0   SAVAR    DHAKA    DHAKA

# %%
df = pd.concat([df_address,df_new],axis = 1,join = 'inner')
# df = df.to_csv('constructed_geocode.csv',index = False)

# %%
df.head()
# Out:
#                   ADDRESS   Geocode Upazial Division District
# 0   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 1   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 2   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 3   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA
# 4   ASHULIA, SAVAR, DHAKA  302672.0   SAVAR    DHAKA    DHAKA

# %%
df_non = pd.read_csv('C:/Users/Administrator/HDA-Tech-Learning/Prescription_Data_integration_master/wrapper/dataset/anonymized_prescription_dataset_mysoft.csv')
df_non.head()
# Out:
# C:\Users\Administrator\.conda\envs\HDA\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (91) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    REGISTRATION_NO       REG_DATE GENDER_DATA M_STATUS_DATA       DOB  \
# 0     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 1     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 2     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 3     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
# 4     1.220000e+12  1/2/2022 2:54           M       Married  1/2/1942
#
#          AGE BLOOD_GROUP                 ADDRESS  UPAZILA_NO  UPAZILA_NAME  \
# 0  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 1  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# 2  80Y 3M 4D         NaN   ASHULIA, SAVAR, DHAKA         NaN           NaN
# ...

# %%
df_non.ADDRESS.head()
# Out:
# 0     ASHULIA, SAVAR, DHAKA
# 1     ASHULIA, SAVAR, DHAKA
# 2     ASHULIA, SAVAR, DHAKA
# 3     ASHULIA, SAVAR, DHAKA
# 4     ASHULIA, SAVAR, DHAKA
# Name: ADDRESS, dtype: object

# %%
df_abar = pd.concat([df,df_non.ADDRESS],axis = 1,join = 'inner')
df_abar_cvs = df_abar.to_csv('constructed_geocode_.csv',index = False)
