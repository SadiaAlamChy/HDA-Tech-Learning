# %% [markdown]
# #   Install Files

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\users\user\vintern\hda-tech-learning\notebook\env\scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Import Files

# %%
import psycopg2
import pandas as pd
import psycopg2.extras
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Connection to DATABASE

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database="ecomdb",
                                           user = "postgres",
                                           password = "15556010",
                                           host = "127.0.0.1",
                                           port = "5432")

    def getConnection(self):
        print("successfully connected to database")
        return self.connection

# %%
con = PostgresConnection().getConnection()
# Out:
# successfully connected to database

# %% [markdown]
# # Queryes

# %%
cur = con.cursor()
select_query1 = "SELECT t.item_key , t.time_key , t.coustomer_key , SUM(t.total_price) " \
    "FROM ecomdb_star_schema.fact_table t " \
    "GROUP BY CUBE(t.item_key, t.time_key, t.coustomer_key) "
cur.execute(select_query1)
records1 = cur.fetchall()
records1

query1 = pd.DataFrame(list(records1), columns=['item_key', 'time_key', 'coustomer_key','SUM'])
query1
# Out:
#         item_key time_key coustomer_key      SUM
# 0         I00001   T00018       C001954     69.0
# 1         I00001   T00018          None     69.0
# 2         I00001   T00140       C002860     34.5
# 3         I00001   T00140          None     34.5
# 4         I00001   T00186       C002321    103.5
# ...          ...      ...           ...      ...
# 3909412   I00255     None       C009191    100.0
# 3909413   I00256     None       C009191    160.0
# 3909414   I00257     None       C009191    210.0
# 3909415   I00261     None       C009191    231.0
# 3909416     None     None       C009191  11028.5
#
# [3909417 rows x 4 columns]

# %%
cur2 = con.cursor()
select_query2 = "SELECT  r.month , SUM(t.total_price)  " \
    "FROM ecomdb_star_schema.fact_table t  " \
       "JOIN ecomdb_star_schema.time_dim r ON t.time_key = r.time_key " \
          "  GROUP BY CUBE(r.month) " \
           "ORDER BY r.month ASC;"
cur2.execute(select_query2)
records2 = cur2.fetchall()
records2

query2 = pd.DataFrame(list(records2), columns=['month','SUM'])
query2
# Out:
#     month           SUM
# 0     1.0  9.042244e+06
# 1     2.0  8.073878e+06
# 2     3.0  8.939152e+06
# 3     4.0  8.504635e+06
# 4     5.0  9.078002e+06
# 5     6.0  8.556853e+06
# 6     7.0  9.046580e+06
# 7     8.0  8.929475e+06
# 8     9.0  8.724326e+06
# 9    10.0  8.902784e+06
# 10   11.0  8.680026e+06
# 11   12.0  8.923480e+06
# 12    NaN  1.054014e+08

# %%
cur3 = con.cursor()
select_query3 = "SELECT  r.bank_name , SUM(t.total_price)" \
    "FROM ecomdb_star_schema.fact_table t " \
    	"JOIN ecomdb_star_schema.trans_dim r ON t.payment_key = r.payment_key" \
	       " GROUP BY CUBE(r.bank_name)" \
			  "ORDER BY r.bank_name ASC;"
cur3.execute(select_query3)
records3 = cur3.fetchall()
records3

query3 = pd.DataFrame(list(records3), columns=['Bank_name','SUM'])
query3
# Out:
#                                             Bank_name           SUM
# 0                                     AB Bank Limited  2.728516e+06
# 1                    Bangladesh Commerce Bank Limited  2.730999e+06
# 2                                   Bank Asia Limited  2.687143e+06
# 3                          Bengal Commercial Bank Ltd  2.704554e+06
# 4                                               Bkash  2.689352e+06
# 5                                   BRAC Bank Limited  2.705796e+06
# 6                               Citizens Bank Limited  2.723215e+06
# 7                                   City Bank Limited  2.713952e+06
# 8                   Community Bank Bangladesh Limited  2.685752e+06
# 9                                  Dhaka Bank Limited  2.728366e+06
# 10                          Dutch-Bangla Bank Limited  2.692435e+06
# 11                               Eastern Bank Limited  2.687182e+06
# 12                                  IFIC Bank Limited  2.699760e+06
# ...

# %%
cur4 = con.cursor()
select_query4 = "SELECT  s.district, SUM(t.total_price) " \
                    "FROM ecomdb_star_schema.fact_table t " \
                  	"JOIN ecomdb_star_schema.store_dim s on s.store_key = t.store_key " \
                    " WHERE  s.district = 'BARISAL' " \
	                "GROUP BY CUBE(s.district) " \
		        	  " ORDER BY s.district ASC;"
cur4.execute(select_query4)
records4 = cur4.fetchall()
records4

query4 = pd.DataFrame(list(records4), columns=['district','SUM'])
query4
# Out:
#   district         SUM
# 0  BARISAL  2897237.75
# 1     None  2897237.75

# %%
query4['item_key']

query('B == `C C`')
# Out:
# 0        None
# 1      I00196
# 2      I00098
# 3      I00137
# 4      I00014
#         ...
# 525    I00261
# 526    I00173
# 527    I00209
# 528    I00242
# 529    I00051
# Name: item_key, Length: 530, dtype: object

# %%
cur5 = con.cursor()
select_query5 = "SELECT  s.year, t.item_key, SUM(t.total_price) " \
                    " FROM ecomdb_star_schema.fact_table t " \
                  	" JOIN ecomdb_star_schema.time_dim s on s.time_key = t.time_key " \
	                " WHERE s.year = 2015 " \
		        	" GROUP BY CUBE(s.year, t.item_key) " \
                    " ORDER BY s.year ASC;"
cur5.execute(select_query5)
records5 = cur5.fetchall()
records5

query5 = pd.DataFrame(list(records5), columns=['year','item_key','SUM'])
query5
# Out:
#        year item_key          SUM
# 0       NaN     None  15095720.25
# 1    2015.0   I00133     49725.00
# 2    2015.0   I00183    113155.00
# 3    2015.0   I00247     54255.00
# 4    2015.0   I00253     71085.00
# ..      ...      ...          ...
# 525     NaN   I00261    113685.00
# 526     NaN   I00173     62719.00
# 527     NaN   I00209     42796.00
# 528     NaN   I00242     36624.00
# 529     NaN   I00051     73738.00
#
# [530 rows x 3 columns]

# %%
cur6 = con.cursor()
select_query6 = "SELECT  s.year,r.division, t.item_key, SUM(t.total_price) " \
         " FROM ecomdb_star_schema.fact_table t " \
        " JOIN ecomdb_star_schema.time_dim s on s.time_key = t.time_key " \
		" JOIN ecomdb_star_schema.store_dim r on r.store_key = r.store_key " \
		" WHERE (s.year = 2015  AND  r.division = 'BARISAL') " \
        " GROUP BY CUBE(s.year,r.division, t.item_key) " \
        "ORDER BY s.year ASC;" 
cur6.execute(select_query6)
records6 = cur6.fetchall()
records6

query6 = pd.DataFrame(list(records6), columns=['year','division','item_key','SUM'])
query6
# Out:
#         year division item_key        SUM
# 0     2015.0  BARISAL   I00001  2092402.0
# 1     2015.0  BARISAL   I00002  1290276.0
# 2     2015.0  BARISAL   I00003  1194102.0
# 3     2015.0  BARISAL   I00004  1205334.0
# 4     2015.0  BARISAL   I00005  1157247.0
# ...      ...      ...      ...        ...
# 1055     NaN  BARISAL   I00143  2862080.0
# 1056     NaN  BARISAL   I00211  2588820.0
# 1057     NaN  BARISAL   I00057  4079712.0
# 1058     NaN  BARISAL   I00099  1089816.0
# 1059     NaN  BARISAL   I00145  2995876.0
#
# [1060 rows x 4 columns]

# %%
cur7 = con.cursor()
select_query7 = " SELECT   s.item_name , r.store_key, count(t.item_key) " \
                   " FROM ecomdb_star_schema.fact_table t  " \
                   " JOIN ecomdb_star_schema.item_dim s on s.item_key = t.item_key " \
	               " JOIN ecomdb_star_schema.store_dim r on r.store_key = t.store_key " \
	               " GROUP BY CUBE( s.item_name, r.store_key) " \
	               "	ORDER BY count(t.item_key) DESC; "
cur7.execute(select_query7)
records7 = cur7.fetchall()
records7

query7 = pd.DataFrame(list(records7), columns=['item_name','store_key','COUNT'])
query7
# Out:
#                                         item_name store_key    COUNT
# 0                                            None      None  1000000
# 1                              Pepsi - 12 oz cans      None     7724
# 2             Muscle Milk Protein Shake Van. 11oz      None     7550
# 3                          Diet Coke - 12 oz cans      None     7544
# 4                             Sprite - 12 oz cans      None     7503
# ...                                           ...       ...      ...
# 188095            Plastic Forks White Heavyweight     S0072        1
# 188096                 Planters Nut Variety Packs    S00650        1
# 188097           Pure Leaf Unsweetened Tea 18.5oz     S0057        1
# 188098  Sargento Bal. Breaks (fruit, nut, cheese)    S00603        1
# 188099              Sargento String Cheese 0.75oz    S00196        1
#
# [188100 rows x 3 columns]

# %% [markdown]
# # Data visualization

# %%
query2 = query2.dropna()
query2 = query2.set_index(['month'])
plot = query2.plot.pie(y='SUM', figsize=(5, 5))

# %%
df = query3[0:5]

# %%
query3 = query3.dropna()

# %%
query3 = query3.dropna()
query3
# Out:
#                                             Bank_name         SUM
# 0                                     AB Bank Limited  2728515.50
# 1                    Bangladesh Commerce Bank Limited  2730999.25
# 2                                   Bank Asia Limited  2687142.75
# 3                          Bengal Commercial Bank Ltd  2704554.25
# 4                                               Bkash  2689352.50
# 5                                   BRAC Bank Limited  2705795.75
# 6                               Citizens Bank Limited  2723215.25
# 7                                   City Bank Limited  2713952.50
# 8                   Community Bank Bangladesh Limited  2685751.50
# 9                                  Dhaka Bank Limited  2728366.00
# 10                          Dutch-Bangla Bank Limited  2692435.25
# 11                               Eastern Bank Limited  2687182.25
# 12                                  IFIC Bank Limited  2699759.75
# ...

# %%
query3 = query3.set_index(['Bank_name'])

query3.plot.pie(y='SUM',figsize=(15,15),shadow='True')
# Out:
# <AxesSubplot:ylabel='SUM'>

# %%
query3.dtypes
# Out:
# Bank_name     object
# SUM          float64
# dtype: object

# %%
query4
# Out:
#   district         SUM
# 0  BARISAL  2897237.75
# 1     None  2897237.75

# %%
query5
# Out:
#        year item_key          SUM
# 0       NaN     None  15095720.25
# 1    2015.0   I00133     49725.00
# 2    2015.0   I00183    113155.00
# 3    2015.0   I00247     54255.00
# 4    2015.0   I00253     71085.00
# ..      ...      ...          ...
# 525     NaN   I00261    113685.00
# 526     NaN   I00173     62719.00
# 527     NaN   I00209     42796.00
# 528     NaN   I00242     36624.00
# 529     NaN   I00051     73738.00
#
# [530 rows x 3 columns]

# %% [markdown]
# ### Query -4

# %%
query5[(query5['year'] == 2015) & (query5['item_key'].isna() == True)]
# Out:
#        year item_key          SUM
# 265  2015.0     None  15095720.25

# %%
query6
# Out:
#         year division item_key        SUM
# 0     2015.0  BARISAL   I00001  2092402.0
# 1     2015.0  BARISAL   I00002  1290276.0
# 2     2015.0  BARISAL   I00003  1194102.0
# 3     2015.0  BARISAL   I00004  1205334.0
# 4     2015.0  BARISAL   I00005  1157247.0
# ...      ...      ...      ...        ...
# 1055     NaN  BARISAL   I00143  2862080.0
# 1056     NaN  BARISAL   I00211  2588820.0
# 1057     NaN  BARISAL   I00057  4079712.0
# 1058     NaN  BARISAL   I00099  1089816.0
# 1059     NaN  BARISAL   I00145  2995876.0
#
# [1060 rows x 4 columns]

# %% [markdown]
# ###  Query -5

# %%
query6[(query6['year'] == 2015) & (query6['division'] == 'BARISAL') & (query6['item_key'].isna() == True) ]
# Out:
#        year division item_key          SUM
# 264  2015.0  BARISAL     None  784977453.0

# %% [markdown]
# ### Query -6

# %%
query7
# Out:
#                                         item_name store_key    COUNT
# 0                                            None      None  1000000
# 1                              Pepsi - 12 oz cans      None     7724
# 2             Muscle Milk Protein Shake Van. 11oz      None     7550
# 3                          Diet Coke - 12 oz cans      None     7544
# 4                             Sprite - 12 oz cans      None     7503
# ...                                           ...       ...      ...
# 188095            Plastic Forks White Heavyweight     S0072        1
# 188096                 Planters Nut Variety Packs    S00650        1
# 188097           Pure Leaf Unsweetened Tea 18.5oz     S0057        1
# 188098  Sargento Bal. Breaks (fruit, nut, cheese)    S00603        1
# 188099              Sargento String Cheese 0.75oz    S00196        1
#
# [188100 rows x 3 columns]

# %%
Store_S0001 = query7[(query7['store_key'] == 'S0001')  & (query7['item_name'].isna() == False) ]
df = Store_S0001[:3]
df
# Out:
#                                 item_name store_key  COUNT
# 1618  Muscle Milk Protein Shake Van. 11oz     S0001     14
# 2396            Njoy Sugar Canister 22 oz     S0001     13
# 2537             Vita Coconut Water 10oz      S0001     12

# %%
plt.bar(df['item_name'],df['COUNT'])
plt.show()

# %%
Store_S0002 = query7[(query7['store_key'] == 'S0002')  & (query7['item_name'].isna() == False) ]
df = Store_S0002[:3]
df
# Out:
#                                   item_name store_key  COUNT
# 2126            Altoids Small Packs Variety     S0002     13
# 2335    Muscle Milk Protein Shake Van. 11oz     S0002     13
# 2764  AquaFina Purified Drinking Water 16oz     S0002     12

# %%
plt.bar(df['item_name'],df['COUNT'])
plt.show()

# %% [markdown]
# ### query 7

# %%
x=input('Enter number of days: ')
