# %% [markdown]
# ### Import Required libraries

# %%
import psycopg2
import pandas as pd
import psycopg2.extras
import pandas.io.sql as sqlio

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.22.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.4.0)
# Collecting scipy>=1.0
#   Using cached scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (4.29.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.15.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.8.0 seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\users\hp\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## DataBase Connection

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database="ecomdb",
                                           user = "postgres",
                                           password = "afra1234",
                                           host = "127.0.0.1",
                                           port = "5432")

    def getConnection(self):
        print("successfully connected to database")
        return self.connection

# %%
con = PostgresConnection().getConnection()
# Out:
# successfully connected to database

# %%
conn = psycopg2.connect(database="ecomdb",
                                           user = "postgres",
                                           password = "afra1234",
                                           host = "127.0.0.1",
                                           port = "5432")
print("successfully connected to database")
# Out:
# successfully connected to database

# %% [markdown]
# ## Simple CUBE query

# %% [markdown]
# ### Q1: Find the division/district/year/month wise total_sale_price joining fact table and respective dimension table

# %% [markdown]
# ***Total_sale_price By Division Wise***

# %%
cur = con.cursor()
select_stmt = "SELECT  s.division, t.item_key, SUM(t.total_price) FROM ecom_schema.fact_table t JOIN ecom_schema.store_dim s on s.store_key = t.store_key GROUP BY CUBE(s.division, t.item_key) ORDER BY s.division ASC"
cur.execute(select_stmt)
records = cur.fetchall()
df = pd.DataFrame(list(records), columns=['division', 'item_key', 'total_sales_price'])
df.head(10)
# Out:
#   division item_key total_sales_price
# 0  BARISAL   I00095           24880.0
# 1  BARISAL   I00173           30096.0
# 2  BARISAL   I00006          25480.00
# 3  BARISAL   I00223           22396.5
# 4  BARISAL   I00043           41472.0
# 5  BARISAL   I00088           28611.0
# 6  BARISAL   I00250           29425.5
# 7  BARISAL   I00110           37462.5
# 8  BARISAL   I00199           26670.0
# 9  BARISAL   I00139           35328.0

# %%
con = PostgresConnection().getConnection()

cur = con.cursor()
select_stmt = "SELECT  s.division, SUM(t.total_price) " \
        "FROM ecom_schema.fact_table t " \
        "JOIN ecom_schema.store_dim s on s.store_key = t.store_key " \
        "GROUP BY CUBE(s.division)" \
        "ORDER BY s.division ASC"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('BARISAL', Decimal('7520343.75')),
#  ('CHITTAGONG', Decimal('19763595.00')),
#  ('DHAKA', Decimal('40764619.75')),
#  ('KHULNA', Decimal('11311610.50')),
#  ('RAJSHAHI', Decimal('12099196.00')),
#  ('RANGPUR', Decimal('8429836.50')),
#  ('SYLHET', Decimal('5512234.25')),
#  (None, Decimal('105401435.75'))]

# %%
df = pd.DataFrame(list(records), columns=['Division', 'Total_sales'])
df
# Out:
#      Division   Total_sales
# 0     BARISAL    7520343.75
# 1  CHITTAGONG   19763595.00
# 2       DHAKA   40764619.75
# 3      KHULNA   11311610.50
# 4    RAJSHAHI   12099196.00
# 5     RANGPUR    8429836.50
# 6      SYLHET    5512234.25
# 7        None  105401435.75

# %%
df.drop([7],axis=0,inplace=True)

# %%
df
# Out:
#      Division  Total_sales
# 0     BARISAL   7520343.75
# 1  CHITTAGONG  19763595.00
# 2       DHAKA  40764619.75
# 3      KHULNA  11311610.50
# 4    RAJSHAHI  12099196.00
# 5     RANGPUR   8429836.50
# 6      SYLHET   5512234.25

# %%
df.dtypes
# Out:
# Division       object
# Total_sales    object
# dtype: object

# %%
df['Total_sales'] = df['Total_sales'].astype('float64')

# %%
df.dtypes
# Out:
# Division        object
# Total_sales    float64
# dtype: object

# %%
fig = plt.figure(figsize =(10, 7))
plt.bar(df["Division"],df["Total_sales"])
 
# Show Plot
plt.show()

# %%
df = df.set_index(['Division'])

# %%
plot = df.plot.pie(y='Total_sales', figsize=(5, 5))

# %% [markdown]
# ***Total_sale_price By District Wise***

# %%
con = PostgresConnection().getConnection()

cur = con.cursor()
select_stmt = "SELECT  s.district, t.item_key, SUM(t.total_price) " \
        "FROM ecom_schema.fact_table t " \
        "JOIN ecom_schema.store_dim s on s.store_key = t.store_key " \
        "GROUP BY CUBE(s.district, t.item_key)" \
        "ORDER BY s.district ASC"  # Ascending order
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('BAGERHAT', 'I00001', Decimal('2863.5')),
#  ('BAGERHAT', 'I00002', Decimal('1559.25')),
#  ('BAGERHAT', 'I00003', Decimal('2362.50')),
#  ('BAGERHAT', 'I00004', Decimal('2038.50')),
#  ('BAGERHAT', 'I00005', Decimal('2058.75')),
#  ('BAGERHAT', 'I00006', Decimal('4371.25')),
#  ('BAGERHAT', 'I00007', Decimal('1707.75')),
#  ('BAGERHAT', 'I00008', Decimal('5248.75')),
#  ('BAGERHAT', 'I00009', Decimal('4598.75')),
#  ('BAGERHAT', 'I00010', Decimal('2396.25')),
#  ('BAGERHAT', 'I00011', Decimal('1626.75')),
#  ('BAGERHAT', 'I00012', Decimal('5963.75')),
#  ('BAGERHAT', 'I00013', Decimal('1586.25')),
#  ('BAGERHAT', 'I00014', Decimal('1991.25')),
#  ('BAGERHAT', 'I00015', Decimal('1451.25')),
#  ('BAGERHAT', 'I00016', Decimal('4663.75')),
#  ('BAGERHAT', 'I00017', Decimal('1640.25')),
#  ('BAGERHAT', 'I00018', Decimal('2112.75')),
#  ('BAGERHAT', 'I00019', Decimal('1822.50')),
#  ('BAGERHAT', 'I00020', Decimal('2004.75')),
#  ('BAGERHAT', 'I00021', Decimal('1660.50')),
#  ('BAGERHAT', 'I00022', Decimal('2811.25')),
#  ('BAGERHAT', 'I00023', Decimal('2666.25')),
#  ('BAGERHAT', 'I00024', Decimal('4241.25')),
#  ('BAGERHAT', 'I00025', Decimal('3473.0')),
#  ('BAGERHAT', 'I00026', Decimal('1998.00')),
#  ('BAGERHAT', 'I00027', Decimal('4062.50')),
#  ('BAGERHAT', 'I00028', Decimal('2450.25')),
#  ('BAGERHAT', 'I00029', Decimal('3208.5')),
#  ('BAGERHAT', 'I00030', Decimal('4224.0')),
#  ('BAGERHAT', 'I00031', Decimal('3888.0')),
#  ('BAGERHAT', 'I00032', Decimal('4480.0')),
#  ('BAGERHAT', 'I00033', Decimal('3616.0')),
#  ('BAGERHAT', 'I00034', Decimal('5088.0')),
#  ('BAGERHAT', 'I00035', Decimal('4816.0')),
#  ('BAGERHAT', 'I00036', Decimal('5408.0')),
#  ('BAGERHAT', 'I00037', Decimal('5280.0')),
#  ('BAGERHAT', 'I00038', Decimal('5382.0')),
#  ('BAGERHAT', 'I00039', Decimal('7254.0')),
#  ('BAGERHAT', 'I00040', Decimal('6556.0')),
#  ('BAGERHAT', 'I00041', Decimal('7153.0')),
#  ('BAGERHAT', 'I00042', Decimal('7644.0')),
#  ('BAGERHAT', 'I00043', Decimal('5952.0')),
#  ('BAGERHAT', 'I00044', Decimal('1720.0')),
#  ('BAGERHAT', 'I00045', Decimal('2552.0')),
#  ('BAGERHAT', 'I00046', Decimal('2312.0')),
#  ('BAGERHAT', 'I00047', Decimal('2664.0')),
#  ('BAGERHAT', 'I00048', Decimal('2080.0')),
#  ('BAGERHAT', 'I00049', Decimal('2424.0')),
#  ('BAGERHAT', 'I00050', Decimal('2792.0')),
#  ('BAGERHAT', 'I00051', Decimal('6739.0')),
#  ('BAGERHAT', 'I00052', Decimal('10320.0')),
#  ('BAGERHAT', 'I00053', Decimal('13160.0')),
#  ('BAGERHAT', 'I00054', Decimal('11840.0')),
#  ('BAGERHAT', 'I00055', Decimal('12440.0')),
#  ('BAGERHAT', 'I00056', Decimal('6888.0')),
#  ('BAGERHAT', 'I00057', Decimal('5448.0')),
#  ('BAGERHAT', 'I00058', Decimal('4950.0')),
#  ('BAGERHAT', 'I00059', Decimal('7876.0')),
#  ('BAGERHAT', 'I00060', Decimal('5896.0')),
#  ('BAGERHAT', 'I00061', Decimal('20790.0')),
#  ('BAGERHAT', 'I00062', Decimal('9583.0')),
#  ('BAGERHAT', 'I00063', Decimal('10640.0')),
#  ('BAGERHAT', 'I00064', Decimal('11080.0')),
#  ('BAGERHAT', 'I00065', Decimal('6560.0')),
#  ('BAGERHAT', 'I00066', Decimal('4420.0')),
#  ('BAGERHAT', 'I00067', Decimal('2248.0')),
#  ('BAGERHAT', 'I00068', Decimal('4460.0')),
#  ('BAGERHAT', 'I00069', Decimal('5565.0')),
#  ('BAGERHAT', 'I00070', Decimal('3307.5')),
#  ('BAGERHAT', 'I00071', Decimal('4760.0')),
#  ('BAGERHAT', 'I00072', Decimal('5020.0')),
#  ('BAGERHAT', 'I00073', Decimal('5260.0')),
#  ('BAGERHAT', 'I00074', Decimal('7120.0')),
#  ('BAGERHAT', 'I00075', Decimal('4262.5')),
#  ('BAGERHAT', 'I00076', Decimal('1950.75')),
#  ('BAGERHAT', 'I00077', Decimal('2085.75')),
#  ('BAGERHAT', 'I00078', Decimal('5338.0')),
#  ('BAGERHAT', 'I00079', Decimal('3927.0')),
#  ('BAGERHAT', 'I00080', Decimal('6842.0')),
#  ('BAGERHAT', 'I00081', Decimal('9019.0')),
#  ('BAGERHAT', 'I00082', Decimal('4290.0')),
#  ('BAGERHAT', 'I00083', Decimal('3654.0')),
#  ('BAGERHAT', 'I00084', Decimal('5364.0')),
#  ('BAGERHAT', 'I00085', Decimal('4716.0')),
#  ('BAGERHAT', 'I00086', Decimal('3996.0')),
#  ('BAGERHAT', 'I00087', Decimal('5280.0')),
#  ('BAGERHAT', 'I00088', Decimal('3961.0')),
#  ('BAGERHAT', 'I00089', Decimal('2646.0')),
#  ('BAGERHAT', 'I00090', Decimal('2214.0')),
#  ('BAGERHAT', 'I00091', Decimal('1890.0')),
#  ('BAGERHAT', 'I00092', Decimal('2200.0')),
#  ('BAGERHAT', 'I00093', Decimal('3211.0')),
#  ('BAGERHAT', 'I00094', Decimal('3762.0')),
#  ('BAGERHAT', 'I00095', Decimal('4432.0')),
#  ('BAGERHAT', 'I00096', Decimal('7280.0')),
#  ('BAGERHAT', 'I00097', Decimal('5662.0')),
#  ('BAGERHAT', 'I00098', Decimal('3630.0')),
#  ('BAGERHAT', 'I00099', Decimal('1776.0')),
#  ('BAGERHAT', 'I00100', Decimal('1920.0')),
#  ('BAGERHAT', 'I00101', Decimal('3255.0')),
#  ('BAGERHAT', 'I00102', Decimal('5360.0')),
#  ('BAGERHAT', 'I00103', Decimal('3585.0')),
#  ('BAGERHAT', 'I00104', Decimal('3360.0')),
#  ('BAGERHAT', 'I00105', Decimal('3960.0')),
#  ('BAGERHAT', 'I00106', Decimal('4199.0')),
#  ('BAGERHAT', 'I00107', Decimal('5880.0')),
#  ('BAGERHAT', 'I00108', Decimal('3585.0')),
#  ('BAGERHAT', 'I00109', Decimal('3961.0')),
#  ('BAGERHAT', 'I00110', Decimal('7132.5')),
#  ('BAGERHAT', 'I00111', Decimal('3664.0')),
#  ('BAGERHAT', 'I00112', Decimal('4284.0')),
#  ('BAGERHAT', 'I00113', Decimal('14742.0')),
#  ('BAGERHAT', 'I00114', Decimal('11836.0')),
#  ('BAGERHAT', 'I00115', Decimal('15582.0')),
#  ('BAGERHAT', 'I00116', Decimal('14928.0')),
#  ('BAGERHAT', 'I00117', Decimal('13524.0')),
#  ('BAGERHAT', 'I00118', Decimal('11928.0')),
#  ('BAGERHAT', 'I00119', Decimal('11925.0')),
#  ('BAGERHAT', 'I00120', Decimal('2088.0')),
#  ('BAGERHAT', 'I00121', Decimal('3723.0')),
#  ('BAGERHAT', 'I00122', Decimal('4530.0')),
#  ('BAGERHAT', 'I00123', Decimal('6615.0')),
#  ('BAGERHAT', 'I00124', Decimal('4650.0')),
#  ('BAGERHAT', 'I00125', Decimal('4350.0')),
#  ('BAGERHAT', 'I00126', Decimal('9325.0')),
#  ('BAGERHAT', 'I00127', Decimal('3637.5')),
#  ('BAGERHAT', 'I00128', Decimal('3728.0')),
#  ('BAGERHAT', 'I00129', Decimal('4806.0')),
#  ('BAGERHAT', 'I00130', Decimal('4046.0')),
#  ('BAGERHAT', 'I00131', Decimal('3696.0')),
#  ('BAGERHAT', 'I00132', Decimal('3304.0')),
#  ('BAGERHAT', 'I00133', Decimal('4695.0')),
#  ('BAGERHAT', 'I00134', Decimal('4240.0')),
#  ('BAGERHAT', 'I00135', Decimal('5306.0')),
#  ('BAGERHAT', 'I00136', Decimal('3763.5')),
#  ('BAGERHAT', 'I00137', Decimal('6000.0')),
#  ('BAGERHAT', 'I00138', Decimal('7392.0')),
#  ('BAGERHAT', 'I00139', Decimal('6096.0')),
#  ('BAGERHAT', 'I00140', Decimal('10121.0')),
#  ('BAGERHAT', 'I00141', Decimal('5346.0')),
#  ('BAGERHAT', 'I00142', Decimal('3025.0')),
#  ('BAGERHAT', 'I00143', Decimal('5040.0')),
#  ('BAGERHAT', 'I00144', Decimal('6000.0')),
#  ('BAGERHAT', 'I00145', Decimal('4981.0')),
#  ('BAGERHAT', 'I00146', Decimal('5103.0')),
#  ('BAGERHAT', 'I00147', Decimal('3810.0')),
#  ('BAGERHAT', 'I00148', Decimal('4245.0')),
#  ('BAGERHAT', 'I00149', Decimal('3840.0')),
#  ('BAGERHAT', 'I00150', Decimal('4624.0')),
#  ('BAGERHAT', 'I00151', Decimal('4267.0')),
#  ('BAGERHAT', 'I00152', Decimal('3270.0')),
#  ('BAGERHAT', 'I00153', Decimal('4020.0')),
#  ('BAGERHAT', 'I00154', Decimal('4530.0')),
#  ('BAGERHAT', 'I00155', Decimal('4624.0')),
#  ('BAGERHAT', 'I00156', Decimal('5984.0')),
#  ('BAGERHAT', 'I00157', Decimal('3060.0')),
#  ('BAGERHAT', 'I00158', Decimal('4947.0')),
#  ('BAGERHAT', 'I00159', Decimal('5066.0')),
#  ('BAGERHAT', 'I00160', Decimal('4131.0')),
#  ('BAGERHAT', 'I00161', Decimal('4012.0')),
#  ('BAGERHAT', 'I00162', Decimal('4960.0')),
#  ('BAGERHAT', 'I00163', Decimal('3405.0')),
#  ('BAGERHAT', 'I00164', Decimal('3936.0')),
#  ('BAGERHAT', 'I00165', Decimal('4384.0')),
#  ('BAGERHAT', 'I00166', Decimal('4301.0')),
#  ('BAGERHAT', 'I00167', Decimal('2898.0')),
#  ('BAGERHAT', 'I00168', Decimal('5256.0')),
#  ('BAGERHAT', 'I00169', Decimal('5474.0')),
#  ('BAGERHAT', 'I00170', Decimal('4170.0')),
#  ('BAGERHAT', 'I00171', Decimal('4576.0')),
#  ('BAGERHAT', 'I00172', Decimal('5339.0')),
#  ('BAGERHAT', 'I00173', Decimal('5624.0')),
#  ('BAGERHAT', 'I00174', Decimal('4806.0')),
#  ('BAGERHAT', 'I00175', Decimal('4769.0')),
#  ('BAGERHAT', 'I00176', Decimal('4978.0')),
#  ('BAGERHAT', 'I00177', Decimal('7525.0')),
#  ('BAGERHAT', 'I00178', Decimal('6812.0')),
#  ('BAGERHAT', 'I00179', Decimal('6631.0')),
#  ('BAGERHAT', 'I00180', Decimal('6023.0')),
#  ('BAGERHAT', 'I00181', Decimal('4784.0')),
#  ('BAGERHAT', 'I00182', Decimal('3945.0')),
#  ('BAGERHAT', 'I00183', Decimal('12215.0')),
#  ('BAGERHAT', 'I00184', Decimal('2952.0')),
#  ('BAGERHAT', 'I00185', Decimal('3108.0')),
#  ('BAGERHAT', 'I00186', Decimal('3341.0')),
#  ('BAGERHAT', 'I00187', Decimal('4017.0')),
#  ('BAGERHAT', 'I00188', Decimal('5026.0')),
#  ('BAGERHAT', 'I00189', Decimal('3770.0')),
#  ('BAGERHAT', 'I00190', Decimal('4976.0')),
#  ('BAGERHAT', 'I00191', Decimal('6240.0')),
#  ('BAGERHAT', 'I00192', Decimal('7080.0')),
#  ('BAGERHAT', 'I00193', Decimal('5346.0')),
#  ('BAGERHAT', 'I00194', Decimal('6900.0')),
#  ('BAGERHAT', 'I00195', Decimal('4000.0')),
#  ('BAGERHAT', 'I00196', Decimal('5216.0')),
#  ('BAGERHAT', 'I00197', Decimal('4455.0')),
#  ('BAGERHAT', 'I00198', Decimal('3600.0')),
#  ('BAGERHAT', 'I00199', Decimal('5085.0')),
#  ('BAGERHAT', 'I00200', Decimal('6000.0')),
#  ('BAGERHAT', 'I00201', Decimal('7383.0')),
#  ('BAGERHAT', 'I00202', Decimal('2904.0')),
#  ('BAGERHAT', 'I00203', Decimal('6138.0')),
#  ('BAGERHAT', 'I00204', Decimal('7021.0')),
#  ('BAGERHAT', 'I00205', Decimal('4608.0')),
#  ('BAGERHAT', 'I00206', Decimal('5175.0')),
#  ('BAGERHAT', 'I00207', Decimal('4018.0')),
#  ('BAGERHAT', 'I00208', Decimal('4410.0')),
#  ('BAGERHAT', 'I00209', Decimal('2886.0')),
#  ('BAGERHAT', 'I00210', Decimal('4125.0')),
#  ('BAGERHAT', 'I00211', Decimal('4125.0')),
#  ('BAGERHAT', 'I00212', Decimal('3588.0')),
#  ('BAGERHAT', 'I00213', Decimal('3360.0')),
#  ('BAGERHAT', 'I00214', Decimal('5148.0')),
#  ('BAGERHAT', 'I00215', Decimal('3906.0')),
#  ('BAGERHAT', 'I00216', Decimal('5626.5')),
#  ('BAGERHAT', 'I00217', Decimal('5002.0')),
#  ('BAGERHAT', 'I00218', Decimal('1740.0')),
#  ('BAGERHAT', 'I00219', Decimal('6842.0')),
#  ('BAGERHAT', 'I00220', Decimal('4060.0')),
#  ('BAGERHAT', 'I00221', Decimal('3626.0')),
#  ('BAGERHAT', 'I00222', Decimal('3492.0')),
#  ('BAGERHAT', 'I00223', Decimal('4293.0')),
#  ('BAGERHAT', 'I00224', Decimal('3641.0')),
#  ('BAGERHAT', 'I00225', Decimal('5440.0')),
#  ('BAGERHAT', 'I00226', Decimal('4515.0')),
#  ('BAGERHAT', 'I00227', Decimal('3645.0')),
#  ('BAGERHAT', 'I00228', Decimal('2660.0')),
#  ('BAGERHAT', 'I00229', Decimal('4472.0')),
#  ('BAGERHAT', 'I00230', Decimal('4665.0')),
#  ('BAGERHAT', 'I00231', Decimal('5472.0')),
#  ('BAGERHAT', 'I00232', Decimal('3732.0')),
#  ('BAGERHAT', 'I00233', Decimal('3216.0')),
#  ('BAGERHAT', 'I00234', Decimal('4030.0')),
#  ('BAGERHAT', 'I00235', Decimal('4802.0')),
#  ('BAGERHAT', 'I00236', Decimal('3756.0')),
#  ('BAGERHAT', 'I00237', Decimal('4784.0')),
#  ('BAGERHAT', 'I00238', Decimal('2760.0')),
#  ('BAGERHAT', 'I00239', Decimal('4746.0')),
#  ('BAGERHAT', 'I00240', Decimal('3052.0')),
#  ('BAGERHAT', 'I00241', Decimal('3396.0')),
#  ('BAGERHAT', 'I00242', Decimal('3240.0')),
#  ('BAGERHAT', 'I00243', Decimal('5536.0')),
#  ('BAGERHAT', 'I00244', Decimal('5400.0')),
#  ('BAGERHAT', 'I00245', Decimal('6188.0')),
#  ('BAGERHAT', 'I00246', Decimal('5220.0')),
#  ('BAGERHAT', 'I00247', Decimal('4920.0')),
#  ('BAGERHAT', 'I00248', Decimal('9360.0')),
#  ('BAGERHAT', 'I00249', Decimal('5584.0')),
#  ('BAGERHAT', 'I00250', Decimal('4738.5')),
#  ('BAGERHAT', 'I00251', Decimal('3133.0')),
#  ('BAGERHAT', 'I00252', Decimal('2629.0')),
#  ('BAGERHAT', 'I00253', Decimal('5628.0')),
#  ('BAGERHAT', 'I00254', Decimal('4368.0')),
#  ('BAGERHAT', 'I00255', Decimal('5700.0')),
#  ('BAGERHAT', 'I00256', Decimal('6720.0')),
#  ('BAGERHAT', 'I00257', Decimal('5712.0')),
#  ('BAGERHAT', 'I00258', Decimal('6762.0')),
#  ('BAGERHAT', 'I00259', Decimal('5876.0')),
#  ('BAGERHAT', 'I00260', Decimal('3030.0')),
#  ('BAGERHAT', 'I00261', Decimal('8745.0')),
#  ('BAGERHAT', 'I00262', Decimal('4214.0')),
#  ('BAGERHAT', 'I00263', Decimal('4592.0')),
#  ('BAGERHAT', 'I00264', Decimal('3840.0')),
#  ('BAGERHAT', None, Decimal('1307651.00')),
#  ('BANDARBAN', 'I00001', Decimal('1886.0')),
#  ('BANDARBAN', 'I00002', Decimal('1856.25')),
#  ('BANDARBAN', 'I00003', Decimal('1194.75')),
#  ('BANDARBAN', 'I00004', Decimal('1005.75')),
#  ('BANDARBAN', 'I00005', Decimal('1653.75')),
#  ('BANDARBAN', 'I00006', Decimal('4712.50')),
#  ('BANDARBAN', 'I00007', Decimal('1842.75')),
#  ('BANDARBAN', 'I00008', Decimal('2096.25')),
#  ('BANDARBAN', 'I00009', Decimal('2681.25')),
#  ('BANDARBAN', 'I00010', Decimal('1221.75')),
#  ('BANDARBAN', 'I00011', Decimal('1471.50')),
#  ('BANDARBAN', 'I00012', Decimal('2762.50')),
#  ('BANDARBAN', 'I00013', Decimal('1410.75')),
#  ('BANDARBAN', 'I00014', Decimal('1579.50')),
#  ('BANDARBAN', 'I00015', Decimal('1559.25')),
#  ('BANDARBAN', 'I00016', Decimal('4290.00')),
#  ('BANDARBAN', 'I00017', Decimal('1221.75')),
#  ('BANDARBAN', 'I00018', Decimal('1404.00')),
#  ('BANDARBAN', 'I00019', Decimal('1113.75')),
#  ('BANDARBAN', 'I00020', Decimal('1134.00')),
#  ('BANDARBAN', 'I00021', Decimal('1255.50')),
#  ('BANDARBAN', 'I00022', Decimal('3623.75')),
#  ('BANDARBAN', 'I00023', Decimal('1491.75')),
#  ('BANDARBAN', 'I00024', Decimal('3412.50')),
#  ('BANDARBAN', 'I00025', Decimal('3001.5')),
#  ('BANDARBAN', 'I00026', Decimal('1127.25')),
#  ('BANDARBAN', 'I00027', Decimal('3087.50')),
#  ('BANDARBAN', 'I00028', Decimal('1633.50')),
#  ('BANDARBAN', 'I00029', Decimal('1897.5')),
#  ('BANDARBAN', 'I00030', Decimal('3536.0')),
#  ('BANDARBAN', 'I00031', Decimal('3184.0')),
#  ('BANDARBAN', 'I00032', Decimal('3696.0')),
#  ('BANDARBAN', 'I00033', Decimal('3520.0')),
#  ('BANDARBAN', 'I00034', Decimal('3040.0')),
#  ('BANDARBAN', 'I00035', Decimal('3168.0')),
#  ('BANDARBAN', 'I00036', Decimal('4352.0')),
#  ('BANDARBAN', 'I00037', Decimal('3264.0')),
#  ('BANDARBAN', 'I00038', Decimal('3795.0')),
#  ('BANDARBAN', 'I00039', Decimal('4160.0')),
#  ('BANDARBAN', 'I00040', Decimal('4378.0')),
#  ('BANDARBAN', 'I00041', Decimal('5474.0')),
#  ('BANDARBAN', 'I00042', Decimal('4396.0')),
#  ('BANDARBAN', 'I00043', Decimal('4128.0')),
#  ('BANDARBAN', 'I00044', Decimal('1480.0')),
#  ('BANDARBAN', 'I00045', Decimal('1936.0')),
#  ('BANDARBAN', 'I00046', Decimal('2072.0')),
#  ('BANDARBAN', 'I00047', Decimal('2112.0')),
#  ('BANDARBAN', 'I00048', Decimal('1664.0')),
#  ('BANDARBAN', 'I00049', Decimal('1760.0')),
#  ('BANDARBAN', 'I00050', Decimal('2504.0')),
#  ('BANDARBAN', 'I00051', Decimal('5658.0')),
#  ('BANDARBAN', 'I00052', Decimal('7960.0')),
#  ('BANDARBAN', 'I00053', Decimal('7080.0')),
#  ('BANDARBAN', 'I00054', Decimal('9880.0')),
#  ('BANDARBAN', 'I00055', Decimal('9240.0')),
#  ('BANDARBAN', 'I00056', Decimal('5328.0')),
#  ('BANDARBAN', 'I00057', Decimal('4032.0')),
#  ('BANDARBAN', 'I00058', Decimal('3762.0')),
#  ('BANDARBAN', 'I00059', Decimal('4906.0')),
#  ('BANDARBAN', 'I00060', Decimal('4862.0')),
#  ('BANDARBAN', 'I00061', Decimal('11550.0')),
#  ('BANDARBAN', 'I00062', Decimal('8288.0')),
#  ('BANDARBAN', 'I00063', Decimal('9720.0')),
#  ('BANDARBAN', 'I00064', Decimal('7840.0')),
#  ('BANDARBAN', 'I00065', Decimal('3100.0')),
#  ('BANDARBAN', 'I00066', Decimal('4780.0')),
#  ('BANDARBAN', 'I00067', Decimal('1768.0')),
#  ('BANDARBAN', 'I00068', Decimal('4460.0')),
#  ('BANDARBAN', 'I00069', Decimal('3517.5')),
#  ('BANDARBAN', 'I00070', Decimal('4025.0')),
#  ('BANDARBAN', 'I00071', Decimal('3412.5')),
#  ('BANDARBAN', 'I00072', Decimal('3860.0')),
#  ('BANDARBAN', 'I00073', Decimal('4240.0')),
#  ('BANDARBAN', 'I00074', Decimal('4240.0')),
#  ('BANDARBAN', 'I00075', Decimal('3503.0')),
#  ('BANDARBAN', 'I00076', Decimal('1566.00')),
#  ('BANDARBAN', 'I00077', Decimal('1552.50')),
#  ('BANDARBAN', 'I00078', Decimal('3842.0')),
#  ('BANDARBAN', 'I00079', Decimal('3672.0')),
#  ('BANDARBAN', 'I00080', Decimal('4290.0')),
#  ('BANDARBAN', 'I00081', Decimal('5742.0')),
#  ('BANDARBAN', 'I00082', Decimal('3555.0')),
#  ('BANDARBAN', 'I00083', Decimal('2954.0')),
#  ('BANDARBAN', 'I00084', Decimal('4608.0')),
#  ('BANDARBAN', 'I00085', Decimal('3114.0')),
#  ('BANDARBAN', 'I00086', Decimal('3240.0')),
#  ('BANDARBAN', 'I00087', Decimal('3465.0')),
#  ('BANDARBAN', 'I00088', Decimal('3791.0')),
#  ('BANDARBAN', 'I00089', Decimal('1449.0')),
#  ('BANDARBAN', 'I00090', Decimal('1827.0')),
#  ('BANDARBAN', 'I00091', Decimal('1515.0')),
#  ('BANDARBAN', 'I00092', Decimal('2070.0')),
#  ('BANDARBAN', 'I00093', Decimal('2743.0')),
#  ('BANDARBAN', 'I00094', Decimal('2233.0')),
#  ('BANDARBAN', 'I00095', Decimal('3376.0')),
#  ('BANDARBAN', 'I00096', Decimal('4860.0')),
#  ('BANDARBAN', 'I00097', Decimal('3610.0')),
#  ('BANDARBAN', 'I00098', Decimal('2300.0')),
#  ('BANDARBAN', 'I00099', Decimal('1434.0')),
#  ('BANDARBAN', 'I00100', Decimal('1960.0')),
#  ('BANDARBAN', 'I00101', Decimal('4995.0')),
#  ('BANDARBAN', 'I00102', Decimal('1840.0')),
#  ('BANDARBAN', 'I00103', Decimal('4020.0')),
#  ('BANDARBAN', 'I00104', Decimal('2828.0')),
#  ('BANDARBAN', 'I00105', Decimal('3267.0')),
#  ('BANDARBAN', 'I00106', Decimal('4437.0')),
#  ('BANDARBAN', 'I00107', Decimal('3220.0')),
#  ('BANDARBAN', 'I00108', Decimal('3090.0')),
#  ('BANDARBAN', 'I00109', Decimal('2958.0')),
#  ('BANDARBAN', 'I00110', Decimal('5827.5')),
#  ('BANDARBAN', 'I00111', Decimal('3792.0')),
#  ('BANDARBAN', 'I00112', Decimal('3598.0')),
#  ('BANDARBAN', 'I00113', Decimal('10374.0')),
#  ('BANDARBAN', 'I00114', Decimal('12716.0')),
#  ('BANDARBAN', 'I00115', Decimal('10653.0')),
#  ('BANDARBAN', 'I00116', Decimal('7920.0')),
#  ('BANDARBAN', 'I00117', Decimal('9798.0')),
#  ('BANDARBAN', 'I00118', Decimal('9912.0')),
#  ('BANDARBAN', 'I00119', Decimal('11501.0')),
#  ('BANDARBAN', 'I00120', Decimal('1935.0')),
#  ('BANDARBAN', 'I00121', Decimal('3145.0')),
#  ('BANDARBAN', 'I00122', Decimal('2865.0')),
#  ('BANDARBAN', 'I00123', Decimal('13320.0')),
#  ('BANDARBAN', 'I00124', Decimal('3870.0')),
#  ('BANDARBAN', 'I00125', Decimal('2580.0')),
#  ('BANDARBAN', 'I00126', Decimal('7150.0')),
#  ('BANDARBAN', 'I00127', Decimal('1762.5')),
#  ('BANDARBAN', 'I00128', Decimal('2816.0')),
#  ('BANDARBAN', 'I00129', Decimal('4590.0')),
#  ('BANDARBAN', 'I00130', Decimal('2884.0')),
#  ('BANDARBAN', 'I00131', Decimal('3276.0')),
#  ('BANDARBAN', 'I00132', Decimal('3626.0')),
#  ('BANDARBAN', 'I00133', Decimal('2835.0')),
#  ('BANDARBAN', 'I00134', Decimal('2912.0')),
#  ('BANDARBAN', 'I00135', Decimal('3598.0')),
#  ('BANDARBAN', 'I00136', Decimal('3276.0')),
#  ('BANDARBAN', 'I00137', Decimal('4728.0')),
#  ('BANDARBAN', 'I00138', Decimal('7296.0')),
#  ('BANDARBAN', 'I00139', Decimal('5832.0')),
#  ('BANDARBAN', 'I00140', Decimal('6641.0')),
#  ('BANDARBAN', 'I00141', Decimal('3132.0')),
#  ('BANDARBAN', 'I00142', Decimal('1950.0')),
#  ('BANDARBAN', 'I00143', Decimal('2912.0')),
#  ('BANDARBAN', 'I00144', Decimal('3720.0')),
#  ('BANDARBAN', 'I00145', Decimal('3587.0')),
#  ('BANDARBAN', 'I00146', Decimal('4641.0')),
#  ('BANDARBAN', 'I00147', Decimal('2520.0')),
#  ('BANDARBAN', 'I00148', Decimal('2820.0')),
#  ('BANDARBAN', 'I00149', Decimal('3675.0')),
#  ('BANDARBAN', 'I00150', Decimal('4736.0')),
#  ('BANDARBAN', 'I00151', Decimal('4607.0')),
#  ('BANDARBAN', 'I00152', Decimal('2895.0')),
#  ('BANDARBAN', 'I00153', Decimal('2850.0')),
#  ('BANDARBAN', 'I00154', Decimal('2610.0')),
#  ('BANDARBAN', 'I00155', Decimal('4811.0')),
#  ('BANDARBAN', 'I00156', Decimal('4012.0')),
#  ('BANDARBAN', 'I00157', Decimal('3485.0')),
#  ('BANDARBAN', 'I00158', Decimal('2924.0')),
#  ('BANDARBAN', 'I00159', Decimal('4250.0')),
#  ('BANDARBAN', 'I00160', Decimal('4148.0')),
#  ('BANDARBAN', 'I00161', Decimal('3638.0')),
#  ('BANDARBAN', 'I00162', Decimal('2848.0')),
#  ('BANDARBAN', 'I00163', Decimal('3705.0')),
#  ('BANDARBAN', 'I00164', Decimal('4208.0')),
#  ('BANDARBAN', 'I00165', Decimal('4304.0')),
#  ('BANDARBAN', 'I00166', Decimal('2805.0')),
#  ('BANDARBAN', 'I00167', Decimal('3052.0')),
#  ('BANDARBAN', 'I00168', Decimal('3240.0')),
#  ('BANDARBAN', 'I00169', Decimal('3332.0')),
#  ('BANDARBAN', 'I00170', Decimal('2955.0')),
#  ('BANDARBAN', 'I00171', Decimal('2928.0')),
#  ('BANDARBAN', 'I00172', Decimal('4104.0')),
#  ('BANDARBAN', 'I00173', Decimal('3496.0')),
#  ('BANDARBAN', 'I00174', Decimal('3294.0')),
#  ('BANDARBAN', 'I00175', Decimal('4275.0')),
#  ('BANDARBAN', 'I00176', Decimal('4085.0')),
#  ('BANDARBAN', 'I00177', Decimal('5180.0')),
#  ('BANDARBAN', 'I00178', Decimal('3744.0')),
#  ('BANDARBAN', 'I00179', Decimal('4218.0')),
#  ('BANDARBAN', 'I00180', Decimal('3743.0')),
#  ('BANDARBAN', 'I00181', Decimal('7436.0')),
#  ('BANDARBAN', 'I00182', Decimal('2925.0')),
#  ('BANDARBAN', 'I00183', Decimal('5950.0')),
#  ('BANDARBAN', 'I00184', Decimal('2616.0')),
#  ('BANDARBAN', 'I00185', Decimal('2926.0')),
#  ('BANDARBAN', 'I00186', Decimal('2509.0')),
#  ('BANDARBAN', 'I00187', Decimal('3042.0')),
#  ('BANDARBAN', 'I00188', Decimal('3094.0')),
#  ('BANDARBAN', 'I00189', Decimal('3094.0')),
#  ('BANDARBAN', 'I00190', Decimal('3952.0')),
#  ('BANDARBAN', 'I00191', Decimal('5160.0')),
#  ('BANDARBAN', 'I00192', Decimal('5880.0')),
#  ('BANDARBAN', 'I00193', Decimal('4284.0')),
#  ('BANDARBAN', 'I00194', Decimal('6187.0')),
#  ('BANDARBAN', 'I00195', Decimal('2737.5')),
#  ('BANDARBAN', 'I00196', Decimal('3488.0')),
#  ('BANDARBAN', 'I00197', Decimal('4410.0')),
#  ('BANDARBAN', 'I00198', Decimal('2820.0')),
#  ('BANDARBAN', 'I00199', Decimal('2760.0')),
#  ('BANDARBAN', 'I00200', Decimal('4680.0')),
#  ('BANDARBAN', 'I00201', Decimal('5727.0')),
#  ('BANDARBAN', 'I00202', Decimal('3276.0')),
#  ('BANDARBAN', 'I00203', Decimal('3204.0')),
#  ('BANDARBAN', 'I00204', Decimal('2754.0')),
#  ('BANDARBAN', 'I00205', Decimal('3328.0')),
#  ('BANDARBAN', 'I00206', Decimal('3960.0')),
#  ('BANDARBAN', 'I00207', Decimal('2800.0')),
#  ('BANDARBAN', 'I00208', Decimal('2842.0')),
#  ('BANDARBAN', 'I00209', Decimal('2392.0')),
#  ('BANDARBAN', 'I00210', Decimal('3105.0')),
#  ('BANDARBAN', 'I00211', Decimal('3780.0')),
#  ('BANDARBAN', 'I00212', Decimal('2604.0')),
#  ('BANDARBAN', 'I00213', Decimal('3024.0')),
#  ('BANDARBAN', 'I00214', Decimal('4348.5')),
#  ('BANDARBAN', 'I00215', Decimal('3500.0')),
#  ('BANDARBAN', 'I00216', Decimal('4257.0')),
#  ('BANDARBAN', 'I00217', Decimal('3505.5')),
#  ('BANDARBAN', 'I00218', Decimal('1194.0')),
#  ('BANDARBAN', 'I00219', Decimal('4774.0')),
#  ('BANDARBAN', 'I00220', Decimal('3178.0')),
#  ('BANDARBAN', 'I00221', Decimal('2632.0')),
#  ('BANDARBAN', 'I00222', Decimal('2952.0')),
#  ('BANDARBAN', 'I00223', Decimal('3064.5')),
#  ('BANDARBAN', 'I00224', Decimal('2046.0')),
#  ('BANDARBAN', 'I00225', Decimal('4012.0')),
#  ('BANDARBAN', 'I00226', Decimal('3390.0')),
#  ('BANDARBAN', 'I00227', Decimal('3585.0')),
#  ('BANDARBAN', 'I00228', Decimal('2716.0')),
#  ('BANDARBAN', 'I00229', Decimal('2990.0')),
#  ('BANDARBAN', 'I00230', Decimal('2430.0')),
#  ('BANDARBAN', 'I00231', Decimal('3472.0')),
#  ('BANDARBAN', 'I00232', Decimal('2232.0')),
#  ('BANDARBAN', 'I00233', Decimal('2256.0')),
#  ('BANDARBAN', 'I00234', Decimal('2314.0')),
#  ('BANDARBAN', 'I00235', Decimal('2772.0')),
#  ('BANDARBAN', 'I00236', Decimal('2052.0')),
#  ('BANDARBAN', 'I00237', Decimal('3456.0')),
#  ('BANDARBAN', 'I00238', Decimal('2652.0')),
#  ('BANDARBAN', 'I00239', Decimal('2786.0')),
#  ('BANDARBAN', 'I00240', Decimal('3248.0')),
#  ('BANDARBAN', 'I00241', Decimal('3084.0')),
#  ('BANDARBAN', 'I00242', Decimal('2196.0')),
#  ('BANDARBAN', 'I00243', Decimal('3632.0')),
#  ('BANDARBAN', 'I00244', Decimal('5130.0')),
#  ('BANDARBAN', 'I00245', Decimal('4550.0')),
#  ('BANDARBAN', 'I00246', Decimal('3420.0')),
#  ('BANDARBAN', 'I00247', Decimal('4140.0')),
#  ('BANDARBAN', 'I00248', Decimal('4784.0')),
#  ('BANDARBAN', 'I00249', Decimal('4208.0')),
#  ('BANDARBAN', 'I00250', Decimal('3997.5')),
#  ('BANDARBAN', 'I00251', Decimal('3497.0')),
#  ('BANDARBAN', 'I00252', Decimal('1859.0')),
#  ('BANDARBAN', 'I00253', Decimal('4998.0')),
#  ('BANDARBAN', 'I00254', Decimal('2834.0')),
#  ('BANDARBAN', 'I00255', Decimal('3080.0')),
#  ('BANDARBAN', 'I00256', Decimal('4360.0')),
#  ('BANDARBAN', 'I00257', Decimal('5607.0')),
#  ('BANDARBAN', 'I00258', Decimal('4830.0')),
#  ('BANDARBAN', 'I00259', Decimal('4758.0')),
#  ('BANDARBAN', 'I00260', Decimal('4545.0')),
#  ('BANDARBAN', 'I00261', Decimal('8481.0')),
#  ('BANDARBAN', 'I00262', Decimal('2436.0')),
#  ('BANDARBAN', 'I00263', Decimal('2632.0')),
#  ('BANDARBAN', 'I00264', Decimal('4590.0')),
#  ('BANDARBAN', None, Decimal('995360.75')),
#  ('BARGUNA', 'I00001', Decimal('2357.5')),
#  ('BARGUNA', 'I00002', Decimal('1066.50')),
#  ('BARGUNA', 'I00003', Decimal('1302.75')),
#  ('BARGUNA', 'I00004', Decimal('1451.25')),
#  ('BARGUNA', 'I00005', Decimal('762.75')),
#  ('BARGUNA', 'I00006', Decimal('3087.50')),
#  ('BARGUNA', 'I00007', Decimal('1221.75')),
#  ('BARGUNA', 'I00008', Decimal('2616.25')),
#  ('BARGUNA', 'I00009', Decimal('3428.75')),
#  ('BARGUNA', 'I00010', Decimal('1431.00')),
#  ('BARGUNA', 'I00011', Decimal('1518.75')),
#  ('BARGUNA', 'I00012', Decimal('3672.50')),
#  ('BARGUNA', 'I00013', Decimal('1444.50')),
#  ('BARGUNA', 'I00014', Decimal('1437.75')),
#  ('BARGUNA', 'I00015', Decimal('1545.75')),
#  ('BARGUNA', 'I00016', Decimal('3120.00')),
#  ('BARGUNA', 'I00017', Decimal('918.00')),
#  ('BARGUNA', 'I00018', Decimal('1228.50')),
#  ('BARGUNA', 'I00019', Decimal('1842.75')),
#  ('BARGUNA', 'I00020', Decimal('1491.75')),
#  ('BARGUNA', 'I00021', Decimal('1606.50')),
#  ('BARGUNA', 'I00022', Decimal('2941.25')),
#  ('BARGUNA', 'I00023', Decimal('1525.50')),
#  ('BARGUNA', 'I00024', Decimal('3510.00')),
#  ('BARGUNA', 'I00025', Decimal('2714.0')),
#  ('BARGUNA', 'I00026', Decimal('999.00')),
#  ('BARGUNA', 'I00027', Decimal('3835.00')),
#  ('BARGUNA', 'I00028', Decimal('1417.50')),
#  ('BARGUNA', 'I00029', Decimal('1805.5')),
#  ('BARGUNA', 'I00030', Decimal('2656.0')),
#  ('BARGUNA', 'I00031', Decimal('3040.0')),
#  ('BARGUNA', 'I00032', Decimal('1904.0')),
#  ('BARGUNA', 'I00033', Decimal('3696.0')),
#  ('BARGUNA', 'I00034', Decimal('3568.0')),
#  ('BARGUNA', 'I00035', Decimal('3408.0')),
#  ('BARGUNA', 'I00036', Decimal('2352.0')),
#  ('BARGUNA', 'I00037', Decimal('2784.0')),
#  ('BARGUNA', 'I00038', Decimal('2760.0')),
#  ('BARGUNA', 'I00039', Decimal('5174.0')),
#  ('BARGUNA', 'I00040', Decimal('3872.0')),
#  ('BARGUNA', 'I00041', Decimal('3887.0')),
#  ('BARGUNA', 'I00042', Decimal('6832.0')),
#  ('BARGUNA', 'I00043', Decimal('3432.0')),
#  ('BARGUNA', 'I00044', Decimal('1456.0')),
#  ('BARGUNA', 'I00045', Decimal('1408.0')),
#  ('BARGUNA', 'I00046', Decimal('2000.0')),
#  ('BARGUNA', 'I00047', Decimal('1688.0')),
#  ('BARGUNA', 'I00048', Decimal('1568.0')),
#  ('BARGUNA', 'I00049', Decimal('1792.0')),
#  ('BARGUNA', 'I00050', Decimal('1336.0')),
#  ('BARGUNA', 'I00051', Decimal('4715.0')),
#  ('BARGUNA', 'I00052', Decimal('6240.0')),
#  ('BARGUNA', 'I00053', Decimal('6960.0')),
#  ('BARGUNA', 'I00054', Decimal('7640.0')),
#  ('BARGUNA', 'I00055', Decimal('11080.0')),
#  ('BARGUNA', 'I00056', Decimal('3384.0')),
#  ('BARGUNA', 'I00057', Decimal('3864.0')),
#  ('BARGUNA', 'I00058', Decimal('3454.0')),
#  ('BARGUNA', 'I00059', Decimal('4840.0')),
#  ('BARGUNA', 'I00060', Decimal('3784.0')),
#  ('BARGUNA', 'I00061', Decimal('9680.0')),
#  ('BARGUNA', 'I00062', Decimal('9731.0')),
#  ('BARGUNA', 'I00063', Decimal('10040.0')),
#  ('BARGUNA', 'I00064', Decimal('5440.0')),
#  ('BARGUNA', 'I00065', Decimal('4120.0')),
#  ('BARGUNA', 'I00066', Decimal('2040.0')),
#  ('BARGUNA', 'I00067', Decimal('1976.0')),
#  ('BARGUNA', 'I00068', Decimal('3440.0')),
#  ('BARGUNA', 'I00069', Decimal('3815.0')),
#  ('BARGUNA', 'I00070', Decimal('3307.5')),
#  ('BARGUNA', 'I00071', Decimal('3622.5')),
#  ('BARGUNA', 'I00072', Decimal('5020.0')),
#  ('BARGUNA', 'I00073', Decimal('3740.0')),
#  ('BARGUNA', 'I00074', Decimal('3360.0')),
#  ('BARGUNA', 'I00075', Decimal('3611.5')),
#  ('BARGUNA', 'I00076', Decimal('1377.00')),
#  ('BARGUNA', 'I00077', Decimal('1350.00')),
#  ('BARGUNA', 'I00078', Decimal('3859.0')),
#  ('BARGUNA', 'I00079', Decimal('2703.0')),
#  ('BARGUNA', 'I00080', Decimal('3190.0')),
#  ('BARGUNA', 'I00081', Decimal('5046.0')),
#  ('BARGUNA', 'I00082', Decimal('2970.0')),
#  ('BARGUNA', 'I00083', Decimal('2758.0')),
#  ('BARGUNA', 'I00084', Decimal('4032.0')),
#  ('BARGUNA', 'I00085', Decimal('3348.0')),
#  ('BARGUNA', 'I00086', Decimal('3582.0')),
#  ('BARGUNA', 'I00087', Decimal('2325.0')),
#  ('BARGUNA', 'I00088', Decimal('2771.0')),
#  ('BARGUNA', 'I00089', Decimal('1080.0')),
#  ('BARGUNA', 'I00090', Decimal('2268.0')),
#  ('BARGUNA', 'I00091', Decimal('1230.0')),
#  ('BARGUNA', 'I00092', Decimal('1450.0')),
#  ('BARGUNA', 'I00093', Decimal('2314.0')),
#  ('BARGUNA', 'I00094', Decimal('1815.0')),
#  ('BARGUNA', 'I00095', Decimal('1984.0')),
#  ('BARGUNA', 'I00096', Decimal('3500.0')),
#  ('BARGUNA', 'I00097', Decimal('3667.0')),
#  ('BARGUNA', 'I00098', Decimal('2030.0')),
#  ('BARGUNA', 'I00099', Decimal('1308.0')),
#  ('BARGUNA', 'I00100', Decimal('1610.0')),
#  ('BARGUNA', 'I00101', Decimal('2790.0')),
#  ('BARGUNA', 'I00102', Decimal('3872.0')),
#  ('BARGUNA', 'I00103', Decimal('2160.0')),
#  ('BARGUNA', 'I00104', Decimal('2282.0')),
#  ('BARGUNA', 'I00105', Decimal('2904.0')),
#  ('BARGUNA', 'I00106', Decimal('3349.0')),
#  ('BARGUNA', 'I00107', Decimal('4000.0')),
#  ('BARGUNA', 'I00108', Decimal('2520.0')),
#  ('BARGUNA', 'I00109', Decimal('3383.0')),
#  ('BARGUNA', 'I00110', Decimal('4297.5')),
#  ('BARGUNA', 'I00111', Decimal('3376.0')),
#  ('BARGUNA', 'I00112', Decimal('2828.0')),
#  ('BARGUNA', 'I00113', Decimal('7014.0')),
#  ('BARGUNA', 'I00114', Decimal('8228.0')),
#  ('BARGUNA', 'I00115', Decimal('9540.0')),
#  ('BARGUNA', 'I00116', Decimal('8832.0')),
#  ('BARGUNA', 'I00117', Decimal('8832.0')),
#  ('BARGUNA', 'I00118', Decimal('9240.0')),
#  ('BARGUNA', 'I00119', Decimal('9010.0')),
#  ('BARGUNA', 'I00120', Decimal('1287.0')),
#  ('BARGUNA', 'I00121', Decimal('3978.0')),
#  ('BARGUNA', 'I00122', Decimal('2895.0')),
#  ('BARGUNA', 'I00123', Decimal('9225.0')),
#  ('BARGUNA', 'I00124', Decimal('3690.0')),
#  ('BARGUNA', 'I00125', Decimal('4050.0')),
#  ('BARGUNA', 'I00126', Decimal('4100.0')),
#  ('BARGUNA', 'I00127', Decimal('2262.5')),
#  ('BARGUNA', 'I00128', Decimal('2800.0')),
#  ('BARGUNA', 'I00129', Decimal('2412.0')),
#  ('BARGUNA', 'I00130', Decimal('2632.0')),
#  ('BARGUNA', 'I00131', Decimal('2380.0')),
#  ('BARGUNA', 'I00132', Decimal('2394.0')),
#  ('BARGUNA', 'I00133', Decimal('3435.0')),
#  ('BARGUNA', 'I00134', Decimal('1888.0')),
#  ('BARGUNA', 'I00135', Decimal('4242.0')),
#  ('BARGUNA', 'I00136', Decimal('3627.0')),
#  ('BARGUNA', 'I00137', Decimal('3792.0')),
#  ('BARGUNA', 'I00138', Decimal('4224.0')),
#  ('BARGUNA', 'I00139', Decimal('3048.0')),
#  ('BARGUNA', 'I00140', Decimal('6960.0')),
#  ('BARGUNA', 'I00141', Decimal('2430.0')),
#  ('BARGUNA', 'I00142', Decimal('2087.5')),
#  ('BARGUNA', 'I00143', Decimal('2592.0')),
#  ('BARGUNA', 'I00144', Decimal('3460.0')),
#  ('BARGUNA', 'I00145', Decimal('3009.0')),
#  ('BARGUNA', 'I00146', Decimal('3129.0')),
#  ('BARGUNA', 'I00147', Decimal('2325.0')),
#  ('BARGUNA', 'I00148', Decimal('2580.0')),
#  ('BARGUNA', 'I00149', Decimal('3000.0')),
#  ('BARGUNA', 'I00150', Decimal('3744.0')),
#  ('BARGUNA', 'I00151', Decimal('2771.0')),
#  ('BARGUNA', 'I00152', Decimal('1950.0')),
#  ('BARGUNA', 'I00153', Decimal('3180.0')),
#  ('BARGUNA', 'I00154', Decimal('3045.0')),
#  ('BARGUNA', 'I00155', Decimal('2907.0')),
#  ('BARGUNA', 'I00156', Decimal('4386.0')),
#  ('BARGUNA', 'I00157', Decimal('2873.0')),
#  ('BARGUNA', 'I00158', Decimal('2941.0')),
#  ('BARGUNA', 'I00159', Decimal('2669.0')),
#  ('BARGUNA', 'I00160', Decimal('3621.0')),
#  ('BARGUNA', 'I00161', Decimal('3332.0')),
#  ('BARGUNA', 'I00162', Decimal('2608.0')),
#  ('BARGUNA', 'I00163', Decimal('4050.0')),
#  ('BARGUNA', 'I00164', Decimal('3792.0')),
#  ('BARGUNA', 'I00165', Decimal('2496.0')),
#  ('BARGUNA', 'I00166', Decimal('3536.0')),
#  ('BARGUNA', 'I00167', Decimal('2688.0')),
#  ('BARGUNA', 'I00168', Decimal('2880.0')),
#  ('BARGUNA', 'I00169', Decimal('3587.0')),
#  ('BARGUNA', 'I00170', Decimal('2370.0')),
#  ('BARGUNA', 'I00171', Decimal('2320.0')),
#  ('BARGUNA', 'I00172', Decimal('3800.0')),
#  ('BARGUNA', 'I00173', Decimal('3249.0')),
#  ('BARGUNA', 'I00174', Decimal('2556.0')),
#  ('BARGUNA', 'I00175', Decimal('3553.0')),
#  ('BARGUNA', 'I00176', Decimal('2888.0')),
#  ('BARGUNA', 'I00177', Decimal('5985.0')),
#  ('BARGUNA', 'I00178', Decimal('7176.0')),
#  ('BARGUNA', 'I00179', Decimal('3876.0')),
#  ('BARGUNA', 'I00180', Decimal('4161.0')),
#  ('BARGUNA', 'I00181', Decimal('4550.0')),
#  ('BARGUNA', 'I00182', Decimal('2790.0')),
#  ('BARGUNA', 'I00183', Decimal('6125.0')),
#  ('BARGUNA', 'I00184', Decimal('1908.0')),
#  ('BARGUNA', 'I00185', Decimal('2702.0')),
#  ('BARGUNA', 'I00186', Decimal('3315.0')),
#  ('BARGUNA', 'I00187', Decimal('2158.0')),
#  ('BARGUNA', 'I00188', Decimal('2688.0')),
#  ('BARGUNA', 'I00189', Decimal('3692.0')),
#  ('BARGUNA', 'I00190', Decimal('1888.0')),
#  ('BARGUNA', 'I00191', Decimal('3288.0')),
#  ('BARGUNA', 'I00192', Decimal('4392.0')),
#  ('BARGUNA', 'I00193', Decimal('3240.0')),
#  ('BARGUNA', 'I00194', Decimal('3795.0')),
#  ('BARGUNA', 'I00195', Decimal('1812.5')),
#  ('BARGUNA', 'I00196', Decimal('3616.0')),
#  ('BARGUNA', 'I00197', Decimal('2535.0')),
#  ('BARGUNA', 'I00198', Decimal('2736.0')),
#  ('BARGUNA', 'I00199', Decimal('3450.0')),
#  ('BARGUNA', 'I00200', Decimal('4760.0')),
#  ('BARGUNA', 'I00201', Decimal('4899.0')),
#  ('BARGUNA', 'I00202', Decimal('1488.0')),
#  ('BARGUNA', 'I00203', Decimal('3510.0')),
#  ('BARGUNA', 'I00204', Decimal('1955.0')),
#  ('BARGUNA', 'I00205', Decimal('3168.0')),
#  ('BARGUNA', 'I00206', Decimal('3585.0')),
#  ('BARGUNA', 'I00207', Decimal('3010.0')),
#  ('BARGUNA', 'I00208', Decimal('2548.0')),
#  ('BARGUNA', 'I00209', Decimal('1573.0')),
#  ('BARGUNA', 'I00210', Decimal('1185.0')),
#  ('BARGUNA', 'I00211', Decimal('2415.0')),
#  ('BARGUNA', 'I00212', Decimal('2412.0')),
#  ('BARGUNA', 'I00213', Decimal('2388.0')),
#  ('BARGUNA', 'I00214', Decimal('4582.5')),
#  ('BARGUNA', 'I00215', Decimal('1638.0')),
#  ('BARGUNA', 'I00216', Decimal('2508.0')),
#  ('BARGUNA', 'I00217', Decimal('3300.5')),
#  ('BARGUNA', 'I00218', Decimal('1530.0')),
#  ('BARGUNA', 'I00219', Decimal('3652.0')),
#  ('BARGUNA', 'I00220', Decimal('1960.0')),
#  ('BARGUNA', 'I00221', Decimal('3248.0')),
#  ('BARGUNA', 'I00222', Decimal('2124.0')),
#  ('BARGUNA', 'I00223', Decimal('1984.5')),
#  ('BARGUNA', 'I00224', Decimal('1925.0')),
#  ('BARGUNA', 'I00225', Decimal('4148.0')),
#  ('BARGUNA', 'I00226', Decimal('2700.0')),
#  ('BARGUNA', 'I00227', Decimal('2655.0')),
#  ('BARGUNA', 'I00228', Decimal('2660.0')),
#  ('BARGUNA', 'I00229', Decimal('2860.0')),
#  ('BARGUNA', 'I00230', Decimal('3105.0')),
#  ('BARGUNA', 'I00231', Decimal('3024.0')),
#  ('BARGUNA', 'I00232', Decimal('1668.0')),
#  ('BARGUNA', 'I00233', Decimal('2808.0')),
#  ('BARGUNA', 'I00234', Decimal('3406.0')),
#  ('BARGUNA', 'I00235', Decimal('2534.0')),
#  ('BARGUNA', 'I00236', Decimal('1128.0')),
#  ('BARGUNA', 'I00237', Decimal('3328.0')),
#  ('BARGUNA', 'I00238', Decimal('2196.0')),
#  ('BARGUNA', 'I00239', Decimal('2870.0')),
#  ('BARGUNA', 'I00240', Decimal('3416.0')),
#  ('BARGUNA', 'I00241', Decimal('2400.0')),
#  ('BARGUNA', 'I00242', Decimal('2448.0')),
#  ('BARGUNA', 'I00243', Decimal('3984.0')),
#  ('BARGUNA', 'I00244', Decimal('2808.0')),
#  ('BARGUNA', 'I00245', Decimal('3276.0')),
#  ('BARGUNA', 'I00246', Decimal('5080.0')),
#  ('BARGUNA', 'I00247', Decimal('3390.0')),
#  ('BARGUNA', 'I00248', Decimal('5356.0')),
#  ('BARGUNA', 'I00249', Decimal('3152.0')),
#  ('BARGUNA', 'I00250', Decimal('2905.5')),
#  ('BARGUNA', 'I00251', Decimal('2613.0')),
#  ('BARGUNA', 'I00252', Decimal('2772.0')),
#  ('BARGUNA', 'I00253', Decimal('4935.0')),
#  ('BARGUNA', 'I00254', Decimal('1651.0')),
#  ('BARGUNA', 'I00255', Decimal('5360.0')),
#  ('BARGUNA', 'I00256', Decimal('2540.0')),
#  ('BARGUNA', 'I00257', Decimal('2016.0')),
#  ('BARGUNA', 'I00258', Decimal('4578.0')),
#  ('BARGUNA', 'I00259', Decimal('4680.0')),
#  ('BARGUNA', 'I00260', Decimal('3480.0')),
#  ('BARGUNA', 'I00261', Decimal('5016.0')),
#  ('BARGUNA', 'I00262', Decimal('3514.0')),
#  ('BARGUNA', 'I00263', Decimal('2520.0')),
#  ('BARGUNA', 'I00264', Decimal('2265.0')),
#  ('BARGUNA', None, Decimal('869041.00')),
#  ('BARISAL', 'I00001', Decimal('7705.0')),
#  ('BARISAL', 'I00002', Decimal('3638.25')),
#  ('BARISAL', 'I00003', Decimal('4576.50')),
#  ('BARISAL', 'I00004', Decimal('3773.25')),
#  ('BARISAL', 'I00005', Decimal('3577.50')),
#  ('BARISAL', 'I00006', Decimal('10367.50')),
#  ('BARISAL', 'I00007', Decimal('3557.25')),
#  ('BARISAL', 'I00008', Decimal('13845.00')),
#  ('BARISAL', 'I00009', Decimal('10172.50')),
#  ('BARISAL', 'I00010', Decimal('3881.25')),
#  ('BARISAL', 'I00011', Decimal('4664.25')),
#  ('BARISAL', 'I00012', Decimal('9018.75')),
#  ('BARISAL', 'I00013', Decimal('3678.75')),
#  ('BARISAL', 'I00014', Decimal('3361.50')),
#  ('BARISAL', 'I00015', Decimal('3813.75')),
#  ('BARISAL', 'I00016', Decimal('11537.50')),
#  ('BARISAL', 'I00017', Decimal('3570.75')),
#  ('BARISAL', 'I00018', Decimal('4664.25')),
#  ('BARISAL', 'I00019', Decimal('3847.50')),
#  ('BARISAL', 'I00020', Decimal('4495.50')),
#  ('BARISAL', 'I00021', Decimal('4198.50')),
#  ('BARISAL', 'I00022', Decimal('9717.50')),
#  ('BARISAL', 'I00023', Decimal('3915.00')),
#  ('BARISAL', 'I00024', Decimal('9067.50')),
#  ('BARISAL', 'I00025', Decimal('5991.5')),
#  ('BARISAL', 'I00026', Decimal('3780.00')),
#  ('BARISAL', 'I00027', Decimal('10562.50')),
#  ('BARISAL', 'I00028', Decimal('3550.50')),
#  ('BARISAL', 'I00029', Decimal('6589.5')),
#  ('BARISAL', 'I00030', Decimal('8976.0')),
#  ('BARISAL', 'I00031', Decimal('9520.0')),
#  ('BARISAL', 'I00032', Decimal('10576.0')),
#  ('BARISAL', 'I00033', Decimal('10416.0')),
#  ('BARISAL', 'I00034', Decimal('10128.0')),
#  ('BARISAL', 'I00035', Decimal('9248.0')),
#  ('BARISAL', 'I00036', Decimal('9104.0')),
#  ('BARISAL', 'I00037', Decimal('11120.0')),
#  ('BARISAL', 'I00038', Decimal('11822.0')),
#  ('BARISAL', 'I00039', Decimal('16432.0')),
#  ('BARISAL', 'I00040', Decimal('14608.0')),
#  ('BARISAL', 'I00041', Decimal('13248.0')),
#  ('BARISAL', 'I00042', Decimal('13496.0')),
#  ('BARISAL', 'I00043', Decimal('14280.0')),
#  ('BARISAL', 'I00044', Decimal('5000.0')),
#  ('BARISAL', 'I00045', Decimal('4264.0')),
#  ('BARISAL', 'I00046', Decimal('4776.0')),
#  ('BARISAL', 'I00047', Decimal('4512.0')),
#  ('BARISAL', 'I00048', Decimal('5064.0')),
#  ('BARISAL', 'I00049', Decimal('5296.0')),
#  ('BARISAL', 'I00050', Decimal('5672.0')),
#  ('BARISAL', 'I00051', Decimal('15686.0')),
#  ('BARISAL', 'I00052', Decimal('25360.0')),
#  ('BARISAL', 'I00053', Decimal('27000.0')),
#  ('BARISAL', 'I00054', Decimal('29520.0')),
#  ('BARISAL', 'I00055', Decimal('24800.0')),
#  ('BARISAL', 'I00056', Decimal('13032.0')),
#  ('BARISAL', 'I00057', Decimal('15720.0')),
#  ('BARISAL', 'I00058', Decimal('16368.0')),
#  ('BARISAL', 'I00059', Decimal('15510.0')),
#  ('BARISAL', 'I00060', Decimal('10450.0')),
#  ('BARISAL', 'I00061', Decimal('38885.0')),
#  ('BARISAL', 'I00062', Decimal('25863.0')),
#  ('BARISAL', 'I00063', Decimal('25720.0')),
#  ('BARISAL', 'I00064', Decimal('28600.0')),
#  ('BARISAL', 'I00065', Decimal('12560.0')),
#  ('BARISAL', 'I00066', Decimal('11800.0')),
#  ('BARISAL', 'I00067', Decimal('5504.0')),
#  ('BARISAL', 'I00068', Decimal('13480.0')),
#  ('BARISAL', 'I00069', Decimal('11060.0')),
#  ('BARISAL', 'I00070', Decimal('9537.5')),
#  ('BARISAL', 'I00071', Decimal('11602.5')),
#  ('BARISAL', 'I00072', Decimal('12960.0')),
#  ('BARISAL', 'I00073', Decimal('13220.0')),
#  ('BARISAL', 'I00074', Decimal('10380.0')),
#  ('BARISAL', 'I00075', Decimal('11299.5')),
#  ('BARISAL', 'I00076', Decimal('4482.00')),
#  ('BARISAL', 'I00077', Decimal('4164.75')),
#  ('BARISAL', 'I00078', Decimal('11543.0')),
#  ('BARISAL', 'I00079', Decimal('9146.0')),
#  ('BARISAL', 'I00080', Decimal('13860.0')),
#  ('BARISAL', 'I00081', Decimal('20561.0')),
#  ('BARISAL', 'I00082', Decimal('8385.0')),
#  ('BARISAL', 'I00083', Decimal('9338.0')),
#  ('BARISAL', 'I00084', Decimal('11178.0')),
#  ('BARISAL', 'I00085', Decimal('11862.0')),
#  ('BARISAL', 'I00086', Decimal('9972.0')),
#  ('BARISAL', 'I00087', Decimal('9420.0')),
#  ('BARISAL', 'I00088', Decimal('9979.0')),
#  ('BARISAL', 'I00089', Decimal('5967.0')),
#  ('BARISAL', 'I00090', Decimal('4653.0')),
#  ('BARISAL', 'I00091', Decimal('4230.0')),
#  ('BARISAL', 'I00092', Decimal('5440.0')),
#  ('BARISAL', 'I00093', Decimal('10803.0')),
#  ('BARISAL', 'I00094', Decimal('7898.0')),
#  ('BARISAL', 'I00095', Decimal('10288.0')),
#  ('BARISAL', 'I00096', Decimal('13580.0')),
#  ('BARISAL', 'I00097', Decimal('12768.0')),
#  ('BARISAL', 'I00098', Decimal('6230.0')),
#  ('BARISAL', 'I00099', Decimal('4236.0')),
#  ('BARISAL', 'I00100', Decimal('5730.0')),
#  ('BARISAL', 'I00101', Decimal('8025.0')),
#  ('BARISAL', 'I00102', Decimal('9568.0')),
#  ('BARISAL', 'I00103', Decimal('11655.0')),
#  ('BARISAL', 'I00104', Decimal('9254.0')),
#  ('BARISAL', 'I00105', Decimal('10972.5')),
#  ('BARISAL', 'I00106', Decimal('11798.0')),
#  ('BARISAL', 'I00107', Decimal('11220.0')),
#  ('BARISAL', 'I00108', Decimal('8445.0')),
#  ('BARISAL', 'I00109', Decimal('10438.0')),
#  ('BARISAL', 'I00110', Decimal('14512.5')),
#  ('BARISAL', 'I00111', Decimal('11728.0')),
#  ('BARISAL', 'I00112', Decimal('7448.0')),
#  ('BARISAL', 'I00113', Decimal('24192.0')),
#  ('BARISAL', 'I00114', Decimal('32604.0')),
#  ('BARISAL', 'I00115', Decimal('30369.0')),
#  ('BARISAL', 'I00116', Decimal('30864.0')),
#  ('BARISAL', 'I00117', Decimal('26128.0')),
#  ('BARISAL', 'I00118', Decimal('25074.0')),
#  ('BARISAL', 'I00119', Decimal('31058.0')),
#  ('BARISAL', 'I00120', Decimal('4968.0')),
#  ('BARISAL', 'I00121', Decimal('11067.0')),
#  ('BARISAL', 'I00122', Decimal('9330.0')),
#  ('BARISAL', 'I00123', Decimal('26460.0')),
#  ('BARISAL', 'I00124', Decimal('10905.0')),
#  ('BARISAL', 'I00125', Decimal('8145.0')),
#  ('BARISAL', 'I00126', Decimal('14525.0')),
#  ('BARISAL', 'I00127', Decimal('7150.0')),
#  ('BARISAL', 'I00128', Decimal('9232.0')),
#  ('BARISAL', 'I00129', Decimal('10566.0')),
#  ('BARISAL', 'I00130', Decimal('9086.0')),
#  ('BARISAL', 'I00131', Decimal('9282.0')),
#  ('BARISAL', 'I00132', Decimal('9576.0')),
#  ('BARISAL', 'I00133', Decimal('8700.0')),
#  ('BARISAL', 'I00134', Decimal('9312.0')),
#  ('BARISAL', 'I00135', Decimal('8568.0')),
#  ('BARISAL', 'I00136', Decimal('11836.5')),
#  ('BARISAL', 'I00137', Decimal('16440.0')),
#  ('BARISAL', 'I00138', Decimal('23296.0')),
#  ('BARISAL', 'I00139', Decimal('13032.0')),
#  ('BARISAL', 'I00140', Decimal('19227.0')),
#  ('BARISAL', 'I00141', Decimal('10980.0')),
#  ('BARISAL', 'I00142', Decimal('7287.5')),
#  ('BARISAL', 'I00143', Decimal('8880.0')),
#  ('BARISAL', 'I00144', Decimal('12760.0')),
#  ('BARISAL', 'I00145', Decimal('11322.0')),
#  ('BARISAL', 'I00146', Decimal('14364.0')),
#  ('BARISAL', 'I00147', Decimal('8700.0')),
#  ('BARISAL', 'I00148', Decimal('7650.0')),
#  ('BARISAL', 'I00149', Decimal('8715.0')),
#  ('BARISAL', 'I00150', Decimal('10576.0')),
#  ('BARISAL', 'I00151', Decimal('9231.0')),
#  ('BARISAL', 'I00152', Decimal('9915.0')),
#  ('BARISAL', 'I00153', Decimal('9645.0')),
#  ('BARISAL', 'I00154', Decimal('8295.0')),
#  ('BARISAL', 'I00155', Decimal('10421.0')),
#  ('BARISAL', 'I00156', Decimal('8959.0')),
#  ('BARISAL', 'I00157', Decimal('9027.0')),
#  ('BARISAL', 'I00158', Decimal('11101.0')),
#  ('BARISAL', 'I00159', Decimal('11985.0')),
#  ('BARISAL', 'I00160', Decimal('9741.0')),
#  ('BARISAL', 'I00161', Decimal('9741.0')),
#  ('BARISAL', 'I00162', Decimal('10512.0')),
#  ('BARISAL', 'I00163', Decimal('9930.0')),
#  ('BARISAL', 'I00164', Decimal('9136.0')),
#  ('BARISAL', 'I00165', Decimal('10784.0')),
#  ('BARISAL', 'I00166', Decimal('9265.0')),
#  ('BARISAL', 'I00167', Decimal('7518.0')),
#  ('BARISAL', 'I00168', Decimal('10278.0')),
#  ('BARISAL', 'I00169', Decimal('9231.0')),
#  ('BARISAL', 'I00170', Decimal('8925.0')),
#  ('BARISAL', 'I00171', Decimal('9632.0')),
#  ('BARISAL', 'I00172', Decimal('9576.0')),
#  ('BARISAL', 'I00173', Decimal('13433.0')),
#  ('BARISAL', 'I00174', Decimal('8694.0')),
#  ('BARISAL', 'I00175', Decimal('12103.0')),
#  ('BARISAL', 'I00176', Decimal('12027.0')),
#  ('BARISAL', 'I00177', Decimal('22190.0')),
#  ('BARISAL', 'I00178', Decimal('19604.0')),
#  ('BARISAL', 'I00179', Decimal('11153.0')),
#  ('BARISAL', 'I00180', Decimal('10564.0')),
#  ('BARISAL', 'I00181', Decimal('17654.0')),
#  ('BARISAL', 'I00182', Decimal('8445.0')),
#  ('BARISAL', 'I00183', Decimal('22085.0')),
#  ('BARISAL', 'I00184', Decimal('7632.0')),
#  ('BARISAL', 'I00185', Decimal('7224.0')),
#  ('BARISAL', 'I00186', Decimal('8515.0')),
#  ('BARISAL', 'I00187', Decimal('8502.0')),
#  ('BARISAL', 'I00188', Decimal('7252.0')),
#  ('BARISAL', 'I00189', Decimal('8073.0')),
#  ('BARISAL', 'I00190', Decimal('11520.0')),
#  ('BARISAL', 'I00191', Decimal('12696.0')),
#  ('BARISAL', 'I00192', Decimal('15696.0')),
#  ('BARISAL', 'I00193', Decimal('9774.0')),
#  ('BARISAL', 'I00194', Decimal('15617.0')),
#  ('BARISAL', 'I00195', Decimal('8762.5')),
#  ('BARISAL', 'I00196', Decimal('10336.0')),
#  ('BARISAL', 'I00197', Decimal('9900.0')),
#  ('BARISAL', 'I00198', Decimal('7224.0')),
#  ('BARISAL', 'I00199', Decimal('10920.0')),
#  ('BARISAL', 'I00200', Decimal('15940.0')),
#  ('BARISAL', 'I00201', Decimal('16721.0')),
#  ('BARISAL', 'I00202', Decimal('6504.0')),
#  ('BARISAL', 'I00203', Decimal('11844.0')),
#  ('BARISAL', 'I00204', Decimal('8925.0')),
#  ('BARISAL', 'I00205', Decimal('8032.0')),
#  ...]

# %%
df = pd.DataFrame(list(records), columns=['District', 'item_key', 'total_sales_price'])
df.head(10)
# Out:
#    District item_key total_sales_price
# 0  BAGERHAT   I00001            2863.5
# 1  BAGERHAT   I00002           1559.25
# 2  BAGERHAT   I00003           2362.50
# 3  BAGERHAT   I00004           2038.50
# 4  BAGERHAT   I00005           2058.75
# 5  BAGERHAT   I00006           4371.25
# 6  BAGERHAT   I00007           1707.75
# 7  BAGERHAT   I00008           5248.75
# 8  BAGERHAT   I00009           4598.75
# 9  BAGERHAT   I00010           2396.25

# %% [markdown]
# ***Total_sale_price By year Wise***

# %%
con = PostgresConnection().getConnection()

cur = con.cursor()
select_stmt = "SELECT  year, SUM(total_price) total_sales_price " \
        "FROM ecom_schema.time_dim " \
        "INNER JOIN ecom_schema.fact_table ON fact_table.time_key = time_dim.time_key " \
        "GROUP BY CUBE(time_dim.year)"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [(None, Decimal('105401435.75')),
#  (Decimal('2021'), Decimal('883772.25')),
#  (Decimal('2019'), Decimal('14949510.25')),
#  (Decimal('2018'), Decimal('15108197.25')),
#  (Decimal('2016'), Decimal('14976508.25')),
#  (Decimal('2014'), Decimal('14334731.25')),
#  (Decimal('2015'), Decimal('15095720.25')),
#  (Decimal('2017'), Decimal('15015806.00')),
#  (Decimal('2020'), Decimal('15037190.25'))]

# %%
df_year = pd.DataFrame(list(records), columns=['year', 'total_sales_price'])
df_year['total_sales_price'] = df_year['total_sales_price'].astype('int64')
df_year.drop([0],axis=0,inplace=True)
df_year
# Out:
#    year  total_sales_price
# 1  2021             883772
# 2  2019           14949510
# 3  2018           15108197
# 4  2016           14976508
# 5  2014           14334731
# 6  2015           15095720
# 7  2017           15015806
# 8  2020           15037190

# %%
df_year.dtypes
# Out:
# year                 object
# total_sales_price     int64
# dtype: object

# %%
x= df_year['year'][:5]
y = np.array(df_year['total_sales_price'][:5])
plt.plot(x,y, linestyle = 'solid',color = 'r')
plt.title("Year Wise Total Sales Price")
plt.xlabel("Years")
plt.ylabel("Total Sales Price")
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.bar(df_year["year"],df_year["total_sales_price"])
 
# Show Plot
plt.show()

# %% [markdown]
# ### Total_sale_price By month Wise

# %%
con = PostgresConnection().getConnection()

cur = con.cursor()
select_stmt = "SELECT  tim.month, SUM(t.total_price) total_sales_price " \
        "FROM ecom_schema.fact_table t " \
        "JOIN ecom_schema.store_dim s on s.store_key = t.store_key " \
        "JOIN ecom_schema.time_dim tim on tim.time_key = t.time_key " \
        "GROUP BY CUBE(tim.month)" \
        "ORDER BY tim.month;"  # Ascending order
cur.execute(select_stmt)
records = cur.fetchall()
df = pd.DataFrame(list(records), columns=['months', 'total_sales_price'])
df
# Out:
# successfully connected to database
#    months total_sales_price
# 0       1        9042244.00
# 1       2        8073877.50
# 2       3        8939152.00
# 3       4        8504634.75
# 4       5        9078002.50
# 5       6        8556853.00
# 6       7        9046580.00
# 7       8        8929475.25
# 8       9        8724326.50
# 9      10        8902783.75
# 10     11        8680026.00
# 11     12        8923480.50
# 12   None      105401435.75

# %%
df.drop([12],axis=0,inplace=True)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="months", y="total_sales_price", data=df)

# %%
fig = plt.figure(figsize =(10, 7))
plt.bar(df["months"],df["total_sales_price"])
 
# Show Plot
plt.show()

# %%
df.dtypes
# Out:
# months               object
# total_sales_price    object
# dtype: object

# %%
df['total_sales_price'] = df['total_sales_price'].astype('float64')

# %%
plot = df.plot.pie(y='total_sales_price', figsize=(5, 5))

# %% [markdown]
# ### Q2: Find the customer/bank/transaction(cash/online) wise total_sale_price joining fact table and respective dimension table

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

query = "SELECT t.bank_name, sum(f.total_price) " \
        "From ecom_schema.fact_table f " \
        "JOIN ecom_schema.trans_dim t on t.payment_key=f.payment_key " \
        "GROUP BY CUBE (t.bank_name)" \ 
        "ORDER by sum (f.total_price)"
cur.execute(query)
result = cur.fetchall()
result
pd_data = pd.DataFrame(list(result), columns=['Bank', 'Sales'])
pd_data['Sales'] = pd_data['Sales'].astype('float64')
pd_data = pd_data.dropna()
fig = pd_data.plot.barh(x='Bank', y='Sales', figsize=(15,10), rot=0)
# Out:
#   Input In [53]
#     "GROUP BY CUBE (t.bank_name)" \
#                                     ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# ### Q3: Total sales in Barisal

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.district, SUM(t.total_price) Total_Sales " \
        "FROM ecom_schema.fact_table t " \
        "JOIN ecom_schema.store_dim s on s.store_key = t.store_key " \
        "WHERE s.district = 'BARISAL' " \
        "GROUP BY CUBE (s.district)"
cur.execute(select_stmt)
records = cur.fetchall()
df = pd.DataFrame(list(records), columns=['month', 'total_sales_price'])
df.head(10)
# Out:
# successfully connected to database
#      month total_sales_price
# 0  BARISAL        2897237.75
# 1     None        2897237.75

# %% [markdown]
# ### Q4: Total sales in 2015

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT tim.year, SUM(t.total_price) Total_Sales " \
        "FROM ecom_schema.fact_table t " \
        "JOIN ecom_schema.time_dim tim ON t.time_key = tim.time_key " \
        "WHERE tim.year = 2015 " \
        "GROUP BY CUBE (tim.year)"
cur.execute(select_stmt)
records = cur.fetchall()
df = pd.DataFrame(list(records), columns=['month', 'total_sales_price'])
df.head(10)
# Out:
# successfully connected to database
#   month total_sales_price
# 0  2015       15095720.25
# 1  None       15095720.25

# %% [markdown]
# ### Q5: Total sales of Barisal in 2015 using ROLLUP

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT tim.year, s.district, SUM(t.total_price) Total_Sales " \
        "FROM ecom_schema.fact_table t " \
        "JOIN ecom_schema.store_dim s on s.store_key = t.store_key " \
        "JOIN ecom_schema.time_dim tim ON t.time_key = tim.time_key " \
        "WHERE s.district = 'BARISAL' and tim.year = 2015 " \
        "GROUP BY ROLLUP (s.district, tim.year)"
cur.execute(select_stmt)
records = cur.fetchall()
df = pd.DataFrame(list(records), columns=['year','district', 'total_sales_price'])
df.drop([1,2],axis=0,inplace=True)
df
# Out:
# successfully connected to database
#    year district total_sales_price
# 0  2015  BARISAL         415748.75

# %% [markdown]
# ### Q6: For each store(item supplier), what are the top three products offered that are most often purchased?

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT tim.year, s.district, SUM(t.total_price) Total_Sales " \
        "FROM ecom_schema.fact_table t " \
        "JOIN ecom_schema.store_dim s on s.store_key = t.store_key " \
        "JOIN ecom_schema.time_dim tim ON t.time_key = tim.time_key " \
        "WHERE s.district = 'BARISAL' and tim.year = 2015 " \
        "GROUP BY ROLLUP (s.district, tim.year)"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [(Decimal('2015'), 'BARISAL', Decimal('415748.75')),
#  (None, 'BARISAL', Decimal('415748.75')),
#  (None, None, Decimal('415748.75'))]

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.store_key, i.item_name, SUM(t.quantity) total_quantity " \
        "From ecom_schema.fact_table t " \
        "JOIN ecom_schema.store_dim s on s.store_key=t.store_key " \
        "JOIN ecom_schema.item_dim i on i.item_key=t.item_key " \
        "GROUP BY CUBE(s.store_key,i.item_name) " 
        
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('S0001', '100% Juice Box Variety 6.75 oz ', Decimal('10')),
#  ('S0001', 'A&W Root Beer - 12 oz cans', Decimal('60')),
#  ('S0001', 'A&W Root Beer Diet - 12 oz cans', Decimal('8')),
#  ('S0001', 'Advil 2 pill packets', Decimal('28')),
#  ('S0001', 'All Purpose Cleaner 409 Spray', Decimal('46')),
#  ('S0001', 'Altoids Small Packs Variety', Decimal('13')),
#  ('S0001', 'Apple Sauce Variety GoGO Squeeze 3.2oz', Decimal('37')),
#  ('S0001', 'AquaFina Purified Drinking Water 16oz', Decimal('39')),
#  ('S0001', 'Austin Cookie Cracker Variety', Decimal('10')),
#  ('S0001', 'Austin Toasty Crackers w/ PBtr', Decimal('22')),
#  ('S0001', 'Baked Chips Variety Mix Frito', Decimal('50')),
#  ('S0001', "Barq's Root Beer - 12 oz cans", Decimal('43')),
#  ('S0001', 'Belvita Hard Biscuits Blueberry', Decimal('11')),
#  ('S0001', 'Belvita Hard Biscuits Cinnamon', Decimal('24')),
#  ('S0001', 'Belvita Protein Oats Soft Biscuit', Decimal('50')),
#  ('S0001', 'Blue Diamond Almonds Rstd, Sltd', Decimal('13')),
#  ('S0001', 'Bounty Paper Towels Select a Size ', Decimal('16')),
#  ('S0001', 'Breath Savers Peppermints 12/roll ', Decimal('28')),
#  ('S0001', 'Brisk Lemon Iced Tea - 12 oz cans', Decimal('30')),
#  ('S0001', 'Cascade Gel Packs Dishwasher', Decimal('33')),
#  ('S0001', 'Cascade Gel w/ Dawn Dishwasher', Decimal('22')),
#  ('S0001', 'Charmin Ultra Bath Tissue', Decimal('25')),
#  ('S0001', 'Cheese and Peanut Butter Crackers', Decimal('45')),
#  ('S0001', "Cheetos Flamin' Hot 1 oz", Decimal('10')),
#  ('S0001', 'Cheez It Original Crackers 1.5oz', Decimal('30')),
#  ('S0001', 'Cheez It White Cheddar 1.5 oz', Decimal('63')),
#  ('S0001', 'Cherry Coke 12oz', Decimal('54')),
#  ('S0001', 'Cherry Coke Zero 12 pack', Decimal('19')),
#  ('S0001', 'Chewy Granola Variety Bars Quaker', Decimal('28')),
#  ('S0001', 'Chex Mix Original', Decimal('38')),
#  ('S0001', 'Chinet Comfort Hot Cups with Lids 16oz', Decimal('18')),
#  ('S0001', 'Chobani Greek Yogurt Variety Pack ', Decimal('41')),
#  ('S0001', 'Clear Plastic 12 oz Cups', Decimal('35')),
#  ('S0001', 'Clear Plastic Cups 9oz', Decimal('39')),
#  ('S0001', 'Cliff Builders Protein Bar Variety Pack', Decimal('40')),
#  ('S0001', 'Cliff Energy Bars Variety Pack', Decimal('17')),
#  ('S0001', 'Clorox Disinfecting Wipes ', Decimal('44')),
#  ('S0001', 'Coffee-Mate French Vanilla Cold', Decimal('47')),
#  ('S0001', 'Coffee-Mate Original Flavor Cold', Decimal('44')),
#  ('S0001', 'Coffee-mate Original Powdered Creamer', Decimal('26')),
#  ('S0001', 'Coke Classic 12 oz cans', Decimal('46')),
#  ('S0001', 'Coke Zero Sugar 12 oz cans', Decimal('47')),
#  ('S0001', 'Community Coffee Dark Roast', Decimal('17')),
#  ('S0001', 'Crunchy Granola Bars Oats & Honey', Decimal('50')),
#  ('S0001', 'Dark Chocolate Mint Patties', Decimal('60')),
#  ('S0001', 'Dasani Bottled Water 16.9 oz', Decimal('20')),
#  ('S0001', 'Dawn Ultra Dish Detergent, Original Scent ', Decimal('6')),
#  ('S0001', 'Deluxe Mixed Nuts with Seasalt', Decimal('13')),
#  ('S0001', 'Detour Lower Sugar Protein Bar', Decimal('18')),
#  ('S0001', 'Dial Anti-bacterial  Foam 7.5oz', Decimal('50')),
#  ('S0001', 'Diet Coke - 12 oz cans', Decimal('40')),
#  ('S0001', 'Diet Coke Caffeine Free 12oz cans', Decimal('51')),
#  ('S0001', 'Diet Dr. Pepper - 12 oz cans', Decimal('45')),
#  ('S0001', 'Diet Fuze Iced Tea', Decimal('21')),
#  ('S0001', 'Diet Gingerale 12 oz cans', Decimal('40')),
#  ('S0001', 'Diet Mountain Dew 12oz cans', Decimal('24')),
#  ('S0001', 'Diet Pepsi - 12 oz cans', Decimal('9')),
#  ('S0001', 'Dixie Perfecttouch Paper Cups 12oz', Decimal('61')),
#  ('S0001', 'Dole Fruit in Gel Cups 4.3 oz', Decimal('34')),
#  ('S0001', 'Doritos Nacho Cheese 1 oz', Decimal('29')),
#  ('S0001', 'Double Bubble Variety Tub', Decimal('32')),
#  ('S0001', 'Dr. Pepper - 12 oz cans', Decimal('39')),
#  ('S0001', 'Dunkin Donuts Original Blend', Decimal('29')),
#  ('S0001', 'Equal Sweetener', Decimal('15')),
#  ('S0001', 'Extra Variety Packs Sugar Free', Decimal('8')),
#  ('S0001', 'Famous Amos Cookies ', Decimal('32')),
#  ('S0001', 'Fiber One 90 Calorie Fudge Brownies', Decimal('19')),
#  ('S0001', 'Fiber One Bars Oats and Chocolate', Decimal('26')),
#  ('S0001', 'Flamin Hot Chip Mix 1oz', Decimal('54')),
#  ('S0001', 'Foam Coffee Cups - 08 ounce', Decimal('39')),
#  ('S0001', 'Foam Coffee Cups - 12 ounce', Decimal('25')),
#  ('S0001', 'Foam Coffee Cups - 16 ounce', Decimal('24')),
#  ('S0001', 'Foam Coffee Cups - 20 ounce', Decimal('35')),
#  ('S0001', 'Folgers 100% Colombian Coffee', Decimal('48')),
#  ('S0001', 'Folgers Classic Roast Coffee', Decimal('42')),
#  ('S0001', 'ForceFlex Trash Bags 13 Gal ', Decimal('19')),
#  ('S0001', 'French Vanilla International Delight', Decimal('47')),
#  ('S0001', 'Fresca Black Cherry - 12 oz cans', Decimal('26')),
#  ('S0001', 'Fresca Original - 12 oz cans', Decimal('24')),
#  ('S0001', 'Fresca Peach Citrus - 12 oz cans', Decimal('6')),
#  ('S0001', 'Frito Big Grab Variety 1.5-2.0 oz', Decimal('53')),
#  ('S0001', 'Frito Bold Flavors Variety', Decimal('56')),
#  ('S0001', 'Frito BOLD Flavors Variety Pack', Decimal('54')),
#  ('S0001', 'Frito Classic Mix Variety', Decimal('21')),
#  ('S0001', 'Frito Fiesta Flavors Variety', Decimal('41')),
#  ('S0001', 'Fuze Iced Tea', Decimal('17')),
#  ('S0001', 'G2 Lo Calorie Variety 20 oz', Decimal('21')),
#  ('S0001', 'Gardettos Snacks', Decimal('30')),
#  ('S0001', 'Gatorade Frost Variety 12 oz', Decimal('30')),
#  ('S0001', 'Gatorade Frost Variety 20 oz ', Decimal('34')),
#  ('S0001', 'Gatorade Lemon Lime 12oz', Decimal('34')),
#  ('S0001', 'Gatorade Liberty Variety 12 oz', Decimal('18')),
#  ('S0001', 'Gatorade Liberty Variety 20 oz ', Decimal('36')),
#  ('S0001', 'Gatorade Original Variety 12 oz', Decimal('18')),
#  ('S0001', 'Gatorade Variety 20 oz ', Decimal('14')),
#  ('S0001', 'Gatorade X-Factor Fierce Variety 20 oz', Decimal('10')),
#  ('S0001', 'Gatorade Zero Variety 20 oz', Decimal('19')),
#  ('S0001', 'Ginger Ale - 12 oz cans', Decimal('31')),
#  ('S0001', 'Go-Gurt Low Fat Yogurt, Strwbry & Berry ', Decimal('51')),
#  ('S0001', 'Goldfish Pepperidge Farm Cheddar 1.5oz ', Decimal('10')),
#  ('S0001', 'Goldfish Variety Bags, cheddar, pretzels', Decimal('20')),
#  ('S0001', "Half & Half -Land o Lakes Mini Moo's", Decimal('32')),
#  ('S0001', 'Hand Sanitizer Refill Pump', Decimal('12')),
#  ('S0001', 'Hawaiian Punch - 12 oz cans', Decimal('48')),
#  ('S0001', 'Hazelnut International Delight', Decimal('29')),
#  ('S0001', "Hefty Cmprtmnt Plates Foam 10'", Decimal('31')),
#  ('S0001', 'Hefty Supreme Foam Bowls 12oz', Decimal('38')),
#  ('S0001', 'Hefty Supreme Foam Plates 6 inch', Decimal('78')),
#  ('S0001', 'Hefty Supreme Foam Plates 9 inch', Decimal('15')),
#  ('S0001', 'Hershey Chocoalte Minatures Assort.', Decimal('60')),
#  ('S0001', 'Hershey Factory Favorites Mix', Decimal('21')),
#  ('S0001', 'Hershey Kisses ', Decimal('18')),
#  ('S0001', 'Hershey Nuggets', Decimal('48')),
#  ('S0001', 'Honey Packets  ', Decimal('38')),
#  ('S0001', 'Ice Breaker Mints Sugar Free ', Decimal('34')),
#  ('S0001', 'Jolly Ranchers Variety Hard Candy', Decimal('42')),
#  ('S0001', 'K Cups - Green Tea', Decimal('28')),
#  ('S0001', 'K Cups - McCafe Premium Roast', Decimal('34')),
#  ('S0001', "K Cups – Starbuck's Pike Place", Decimal('23')),
#  ('S0001', 'K Cups Daily Chef Columbian Supremo', Decimal('54')),
#  ('S0001', 'K Cups Dunkin Donuts Medium Roast', Decimal('29')),
#  ('S0001', 'K Cups Folgers Lively Columbian', Decimal('20')),
#  ('S0001', 'K Cups Hot Cocoa', Decimal('42')),
#  ('S0001', 'K Cups Original Donut Shop Med. Roast', Decimal('39')),
#  ('S0001', 'Keebler Cookie & Cracker Variety', Decimal('55')),
#  ('S0001', "Kellogg's Cereals Assortment Pack ", Decimal('21')),
#  ('S0001', "Kellogg's Fruity Snacks", Decimal('20')),
#  ('S0001', 'Kellogg Fun Mix Cheez it, Prngls, Fam Amos', Decimal('58')),
#  ('S0001', 'Kind  Bars Mini Variety Pack 0.7 oz ', Decimal('24')),
#  ('S0001', 'Kind  Bars Variety Pack 1.4 oz ', Decimal('10')),
#  ('S0001', 'Kleenex Tissue Rectangle Boxes 160/box', Decimal('9')),
#  ('S0001', 'Kleenex Tissue Square Boxes 75/box', Decimal('49')),
#  ('S0001', 'La Croix Sparkling Berry 12 ozv', Decimal('47')),
#  ('S0001', 'La Croix Sparkling Coconut 12 oz', Decimal('43')),
#  ('S0001', 'La Croix Sparkling Cran-Raspberry 12 oz', Decimal('12')),
#  ('S0001', 'La Croix Sparkling Grapefruit 12 oz', Decimal('44')),
#  ('S0001', 'La Croix Sparkling Lemon 12 oz', Decimal('27')),
#  ('S0001', 'La Croix Sparkling Lime 12 oz', Decimal('47')),
#  ('S0001', 'La Croix Sparkling Orange 12 oz', Decimal('33')),
#  ('S0001', 'La Croix Sparkling Pure 12 oz', Decimal('31')),
#  ('S0001', 'Lance Variety Cracker Packs ', Decimal('37')),
#  ('S0001', 'Large Trash Bags Black 33 gal', Decimal('59')),
#  ('S0001', 'Lunchables Variety Pack Oscar Meyer', Decimal('46')),
#  ('S0001', 'Lysol Disinfectant Spray 19 oz', Decimal('12')),
#  ('S0001', 'Lysol Wipes 100 ct', Decimal('38')),
#  ('S0001', 'M&M Peanut Butter 1.6 oz', Decimal('9')),
#  ('S0001', 'M&M Peanut Candy 1.7 oz', Decimal('45')),
#  ('S0001', 'M&M Variety Full Size Bags', Decimal('20')),
#  ('S0001', 'Mars Chocolate Favorites', Decimal('42')),
#  ('S0001', 'Mars Mini Mix', Decimal('21')),
#  ('S0001', 'Miss Vickies Chips', Decimal('17')),
#  ('S0001', 'Monster Java 15 oz', Decimal('22')),
#  ('S0001', 'Monster Lo-Carb 16 oz', Decimal('37')),
#  ('S0001', 'Monster Original Green 16 oz', Decimal('17')),
#  ('S0001', 'Monster Zero Ultra 16 oz', Decimal('7')),
#  ('S0001', 'Monster Zero Ultra Variety 16 oz', Decimal('26')),
#  ('S0001', 'Mountain Dew - 12 oz cans', Decimal('40')),
#  ('S0001', 'Muscle Milk Protein Shake Choc. 11oz', Decimal('50')),
#  ('S0001', 'Muscle Milk Protein Shake Strbry. 11oz', Decimal('67')),
#  ('S0001', 'Muscle Milk Protein Shake Van. 11oz', Decimal('90')),
#  ('S0001', 'Nabisco Classic Mix ccooki, cracker', Decimal('8')),
#  ('S0001', 'Nabisco Cookie Variety Pk Oreo/ChocChip', Decimal('26')),
#  ('S0001', 'Napkins Square Lunch', Decimal('14')),
#  ('S0001', 'Nat.Valley PeanutButter Protein Bars', Decimal('35')),
#  ('S0001', 'Nature Valley Biscuit Sandwich Variety Pack ', Decimal('35')),
#  ('S0001', 'Nature Valley Chewy Trail Mix Bars', Decimal('25')),
#  ('S0001', 'Nature Valley Soft Oatmeal Squares   ', Decimal('21')),
#  ('S0001', 'Nature Valley Sweet/Salty Almond Bars      ', Decimal('59')),
#  ('S0001', 'Nature Valley Sweet/Salty Peanut Bars      ', Decimal('39')),
#  ('S0001', 'Nestle Purelife 16oz ', Decimal('52')),
#  ('S0001', 'Njoy Creamer Canister 16 oz', Decimal('37')),
#  ('S0001', 'Njoy Creamer Packs', Decimal('10')),
#  ('S0001', 'Njoy Sugar Canister 22 oz', Decimal('69')),
#  ('S0001', 'Ocean Spray Cranberry Juice Cocktail 15oz ', Decimal('50')),
#  ('S0001', 'Ozarka Spring Water 16.9 oz bottles', Decimal('26')),
#  ('S0001', 'Ozarka Spring Water 20 oz', Decimal('46')),
#  ('S0001', 'Ozarka Spring Water Mini 8oz', Decimal('9')),
#  ('S0001', 'Paper Bowls 20 oz Ultra Strong', Decimal('23')),
#  ('S0001', 'Paper Plate 10 inch Ultra Strong', Decimal('37')),
#  ('S0001', 'Paper Plates 7 inch  Ultra Strong', Decimal('48')),
#  ('S0001', 'Paper Plates 8.5 inch Ultra Strong', Decimal('26')),
#  ('S0001', 'Peanutbutter Filled Pretzels', Decimal('32')),
#  ('S0001', 'Peppermints Hard Candy', Decimal('15')),
#  ('S0001', 'Pepsi - 12 oz cans', Decimal('92')),
#  ('S0001', 'Perrier Flavors Sparkling Water 16.9oz', Decimal('5')),
#  ('S0001', 'Perrier Sparkling Water glass 11oz', Decimal('31')),
#  ('S0001', 'Perrier Sparkling Water plastic 16.9oz', Decimal('42')),
#  ('S0001', 'Planters Nut-trition 1.5 oz ', Decimal('42')),
#  ('S0001', 'Planters Nut Variety Packs', Decimal('19')),
#  ('S0001', 'Plastic Forks White Heavyweight', Decimal('23')),
#  ('S0001', 'Plastic Knives White  Heavyweight', Decimal('20')),
#  ('S0001', 'Plastic Spoons White  Heavyweight', Decimal('29')),
#  ('S0001', 'POM 2 ply paper towels', Decimal('23')),
#  ('S0001', 'Pop-Tarts, Brown Sugar Cinnamon ', Decimal('34')),
#  ('S0001', 'Pop-Tarts, Frosted Strawberry', Decimal('26')),
#  ('S0001', 'Pop Chips Variety bags', Decimal('34')),
#  ('S0001', 'Premier Protein Shake Choc. 11oz', Decimal('17')),
#  ('S0001', 'Pringles Snak Stacks Variety', Decimal('36')),
#  ('S0001', 'Propel Zero Variety 20 oz', Decimal('44')),
#  ('S0001', 'Pure Leaf Sweet Tea 8.5oz', Decimal('28')),
#  ('S0001', 'Pure Leaf Unsweetened Tea 18.5oz', Decimal('15')),
#  ('S0001', 'Pure White Sugar Packets', Decimal('16')),
#  ('S0001', 'Quaker Instant Oatmeal Maple Brn Sugar', Decimal('57')),
#  ('S0001', 'Quaker Instant Oatmeal Variety ', Decimal('50')),
#  ('S0001', 'Red Bull 12oz', Decimal('18')),
#  ('S0001', 'Red Bull 16oz', Decimal('49')),
#  ('S0001', 'Red Bull 8.4 oz', Decimal('38')),
#  ('S0001', 'Red Bull Sugar Free 8.4 oz', Decimal('33')),
#  ('S0001', 'Red Plastic Cups 18oz', Decimal('21')),
#  ('S0001', "Reese's Peanutbutter Cups 2/pk", Decimal('4')),
#  ('S0001', "Reese's Pieces Peanutbutter Candy", Decimal('51')),
#  ('S0001', 'San Pelligrino 16oz Plastic ', Decimal('13')),
#  ('S0001', 'Sargento Bal. Breaks (fruit, nut, cheese)', Decimal('62')),
#  ('S0001', 'Sargento String Cheese 0.75oz', Decimal('35')),
#  ('S0001', 'Seven Up - 12 oz cans', Decimal('34')),
#  ('S0001', 'Snapple Variety Pack 20oz', Decimal('25')),
#  ('S0001', 'Snickers Bars 1.8oz', Decimal('15')),
#  ('S0001', 'Snyders Pretzels Minis', Decimal('32')),
#  ('S0001', 'Sobe Zero Lifewater Variety 20 oz', Decimal('41')),
#  ('S0001', 'Splenda Sweetener', Decimal('27')),
#  ('S0001', 'Sprite - 12 oz cans', Decimal('64')),
#  ('S0001', 'Sprite Zero - 12 pack', Decimal('26')),
#  ('S0001', 'Spunkmeyer Muffin Variety', Decimal('17')),
#  ('S0001', "Starbuck's Pike Place", Decimal('15')),
#  ('S0001', 'Stirrers Coffee Stirs 7inch', Decimal('17')),
#  ('S0001', 'Strong Everyday Napkins', Decimal('33')),
#  ('S0001', 'Sugar in the Raw Packets', Decimal('35')),
#  ('S0001', 'Sun Chips Variety Pack', Decimal('29')),
#  ('S0001', 'Sunkist Orange - 12 oz cans', Decimal('18')),
#  ('S0001', 'Sweet N Low Sweetener', Decimal('12')),
#  ('S0001', 'Swiss Miss Hot Cocoa Mix 1 oz', Decimal('36')),
#  ('S0001', 'Tejava Unsweetened Black Tea 16.9oz', Decimal('4')),
#  ('S0001', 'Tootsie Roll Midgets', Decimal('28')),
#  ('S0001', 'Topo Chico 12 oz glass', Decimal('16')),
#  ('S0001', 'Topo Chico 20oz plastic', Decimal('15')),
#  ('S0001', 'Trident Original Flavor 18/pk', Decimal('37')),
#  ('S0001', 'Tropicana Apple Juice 10 oz 100% ', Decimal('20')),
#  ('S0001', 'Tropicana Orange Juice 10 oz 100% ', Decimal('25')),
#  ('S0001', 'Truvia Natural Sweetener', Decimal('15')),
#  ('S0001', 'Tylenol Extra Strength 2 pill packets', Decimal('24')),
#  ('S0001', 'Unsalted Premium Blend Nuts', Decimal('28')),
#  ('S0001', 'V-8 Splash Variety 20 oz', Decimal('27')),
#  ('S0001', 'V8 100% Vegetable Juice 11oz cans', Decimal('45')),
#  ('S0001', 'Veggie Chips 1oz ', Decimal('29')),
#  ('S0001', 'Vita Coconut Water 10oz ', Decimal('68')),
#  ('S0001', 'Waterloo Sparkling Blackcherry 12oz', Decimal('10')),
#  ('S0001', 'Waterloo Sparkling Grapefruit 12oz', Decimal('37')),
#  ('S0001', 'Waterloo Sparkling Lemon 12oz', Decimal('17')),
#  ('S0001', 'Waterloo Sparkling Lime 12oz', Decimal('70')),
#  ('S0001', 'Waterloo Sparkling Mango 12oz', Decimal('20')),
#  ('S0001', 'Waterloo Sparkling Original 12oz', Decimal('44')),
#  ('S0001', 'Waterloo Sparkling Watermelon 12oz', Decimal('13')),
#  ('S0001', "Welch's 100% Juice Variety10 oz", Decimal('43')),
#  ('S0001', 'Wint O Green LifeSavers Sugar Free', Decimal('52')),
#  ('S0001', 'Wonderful Pistachios (in shell)', Decimal('9')),
#  ('S0001', 'Yoplait Original Yogurt Variety Pack ', Decimal('30')),
#  ('S0001', 'Zoo Animal Cookies/Crackers', Decimal('29')),
#  ('S0001', None, Decimal('8169')),
#  ('S0002', '100% Juice Box Variety 6.75 oz ', Decimal('23')),
#  ('S0002', 'A&W Root Beer - 12 oz cans', Decimal('45')),
#  ('S0002', 'A&W Root Beer Diet - 12 oz cans', Decimal('2')),
#  ('S0002', 'Advil 2 pill packets', Decimal('55')),
#  ('S0002', 'All Purpose Cleaner 409 Spray', Decimal('35')),
#  ('S0002', 'Altoids Small Packs Variety', Decimal('80')),
#  ('S0002', 'Apple Sauce Variety GoGO Squeeze 3.2oz', Decimal('36')),
#  ('S0002', 'AquaFina Purified Drinking Water 16oz', Decimal('78')),
#  ('S0002', 'Austin Cookie Cracker Variety', Decimal('29')),
#  ('S0002', 'Austin Toasty Crackers w/ PBtr', Decimal('22')),
#  ('S0002', 'Baked Chips Variety Mix Frito', Decimal('19')),
#  ('S0002', "Barq's Root Beer - 12 oz cans", Decimal('17')),
#  ('S0002', 'Belvita Hard Biscuits Blueberry', Decimal('47')),
#  ('S0002', 'Belvita Hard Biscuits Cinnamon', Decimal('55')),
#  ('S0002', 'Belvita Protein Oats Soft Biscuit', Decimal('67')),
#  ('S0002', 'Blue Diamond Almonds Rstd, Sltd', Decimal('54')),
#  ('S0002', 'Bounty Paper Towels Select a Size ', Decimal('35')),
#  ('S0002', 'Breath Savers Peppermints 12/roll ', Decimal('31')),
#  ('S0002', 'Brisk Lemon Iced Tea - 12 oz cans', Decimal('35')),
#  ('S0002', 'Cascade Gel Packs Dishwasher', Decimal('34')),
#  ('S0002', 'Cascade Gel w/ Dawn Dishwasher', Decimal('15')),
#  ('S0002', 'Charmin Ultra Bath Tissue', Decimal('48')),
#  ('S0002', 'Cheese and Peanut Butter Crackers', Decimal('25')),
#  ('S0002', "Cheetos Flamin' Hot 1 oz", Decimal('26')),
#  ('S0002', 'Cheez It Original Crackers 1.5oz', Decimal('58')),
#  ('S0002', 'Cheez It White Cheddar 1.5 oz', Decimal('19')),
#  ('S0002', 'Cherry Coke 12oz', Decimal('13')),
#  ('S0002', 'Cherry Coke Zero 12 pack', Decimal('18')),
#  ('S0002', 'Chewy Granola Variety Bars Quaker', Decimal('48')),
#  ('S0002', 'Chex Mix Original', Decimal('22')),
#  ('S0002', 'Chinet Comfort Hot Cups with Lids 16oz', Decimal('46')),
#  ('S0002', 'Chobani Greek Yogurt Variety Pack ', Decimal('11')),
#  ('S0002', 'Clear Plastic 12 oz Cups', Decimal('42')),
#  ('S0002', 'Clear Plastic Cups 9oz', Decimal('16')),
#  ('S0002', 'Cliff Builders Protein Bar Variety Pack', Decimal('42')),
#  ('S0002', 'Cliff Energy Bars Variety Pack', Decimal('59')),
#  ('S0002', 'Clorox Bleach Large Jugs', Decimal('25')),
#  ('S0002', 'Clorox Disinfecting Wipes ', Decimal('12')),
#  ('S0002', 'Coffee-Mate French Vanilla Cold', Decimal('51')),
#  ('S0002', 'Coffee-Mate Original Flavor Cold', Decimal('47')),
#  ('S0002', 'Coffee-mate Original Powdered Creamer', Decimal('31')),
#  ('S0002', 'Coke Classic 12 oz cans', Decimal('66')),
#  ('S0002', 'Coke Zero Sugar 12 oz cans', Decimal('57')),
#  ('S0002', 'Community Coffee Dark Roast', Decimal('53')),
#  ('S0002', 'Crunchy Granola Bars Oats & Honey', Decimal('57')),
#  ('S0002', 'Dark Chocolate Mint Patties', Decimal('31')),
#  ('S0002', 'Dasani Bottled Water 16.9 oz', Decimal('27')),
#  ('S0002', 'Dawn Ultra Dish Detergent, Original Scent ', Decimal('56')),
#  ('S0002', 'Deluxe Mixed Nuts with Seasalt', Decimal('9')),
#  ('S0002', 'Detour Lower Sugar Protein Bar', Decimal('12')),
#  ('S0002', 'Dial Anti-bacterial  Foam 7.5oz', Decimal('44')),
#  ('S0002', 'Diet Coke - 12 oz cans', Decimal('41')),
#  ('S0002', 'Diet Coke Caffeine Free 12oz cans', Decimal('53')),
#  ('S0002', 'Diet Dr. Pepper - 12 oz cans', Decimal('17')),
#  ('S0002', 'Diet Fuze Iced Tea', Decimal('7')),
#  ('S0002', 'Diet Gingerale 12 oz cans', Decimal('25')),
#  ('S0002', 'Diet Mountain Dew 12oz cans', Decimal('18')),
#  ('S0002', 'Diet Pepsi - 12 oz cans', Decimal('24')),
#  ('S0002', 'Dixie Perfecttouch Paper Cups 12oz', Decimal('38')),
#  ('S0002', 'Dole Fruit in Gel Cups 4.3 oz', Decimal('17')),
#  ('S0002', 'Doritos Nacho Cheese 1 oz', Decimal('12')),
#  ('S0002', 'Double Bubble Variety Tub', Decimal('20')),
#  ('S0002', 'Dr. Pepper - 12 oz cans', Decimal('48')),
#  ('S0002', 'Dunkin Donuts Original Blend', Decimal('25')),
#  ('S0002', 'Equal Sweetener', Decimal('19')),
#  ('S0002', 'Extra Variety Packs Sugar Free', Decimal('49')),
#  ('S0002', 'Famous Amos Cookies ', Decimal('43')),
#  ('S0002', 'Fiber One 90 Calorie Fudge Brownies', Decimal('40')),
#  ('S0002', 'Fiber One Bars Oats and Chocolate', Decimal('32')),
#  ('S0002', 'Flamin Hot Chip Mix 1oz', Decimal('10')),
#  ('S0002', 'Foam Coffee Cups - 08 ounce', Decimal('37')),
#  ('S0002', 'Foam Coffee Cups - 12 ounce', Decimal('36')),
#  ('S0002', 'Foam Coffee Cups - 16 ounce', Decimal('45')),
#  ('S0002', 'Foam Coffee Cups - 20 ounce', Decimal('39')),
#  ('S0002', 'Folgers 100% Colombian Coffee', Decimal('18')),
#  ('S0002', 'Folgers Classic Roast Coffee', Decimal('19')),
#  ('S0002', 'ForceFlex Trash Bags 13 Gal ', Decimal('30')),
#  ('S0002', 'French Vanilla International Delight', Decimal('29')),
#  ('S0002', 'Fresca Black Cherry - 12 oz cans', Decimal('71')),
#  ('S0002', 'Fresca Original - 12 oz cans', Decimal('13')),
#  ('S0002', 'Fresca Peach Citrus - 12 oz cans', Decimal('10')),
#  ('S0002', 'Frito Big Grab Variety 1.5-2.0 oz', Decimal('34')),
#  ('S0002', 'Frito Bold Flavors Variety', Decimal('10')),
#  ('S0002', 'Frito BOLD Flavors Variety Pack', Decimal('41')),
#  ('S0002', 'Frito Classic Mix Variety', Decimal('48')),
#  ('S0002', 'Frito Fiesta Flavors Variety', Decimal('25')),
#  ('S0002', 'Fuze Iced Tea', Decimal('44')),
#  ('S0002', 'G2 Lo Calorie Variety 20 oz', Decimal('25')),
#  ('S0002', 'Gardettos Snacks', Decimal('47')),
#  ('S0002', 'Gatorade Frost Variety 12 oz', Decimal('9')),
#  ('S0002', 'Gatorade Frost Variety 20 oz ', Decimal('58')),
#  ('S0002', 'Gatorade Lemon Lime 12oz', Decimal('19')),
#  ('S0002', 'Gatorade Liberty Variety 12 oz', Decimal('12')),
#  ('S0002', 'Gatorade Liberty Variety 20 oz ', Decimal('36')),
#  ('S0002', 'Gatorade Original Variety 12 oz', Decimal('24')),
#  ('S0002', 'Gatorade Variety 20 oz ', Decimal('52')),
#  ('S0002', 'Gatorade X-Factor Fierce Variety 20 oz', Decimal('32')),
#  ('S0002', 'Gatorade Zero Variety 20 oz', Decimal('38')),
#  ('S0002', 'Ginger Ale - 12 oz cans', Decimal('13')),
#  ('S0002', 'Go-Gurt Low Fat Yogurt, Strwbry & Berry ', Decimal('13')),
#  ('S0002', 'Goldfish Pepperidge Farm Cheddar 1.5oz ', Decimal('55')),
#  ('S0002', 'Goldfish Variety Bags, cheddar, pretzels', Decimal('19')),
#  ('S0002', "Half & Half -Land o Lakes Mini Moo's", Decimal('19')),
#  ('S0002', 'Hand Sanitizer Refill Pump', Decimal('21')),
#  ('S0002', 'Hawaiian Punch - 12 oz cans', Decimal('30')),
#  ('S0002', 'Hazelnut International Delight', Decimal('34')),
#  ('S0002', "Hefty Cmprtmnt Plates Foam 10'", Decimal('2')),
#  ('S0002', 'Hefty Supreme Foam Bowls 12oz', Decimal('78')),
#  ('S0002', 'Hefty Supreme Foam Plates 6 inch', Decimal('35')),
#  ('S0002', 'Hefty Supreme Foam Plates 9 inch', Decimal('13')),
#  ('S0002', 'Hershey Chocoalte Minatures Assort.', Decimal('32')),
#  ('S0002', 'Hershey Factory Favorites Mix', Decimal('42')),
#  ('S0002', 'Hershey Kisses ', Decimal('14')),
#  ('S0002', 'Hershey Nuggets', Decimal('41')),
#  ('S0002', 'Honey Packets  ', Decimal('22')),
#  ('S0002', 'Ice Breaker Mints Sugar Free ', Decimal('17')),
#  ('S0002', 'Jolly Ranchers Variety Hard Candy', Decimal('37')),
#  ('S0002', 'K Cups - Green Tea', Decimal('50')),
#  ('S0002', 'K Cups - McCafe Premium Roast', Decimal('11')),
#  ('S0002', "K Cups – Starbuck's Pike Place", Decimal('4')),
#  ('S0002', 'K Cups –Organic Breakfast Blend', Decimal('38')),
#  ('S0002', 'K Cups Daily Chef Columbian Supremo', Decimal('27')),
#  ('S0002', 'K Cups Dunkin Donuts Medium Roast', Decimal('36')),
#  ('S0002', 'K Cups Folgers Lively Columbian', Decimal('36')),
#  ('S0002', 'K Cups Hot Cocoa', Decimal('75')),
#  ('S0002', 'K Cups Original Donut Shop Med. Roast', Decimal('24')),
#  ('S0002', 'Keebler Cookie & Cracker Variety', Decimal('29')),
#  ('S0002', "Kellogg's Cereals Assortment Pack ", Decimal('34')),
#  ('S0002', "Kellogg's Fruity Snacks", Decimal('19')),
#  ('S0002', 'Kellogg Fun Mix Cheez it, Prngls, Fam Amos', Decimal('16')),
#  ('S0002', 'Kind  Bars Mini Variety Pack 0.7 oz ', Decimal('45')),
#  ('S0002', 'Kind  Bars Variety Pack 1.4 oz ', Decimal('33')),
#  ('S0002', 'Kleenex Tissue Rectangle Boxes 160/box', Decimal('48')),
#  ('S0002', 'Kleenex Tissue Square Boxes 75/box', Decimal('42')),
#  ('S0002', 'La Croix Sparkling Berry 12 ozv', Decimal('15')),
#  ('S0002', 'La Croix Sparkling Coconut 12 oz', Decimal('28')),
#  ('S0002', 'La Croix Sparkling Cran-Raspberry 12 oz', Decimal('9')),
#  ('S0002', 'La Croix Sparkling Grapefruit 12 oz', Decimal('32')),
#  ('S0002', 'La Croix Sparkling Lemon 12 oz', Decimal('24')),
#  ('S0002', 'La Croix Sparkling Lime 12 oz', Decimal('15')),
#  ('S0002', 'La Croix Sparkling Orange 12 oz', Decimal('19')),
#  ('S0002', 'La Croix Sparkling Pure 12 oz', Decimal('25')),
#  ('S0002', 'Lance Variety Cracker Packs ', Decimal('26')),
#  ('S0002', 'Large Trash Bags Black 33 gal', Decimal('24')),
#  ('S0002', 'Lunchables Variety Pack Oscar Meyer', Decimal('37')),
#  ('S0002', 'Lysol Disinfectant Spray 19 oz', Decimal('51')),
#  ('S0002', 'Lysol Wipes 100 ct', Decimal('17')),
#  ('S0002', 'M&M Peanut Butter 1.6 oz', Decimal('13')),
#  ('S0002', 'M&M Peanut Candy 1.7 oz', Decimal('69')),
#  ('S0002', 'M&M Variety Full Size Bags', Decimal('28')),
#  ('S0002', 'Mars Chocolate Favorites', Decimal('56')),
#  ('S0002', 'Mars Mini Mix', Decimal('36')),
#  ('S0002', 'Miss Vickies Chips', Decimal('22')),
#  ('S0002', 'Monster Java 15 oz', Decimal('52')),
#  ('S0002', 'Monster Lo-Carb 16 oz', Decimal('17')),
#  ('S0002', 'Monster Original Green 16 oz', Decimal('34')),
#  ('S0002', 'Monster Zero Ultra 16 oz', Decimal('25')),
#  ('S0002', 'Monster Zero Ultra Variety 16 oz', Decimal('39')),
#  ('S0002', 'Mountain Dew - 12 oz cans', Decimal('56')),
#  ('S0002', 'Muscle Milk Protein Shake Choc. 11oz', Decimal('39')),
#  ('S0002', 'Muscle Milk Protein Shake Strbry. 11oz', Decimal('22')),
#  ('S0002', 'Muscle Milk Protein Shake Van. 11oz', Decimal('78')),
#  ('S0002', 'Nabisco Classic Mix ccooki, cracker', Decimal('20')),
#  ('S0002', 'Nabisco Cookie Variety Pk Oreo/ChocChip', Decimal('33')),
#  ('S0002', 'Napkins Square Lunch', Decimal('21')),
#  ('S0002', 'Nat.Valley PeanutButter Protein Bars', Decimal('76')),
#  ('S0002', 'Nature Valley Biscuit Sandwich Variety Pack ', Decimal('14')),
#  ('S0002', 'Nature Valley Chewy Trail Mix Bars', Decimal('14')),
#  ('S0002', 'Nature Valley Soft Oatmeal Squares   ', Decimal('52')),
#  ('S0002', 'Nature Valley Sweet/Salty Almond Bars      ', Decimal('18')),
#  ('S0002', 'Nature Valley Sweet/Salty Peanut Bars      ', Decimal('31')),
#  ('S0002', 'Nestle Purelife 16oz ', Decimal('25')),
#  ('S0002', 'Njoy Creamer Canister 16 oz', Decimal('8')),
#  ('S0002', 'Njoy Creamer Packs', Decimal('56')),
#  ('S0002', 'Njoy Sugar Canister 22 oz', Decimal('31')),
#  ('S0002', 'Ocean Spray Cranberry Juice Cocktail 15oz ', Decimal('57')),
#  ('S0002', 'Ozarka Spring Water 16.9 oz bottles', Decimal('34')),
#  ('S0002', 'Ozarka Spring Water 20 oz', Decimal('14')),
#  ('S0002', 'Ozarka Spring Water Mini 8oz', Decimal('24')),
#  ('S0002', 'Paper Bowls 20 oz Ultra Strong', Decimal('27')),
#  ('S0002', 'Paper Plate 10 inch Ultra Strong', Decimal('24')),
#  ('S0002', 'Paper Plates 7 inch  Ultra Strong', Decimal('9')),
#  ('S0002', 'Paper Plates 8.5 inch Ultra Strong', Decimal('14')),
#  ('S0002', 'Peanutbutter Filled Pretzels', Decimal('43')),
#  ('S0002', 'Peppermints Hard Candy', Decimal('50')),
#  ('S0002', 'Pepsi - 12 oz cans', Decimal('64')),
#  ('S0002', 'Perrier Flavors Sparkling Water 16.9oz', Decimal('26')),
#  ('S0002', 'Perrier Sparkling Water glass 11oz', Decimal('24')),
#  ('S0002', 'Perrier Sparkling Water plastic 16.9oz', Decimal('53')),
#  ('S0002', 'Planters Nut-trition 1.5 oz ', Decimal('83')),
#  ('S0002', 'Planters Nut Variety Packs', Decimal('9')),
#  ('S0002', 'Plastic Forks White Heavyweight', Decimal('42')),
#  ('S0002', 'Plastic Knives White  Heavyweight', Decimal('36')),
#  ('S0002', 'Plastic Spoons White  Heavyweight', Decimal('20')),
#  ('S0002', 'POM 2 ply paper towels', Decimal('30')),
#  ('S0002', 'Pop-Tarts, Brown Sugar Cinnamon ', Decimal('12')),
#  ('S0002', 'Pop-Tarts, Frosted Strawberry', Decimal('24')),
#  ('S0002', 'Pop Chips Variety bags', Decimal('37')),
#  ('S0002', 'Premier Protein Shake Choc. 11oz', Decimal('57')),
#  ('S0002', 'Pringles Snak Stacks Variety', Decimal('27')),
#  ('S0002', 'Propel Zero Variety 20 oz', Decimal('18')),
#  ('S0002', 'Pure Leaf Sweet Tea 8.5oz', Decimal('34')),
#  ('S0002', 'Pure Leaf Unsweetened Tea 18.5oz', Decimal('4')),
#  ('S0002', 'Pure White Sugar Packets', Decimal('16')),
#  ('S0002', 'Quaker Instant Oatmeal Maple Brn Sugar', Decimal('37')),
#  ('S0002', 'Quaker Instant Oatmeal Variety ', Decimal('37')),
#  ('S0002', 'Red Bull 12oz', Decimal('16')),
#  ('S0002', 'Red Bull 16oz', Decimal('6')),
#  ('S0002', 'Red Bull 8.4 oz', Decimal('17')),
#  ('S0002', 'Red Bull Sugar Free 8.4 oz', Decimal('62')),
#  ('S0002', 'Red Plastic Cups 18oz', Decimal('35')),
#  ('S0002', "Reese's Peanutbutter Cups 2/pk", Decimal('12')),
#  ('S0002', "Reese's Pieces Peanutbutter Candy", Decimal('48')),
#  ('S0002', 'San Pelligrino 16oz Plastic ', Decimal('70')),
#  ('S0002', 'Sargento Bal. Breaks (fruit, nut, cheese)', Decimal('35')),
#  ('S0002', 'Sargento String Cheese 0.75oz', Decimal('38')),
#  ('S0002', 'Seven Up - 12 oz cans', Decimal('36')),
#  ('S0002', 'Snapple Variety Pack 20oz', Decimal('17')),
#  ('S0002', 'Snickers Bars 1.8oz', Decimal('22')),
#  ('S0002', 'Snyders Pretzels Minis', Decimal('27')),
#  ('S0002', 'Sobe Zero Lifewater Variety 20 oz', Decimal('72')),
#  ('S0002', 'Splenda Sweetener', Decimal('43')),
#  ('S0002', 'Sprite - 12 oz cans', Decimal('46')),
#  ('S0002', 'Sprite Zero - 12 pack', Decimal('60')),
#  ('S0002', 'Spunkmeyer Muffin Variety', Decimal('47')),
#  ('S0002', "Starbuck's Pike Place", Decimal('31')),
#  ('S0002', 'Stirrers Coffee Stirs 7inch', Decimal('8')),
#  ('S0002', 'Strong Everyday Napkins', Decimal('11')),
#  ('S0002', 'Sugar in the Raw Packets', Decimal('21')),
#  ('S0002', 'Sun Chips Variety Pack', Decimal('24')),
#  ('S0002', 'Sunkist Orange - 12 oz cans', Decimal('23')),
#  ('S0002', 'Sweet N Low Sweetener', Decimal('44')),
#  ('S0002', 'Swiss Miss Hot Cocoa Mix 1 oz', Decimal('43')),
#  ('S0002', 'Tejava Unsweetened Black Tea 16.9oz', Decimal('14')),
#  ('S0002', 'Tootsie Roll Midgets', Decimal('52')),
#  ('S0002', 'Topo Chico 12 oz glass', Decimal('42')),
#  ('S0002', 'Topo Chico 20oz plastic', Decimal('31')),
#  ('S0002', 'Trident Original Flavor 18/pk', Decimal('15')),
#  ('S0002', 'Tropicana Apple Juice 10 oz 100% ', Decimal('44')),
#  ('S0002', 'Tropicana Orange Juice 10 oz 100% ', Decimal('27')),
#  ('S0002', 'Truvia Natural Sweetener', Decimal('38')),
#  ('S0002', 'Tylenol Extra Strength 2 pill packets', Decimal('48')),
#  ('S0002', 'Unsalted Premium Blend Nuts', Decimal('23')),
#  ('S0002', 'V-8 Splash Variety 20 oz', Decimal('13')),
#  ('S0002', 'V8 100% Vegetable Juice 11oz cans', Decimal('17')),
#  ('S0002', 'Veggie Chips 1oz ', Decimal('38')),
#  ('S0002', 'Vita Coconut Water 10oz ', Decimal('33')),
#  ('S0002', 'Waterloo Sparkling Blackcherry 12oz', Decimal('26')),
#  ('S0002', 'Waterloo Sparkling Grapefruit 12oz', Decimal('26')),
#  ('S0002', 'Waterloo Sparkling Lemon 12oz', Decimal('57')),
#  ('S0002', 'Waterloo Sparkling Lime 12oz', Decimal('22')),
#  ('S0002', 'Waterloo Sparkling Original 12oz', Decimal('19')),
#  ('S0002', 'Waterloo Sparkling Watermelon 12oz', Decimal('23')),
#  ('S0002', "Welch's 100% Juice Variety10 oz", Decimal('53')),
#  ('S0002', 'Wint O Green LifeSavers Sugar Free', Decimal('32')),
#  ('S0002', 'Wonderful Pistachios (in shell)', Decimal('8')),
#  ('S0002', 'Yoplait Original Yogurt Variety Pack ', Decimal('43')),
#  ('S0002', 'Zoo Animal Cookies/Crackers', Decimal('36')),
#  ('S0002', None, Decimal('8415')),
#  ('S0003', '100% Juice Box Variety 6.75 oz ', Decimal('46')),
#  ('S0003', 'A&W Root Beer - 12 oz cans', Decimal('30')),
#  ('S0003', 'A&W Root Beer Diet - 12 oz cans', Decimal('26')),
#  ('S0003', 'Advil 2 pill packets', Decimal('19')),
#  ('S0003', 'All Purpose Cleaner 409 Spray', Decimal('17')),
#  ('S0003', 'Altoids Small Packs Variety', Decimal('52')),
#  ('S0003', 'Apple Sauce Variety GoGO Squeeze 3.2oz', Decimal('35')),
#  ('S0003', 'AquaFina Purified Drinking Water 16oz', Decimal('25')),
#  ('S0003', 'Austin Cookie Cracker Variety', Decimal('39')),
#  ('S0003', 'Austin Toasty Crackers w/ PBtr', Decimal('20')),
#  ('S0003', 'Baked Chips Variety Mix Frito', Decimal('26')),
#  ('S0003', "Barq's Root Beer - 12 oz cans", Decimal('33')),
#  ('S0003', 'Belvita Hard Biscuits Blueberry', Decimal('34')),
#  ('S0003', 'Belvita Hard Biscuits Cinnamon', Decimal('59')),
#  ('S0003', 'Belvita Protein Oats Soft Biscuit', Decimal('12')),
#  ('S0003', 'Blue Diamond Almonds Rstd, Sltd', Decimal('51')),
#  ('S0003', 'Bounty Paper Towels Select a Size ', Decimal('12')),
#  ('S0003', 'Breath Savers Peppermints 12/roll ', Decimal('68')),
#  ('S0003', 'Brisk Lemon Iced Tea - 12 oz cans', Decimal('45')),
#  ('S0003', 'Cascade Gel Packs Dishwasher', Decimal('8')),
#  ('S0003', 'Cascade Gel w/ Dawn Dishwasher', Decimal('16')),
#  ('S0003', 'Charmin Ultra Bath Tissue', Decimal('19')),
#  ('S0003', 'Cheese and Peanut Butter Crackers', Decimal('16')),
#  ('S0003', "Cheetos Flamin' Hot 1 oz", Decimal('22')),
#  ('S0003', 'Cheez It Original Crackers 1.5oz', Decimal('48')),
#  ('S0003', 'Cheez It White Cheddar 1.5 oz', Decimal('39')),
#  ('S0003', 'Cherry Coke 12oz', Decimal('47')),
#  ('S0003', 'Cherry Coke Zero 12 pack', Decimal('21')),
#  ('S0003', 'Chewy Granola Variety Bars Quaker', Decimal('16')),
#  ('S0003', 'Chex Mix Original', Decimal('53')),
#  ('S0003', 'Chinet Comfort Hot Cups with Lids 16oz', Decimal('48')),
#  ('S0003', 'Chobani Greek Yogurt Variety Pack ', Decimal('24')),
#  ('S0003', 'Clear Plastic 12 oz Cups', Decimal('22')),
#  ('S0003', 'Clear Plastic Cups 9oz', Decimal('28')),
#  ('S0003', 'Cliff Builders Protein Bar Variety Pack', Decimal('25')),
#  ('S0003', 'Cliff Energy Bars Variety Pack', Decimal('28')),
#  ('S0003', 'Clorox Bleach Large Jugs', Decimal('36')),
#  ('S0003', 'Clorox Disinfecting Wipes ', Decimal('10')),
#  ('S0003', 'Coffee-Mate French Vanilla Cold', Decimal('39')),
#  ('S0003', 'Coffee-Mate Original Flavor Cold', Decimal('49')),
#  ('S0003', 'Coffee-mate Original Powdered Creamer', Decimal('21')),
#  ('S0003', 'Coke Classic 12 oz cans', Decimal('70')),
#  ('S0003', 'Coke Zero Sugar 12 oz cans', Decimal('18')),
#  ('S0003', 'Community Coffee Dark Roast', Decimal('31')),
#  ('S0003', 'Crunchy Granola Bars Oats & Honey', Decimal('10')),
#  ('S0003', 'Dark Chocolate Mint Patties', Decimal('45')),
#  ('S0003', 'Dasani Bottled Water 16.9 oz', Decimal('35')),
#  ('S0003', 'Dawn Ultra Dish Detergent, Original Scent ', Decimal('28')),
#  ('S0003', 'Deluxe Mixed Nuts with Seasalt', Decimal('71')),
#  ('S0003', 'Detour Lower Sugar Protein Bar', Decimal('9')),
#  ('S0003', 'Dial Anti-bacterial  Foam 7.5oz', Decimal('33')),
#  ('S0003', 'Diet Coke - 12 oz cans', Decimal('109')),
#  ('S0003', 'Diet Coke Caffeine Free 12oz cans', Decimal('28')),
#  ('S0003', 'Diet Dr. Pepper - 12 oz cans', Decimal('13')),
#  ('S0003', 'Diet Fuze Iced Tea', Decimal('47')),
#  ('S0003', 'Diet Gingerale 12 oz cans', Decimal('29')),
#  ('S0003', 'Diet Mountain Dew 12oz cans', Decimal('19')),
#  ('S0003', 'Diet Pepsi - 12 oz cans', Decimal('39')),
#  ('S0003', 'Dixie Perfecttouch Paper Cups 12oz', Decimal('39')),
#  ('S0003', 'Dole Fruit in Gel Cups 4.3 oz', Decimal('24')),
#  ('S0003', 'Doritos Nacho Cheese 1 oz', Decimal('48')),
#  ('S0003', 'Double Bubble Variety Tub', Decimal('28')),
#  ('S0003', 'Dr. Pepper - 12 oz cans', Decimal('49')),
#  ('S0003', 'Dunkin Donuts Original Blend', Decimal('31')),
#  ('S0003', 'Equal Sweetener', Decimal('29')),
#  ('S0003', 'Extra Variety Packs Sugar Free', Decimal('45')),
#  ('S0003', 'Famous Amos Cookies ', Decimal('47')),
#  ('S0003', 'Fiber One 90 Calorie Fudge Brownies', Decimal('40')),
#  ('S0003', 'Fiber One Bars Oats and Chocolate', Decimal('30')),
#  ('S0003', 'Flamin Hot Chip Mix 1oz', Decimal('26')),
#  ('S0003', 'Foam Coffee Cups - 08 ounce', Decimal('32')),
#  ('S0003', 'Foam Coffee Cups - 12 ounce', Decimal('16')),
#  ('S0003', 'Foam Coffee Cups - 16 ounce', Decimal('41')),
#  ('S0003', 'Foam Coffee Cups - 20 ounce', Decimal('33')),
#  ('S0003', 'Folgers 100% Colombian Coffee', Decimal('39')),
#  ('S0003', 'Folgers Classic Roast Coffee', Decimal('16')),
#  ('S0003', 'ForceFlex Trash Bags 13 Gal ', Decimal('65')),
#  ('S0003', 'French Vanilla International Delight', Decimal('19')),
#  ('S0003', 'Fresca Black Cherry - 12 oz cans', Decimal('14')),
#  ('S0003', 'Fresca Original - 12 oz cans', Decimal('74')),
#  ('S0003', 'Fresca Peach Citrus - 12 oz cans', Decimal('32')),
#  ('S0003', 'Frito Big Grab Variety 1.5-2.0 oz', Decimal('14')),
#  ('S0003', 'Frito Bold Flavors Variety', Decimal('13')),
#  ('S0003', 'Frito BOLD Flavors Variety Pack', Decimal('63')),
#  ('S0003', 'Frito Classic Mix Variety', Decimal('20')),
#  ('S0003', 'Frito Fiesta Flavors Variety', Decimal('55')),
#  ('S0003', 'Fuze Iced Tea', Decimal('2')),
#  ('S0003', 'G2 Lo Calorie Variety 20 oz', Decimal('31')),
#  ('S0003', 'Gardettos Snacks', Decimal('23')),
#  ('S0003', 'Gatorade Frost Variety 12 oz', Decimal('32')),
#  ('S0003', 'Gatorade Frost Variety 20 oz ', Decimal('22')),
#  ('S0003', 'Gatorade Lemon Lime 12oz', Decimal('14')),
#  ('S0003', 'Gatorade Liberty Variety 12 oz', Decimal('19')),
#  ('S0003', 'Gatorade Liberty Variety 20 oz ', Decimal('18')),
#  ('S0003', 'Gatorade Original Variety 12 oz', Decimal('40')),
#  ('S0003', 'Gatorade Variety 20 oz ', Decimal('17')),
#  ('S0003', 'Gatorade X-Factor Fierce Variety 20 oz', Decimal('23')),
#  ('S0003', 'Gatorade Zero Variety 20 oz', Decimal('30')),
#  ('S0003', 'Ginger Ale - 12 oz cans', Decimal('46')),
#  ('S0003', 'Go-Gurt Low Fat Yogurt, Strwbry & Berry ', Decimal('29')),
#  ('S0003', 'Goldfish Pepperidge Farm Cheddar 1.5oz ', Decimal('34')),
#  ('S0003', 'Goldfish Variety Bags, cheddar, pretzels', Decimal('22')),
#  ('S0003', "Half & Half -Land o Lakes Mini Moo's", Decimal('36')),
#  ('S0003', 'Hand Sanitizer Refill Pump', Decimal('26')),
#  ('S0003', 'Hawaiian Punch - 12 oz cans', Decimal('41')),
#  ('S0003', 'Hazelnut International Delight', Decimal('36')),
#  ('S0003', "Hefty Cmprtmnt Plates Foam 10'", Decimal('30')),
#  ('S0003', 'Hefty Supreme Foam Bowls 12oz', Decimal('41')),
#  ('S0003', 'Hefty Supreme Foam Plates 6 inch', Decimal('63')),
#  ('S0003', 'Hefty Supreme Foam Plates 9 inch', Decimal('2')),
#  ('S0003', 'Hershey Chocoalte Minatures Assort.', Decimal('5')),
#  ('S0003', 'Hershey Factory Favorites Mix', Decimal('35')),
#  ('S0003', 'Hershey Kisses ', Decimal('42')),
#  ('S0003', 'Hershey Nuggets', Decimal('28')),
#  ('S0003', 'Honey Packets  ', Decimal('58')),
#  ('S0003', 'Ice Breaker Mints Sugar Free ', Decimal('14')),
#  ('S0003', 'Jolly Ranchers Variety Hard Candy', Decimal('36')),
#  ('S0003', 'K Cups - Green Tea', Decimal('51')),
#  ('S0003', 'K Cups - McCafe Premium Roast', Decimal('25')),
#  ('S0003', "K Cups – Starbuck's Pike Place", Decimal('22')),
#  ('S0003', 'K Cups –Organic Breakfast Blend', Decimal('29')),
#  ('S0003', 'K Cups Daily Chef Columbian Supremo', Decimal('43')),
#  ('S0003', 'K Cups Dunkin Donuts Medium Roast', Decimal('52')),
#  ('S0003', 'K Cups Folgers Lively Columbian', Decimal('30')),
#  ('S0003', 'K Cups Hot Cocoa', Decimal('24')),
#  ('S0003', 'K Cups Original Donut Shop Med. Roast', Decimal('46')),
#  ('S0003', 'Keebler Cookie & Cracker Variety', Decimal('55')),
#  ('S0003', "Kellogg's Cereals Assortment Pack ", Decimal('27')),
#  ('S0003', "Kellogg's Fruity Snacks", Decimal('42')),
#  ('S0003', 'Kellogg Fun Mix Cheez it, Prngls, Fam Amos', Decimal('49')),
#  ('S0003', 'Kind  Bars Mini Variety Pack 0.7 oz ', Decimal('9')),
#  ('S0003', 'Kind  Bars Variety Pack 1.4 oz ', Decimal('38')),
#  ('S0003', 'Kleenex Tissue Rectangle Boxes 160/box', Decimal('24')),
#  ('S0003', 'Kleenex Tissue Square Boxes 75/box', Decimal('13')),
#  ('S0003', 'La Croix Sparkling Berry 12 ozv', Decimal('51')),
#  ('S0003', 'La Croix Sparkling Coconut 12 oz', Decimal('54')),
#  ('S0003', 'La Croix Sparkling Cran-Raspberry 12 oz', Decimal('4')),
#  ('S0003', 'La Croix Sparkling Grapefruit 12 oz', Decimal('30')),
#  ('S0003', 'La Croix Sparkling Lemon 12 oz', Decimal('50')),
#  ('S0003', 'La Croix Sparkling Lime 12 oz', Decimal('25')),
#  ('S0003', 'La Croix Sparkling Orange 12 oz', Decimal('20')),
#  ('S0003', 'La Croix Sparkling Pure 12 oz', Decimal('49')),
#  ('S0003', 'Lance Variety Cracker Packs ', Decimal('51')),
#  ('S0003', 'Large Trash Bags Black 33 gal', Decimal('34')),
#  ('S0003', 'Lunchables Variety Pack Oscar Meyer', Decimal('58')),
#  ('S0003', 'Lysol Disinfectant Spray 19 oz', Decimal('49')),
#  ('S0003', 'Lysol Wipes 100 ct', Decimal('36')),
#  ('S0003', 'M&M Peanut Butter 1.6 oz', Decimal('37')),
#  ('S0003', 'M&M Peanut Candy 1.7 oz', Decimal('43')),
#  ('S0003', 'M&M Variety Full Size Bags', Decimal('12')),
#  ('S0003', 'Mars Chocolate Favorites', Decimal('42')),
#  ('S0003', 'Mars Mini Mix', Decimal('22')),
#  ('S0003', 'Miss Vickies Chips', Decimal('42')),
#  ('S0003', 'Monster Java 15 oz', Decimal('13')),
#  ('S0003', 'Monster Lo-Carb 16 oz', Decimal('29')),
#  ('S0003', 'Monster Original Green 16 oz', Decimal('49')),
#  ('S0003', 'Monster Zero Ultra 16 oz', Decimal('15')),
#  ('S0003', 'Monster Zero Ultra Variety 16 oz', Decimal('22')),
#  ('S0003', 'Mountain Dew - 12 oz cans', Decimal('26')),
#  ('S0003', 'Muscle Milk Protein Shake Choc. 11oz', Decimal('15')),
#  ('S0003', 'Muscle Milk Protein Shake Strbry. 11oz', Decimal('46')),
#  ('S0003', 'Muscle Milk Protein Shake Van. 11oz', Decimal('76')),
#  ('S0003', 'Nabisco Classic Mix ccooki, cracker', Decimal('33')),
#  ('S0003', 'Nabisco Cookie Variety Pk Oreo/ChocChip', Decimal('42')),
#  ('S0003', 'Napkins Square Lunch', Decimal('31')),
#  ('S0003', 'Nat.Valley PeanutButter Protein Bars', Decimal('49')),
#  ('S0003', 'Nature Valley Biscuit Sandwich Variety Pack ', Decimal('18')),
#  ('S0003', 'Nature Valley Chewy Trail Mix Bars', Decimal('14')),
#  ('S0003', 'Nature Valley Soft Oatmeal Squares   ', Decimal('51')),
#  ('S0003', 'Nature Valley Sweet/Salty Almond Bars      ', Decimal('24')),
#  ('S0003', 'Nature Valley Sweet/Salty Peanut Bars      ', Decimal('26')),
#  ('S0003', 'Nestle Purelife 16oz ', Decimal('17')),
#  ('S0003', 'Njoy Creamer Canister 16 oz', Decimal('57')),
#  ('S0003', 'Njoy Creamer Packs', Decimal('18')),
#  ('S0003', 'Njoy Sugar Canister 22 oz', Decimal('28')),
#  ('S0003', 'Ocean Spray Cranberry Juice Cocktail 15oz ', Decimal('7')),
#  ('S0003', 'Ozarka Spring Water 16.9 oz bottles', Decimal('4')),
#  ('S0003', 'Ozarka Spring Water 20 oz', Decimal('32')),
#  ('S0003', 'Ozarka Spring Water Mini 8oz', Decimal('56')),
#  ('S0003', 'Paper Bowls 20 oz Ultra Strong', Decimal('21')),
#  ('S0003', 'Paper Plate 10 inch Ultra Strong', Decimal('14')),
#  ('S0003', 'Paper Plates 7 inch  Ultra Strong', Decimal('46')),
#  ('S0003', 'Paper Plates 8.5 inch Ultra Strong', Decimal('27')),
#  ('S0003', 'Peanutbutter Filled Pretzels', Decimal('17')),
#  ('S0003', 'Peppermints Hard Candy', Decimal('28')),
#  ('S0003', 'Pepsi - 12 oz cans', Decimal('73')),
#  ('S0003', 'Perrier Flavors Sparkling Water 16.9oz', Decimal('33')),
#  ('S0003', 'Perrier Sparkling Water glass 11oz', Decimal('23')),
#  ('S0003', 'Planters Nut-trition 1.5 oz ', Decimal('40')),
#  ('S0003', 'Planters Nut Variety Packs', Decimal('32')),
#  ('S0003', 'Plastic Forks White Heavyweight', Decimal('19')),
#  ('S0003', 'Plastic Knives White  Heavyweight', Decimal('8')),
#  ('S0003', 'Plastic Spoons White  Heavyweight', Decimal('6')),
#  ('S0003', 'POM 2 ply paper towels', Decimal('12')),
#  ('S0003', 'Pop-Tarts, Brown Sugar Cinnamon ', Decimal('27')),
#  ('S0003', 'Pop-Tarts, Frosted Strawberry', Decimal('70')),
#  ('S0003', 'Pop Chips Variety bags', Decimal('12')),
#  ('S0003', 'Premier Protein Shake Choc. 11oz', Decimal('64')),
#  ('S0003', 'Pringles Snak Stacks Variety', Decimal('33')),
#  ('S0003', 'Propel Zero Variety 20 oz', Decimal('15')),
#  ('S0003', 'Pure Leaf Sweet Tea 8.5oz', Decimal('33')),
#  ('S0003', 'Pure Leaf Unsweetened Tea 18.5oz', Decimal('35')),
#  ('S0003', 'Pure White Sugar Packets', Decimal('12')),
#  ('S0003', 'Quaker Instant Oatmeal Maple Brn Sugar', Decimal('5')),
#  ('S0003', 'Quaker Instant Oatmeal Variety ', Decimal('35')),
#  ('S0003', 'Red Bull 12oz', Decimal('32')),
#  ('S0003', 'Red Bull 16oz', Decimal('26')),
#  ('S0003', 'Red Bull 8.4 oz', Decimal('36')),
#  ('S0003', 'Red Bull Sugar Free 8.4 oz', Decimal('52')),
#  ('S0003', 'Red Plastic Cups 18oz', Decimal('22')),
#  ('S0003', "Reese's Peanutbutter Cups 2/pk", Decimal('25')),
#  ('S0003', "Reese's Pieces Peanutbutter Candy", Decimal('10')),
#  ('S0003', 'San Pelligrino 16oz Plastic ', Decimal('19')),
#  ('S0003', 'Sargento Bal. Breaks (fruit, nut, cheese)', Decimal('20')),
#  ('S0003', 'Sargento String Cheese 0.75oz', Decimal('34')),
#  ('S0003', 'Seven Up - 12 oz cans', Decimal('16')),
#  ('S0003', 'Snapple Variety Pack 20oz', Decimal('17')),
#  ('S0003', 'Snickers Bars 1.8oz', Decimal('34')),
#  ('S0003', 'Snyders Pretzels Minis', Decimal('28')),
#  ('S0003', 'Sobe Zero Lifewater Variety 20 oz', Decimal('47')),
#  ('S0003', 'Splenda Sweetener', Decimal('23')),
#  ('S0003', 'Sprite - 12 oz cans', Decimal('122')),
#  ('S0003', 'Sprite Zero - 12 pack', Decimal('28')),
#  ('S0003', 'Spunkmeyer Muffin Variety', Decimal('30')),
#  ('S0003', "Starbuck's Pike Place", Decimal('17')),
#  ('S0003', 'Stirrers Coffee Stirs 7inch', Decimal('28')),
#  ('S0003', 'Strong Everyday Napkins', Decimal('22')),
#  ('S0003', 'Sugar in the Raw Packets', Decimal('24')),
#  ('S0003', 'Sun Chips Variety Pack', Decimal('27')),
#  ('S0003', 'Sunkist Orange - 12 oz cans', Decimal('11')),
#  ('S0003', 'Sweet N Low Sweetener', Decimal('43')),
#  ('S0003', 'Swiss Miss Hot Cocoa Mix 1 oz', Decimal('26')),
#  ('S0003', 'Tejava Unsweetened Black Tea 16.9oz', Decimal('41')),
#  ('S0003', 'Tootsie Roll Midgets', Decimal('13')),
#  ('S0003', 'Topo Chico 12 oz glass', Decimal('32')),
#  ('S0003', 'Topo Chico 20oz plastic', Decimal('19')),
#  ('S0003', 'Trident Original Flavor 18/pk', Decimal('38')),
#  ('S0003', 'Tropicana Apple Juice 10 oz 100% ', Decimal('35')),
#  ('S0003', 'Tropicana Orange Juice 10 oz 100% ', Decimal('59')),
#  ('S0003', 'Truvia Natural Sweetener', Decimal('28')),
#  ('S0003', 'Tylenol Extra Strength 2 pill packets', Decimal('6')),
#  ('S0003', 'Unsalted Premium Blend Nuts', Decimal('45')),
#  ('S0003', 'V-8 Splash Variety 20 oz', Decimal('11')),
#  ('S0003', 'V8 100% Vegetable Juice 11oz cans', Decimal('18')),
#  ('S0003', 'Veggie Chips 1oz ', Decimal('37')),
#  ('S0003', 'Vita Coconut Water 10oz ', Decimal('47')),
#  ('S0003', 'Waterloo Sparkling Blackcherry 12oz', Decimal('13')),
#  ('S0003', 'Waterloo Sparkling Grapefruit 12oz', Decimal('36')),
#  ('S0003', 'Waterloo Sparkling Lemon 12oz', Decimal('31')),
#  ('S0003', 'Waterloo Sparkling Lime 12oz', Decimal('14')),
#  ('S0003', 'Waterloo Sparkling Mango 12oz', Decimal('54')),
#  ('S0003', 'Waterloo Sparkling Original 12oz', Decimal('30')),
#  ('S0003', 'Waterloo Sparkling Watermelon 12oz', Decimal('45')),
#  ('S0003', "Welch's 100% Juice Variety10 oz", Decimal('32')),
#  ('S0003', 'Wint O Green LifeSavers Sugar Free', Decimal('48')),
#  ('S0003', 'Wonderful Pistachios (in shell)', Decimal('39')),
#  ('S0003', 'Yoplait Original Yogurt Variety Pack ', Decimal('48')),
#  ('S0003', 'Zoo Animal Cookies/Crackers', Decimal('40')),
#  ('S0003', None, Decimal('8299')),
#  ('S0004', '100% Juice Box Variety 6.75 oz ', Decimal('26')),
#  ('S0004', 'A&W Root Beer - 12 oz cans', Decimal('59')),
#  ('S0004', 'A&W Root Beer Diet - 12 oz cans', Decimal('7')),
#  ('S0004', 'Advil 2 pill packets', Decimal('34')),
#  ('S0004', 'All Purpose Cleaner 409 Spray', Decimal('31')),
#  ('S0004', 'Altoids Small Packs Variety', Decimal('20')),
#  ('S0004', 'Apple Sauce Variety GoGO Squeeze 3.2oz', Decimal('4')),
#  ('S0004', 'AquaFina Purified Drinking Water 16oz', Decimal('43')),
#  ('S0004', 'Austin Cookie Cracker Variety', Decimal('44')),
#  ('S0004', 'Austin Toasty Crackers w/ PBtr', Decimal('26')),
#  ('S0004', 'Baked Chips Variety Mix Frito', Decimal('42')),
#  ('S0004', "Barq's Root Beer - 12 oz cans", Decimal('19')),
#  ('S0004', 'Belvita Hard Biscuits Blueberry', Decimal('20')),
#  ('S0004', 'Belvita Hard Biscuits Cinnamon', Decimal('37')),
#  ('S0004', 'Belvita Protein Oats Soft Biscuit', Decimal('20')),
#  ('S0004', 'Blue Diamond Almonds Rstd, Sltd', Decimal('28')),
#  ('S0004', 'Bounty Paper Towels Select a Size ', Decimal('28')),
#  ('S0004', 'Breath Savers Peppermints 12/roll ', Decimal('35')),
#  ('S0004', 'Brisk Lemon Iced Tea - 12 oz cans', Decimal('31')),
#  ('S0004', 'Cascade Gel Packs Dishwasher', Decimal('27')),
#  ('S0004', 'Cascade Gel w/ Dawn Dishwasher', Decimal('54')),
#  ('S0004', 'Charmin Ultra Bath Tissue', Decimal('12')),
#  ('S0004', 'Cheese and Peanut Butter Crackers', Decimal('11')),
#  ('S0004', "Cheetos Flamin' Hot 1 oz", Decimal('12')),
#  ('S0004', 'Cheez It Original Crackers 1.5oz', Decimal('42')),
#  ('S0004', 'Cheez It White Cheddar 1.5 oz', Decimal('32')),
#  ('S0004', 'Cherry Coke 12oz', Decimal('27')),
#  ('S0004', 'Cherry Coke Zero 12 pack', Decimal('41')),
#  ('S0004', 'Chewy Granola Variety Bars Quaker', Decimal('40')),
#  ('S0004', 'Chex Mix Original', Decimal('28')),
#  ('S0004', 'Chinet Comfort Hot Cups with Lids 16oz', Decimal('56')),
#  ('S0004', 'Chobani Greek Yogurt Variety Pack ', Decimal('55')),
#  ('S0004', 'Clear Plastic 12 oz Cups', Decimal('29')),
#  ('S0004', 'Clear Plastic Cups 9oz', Decimal('14')),
#  ('S0004', 'Cliff Builders Protein Bar Variety Pack', Decimal('55')),
#  ('S0004', 'Cliff Energy Bars Variety Pack', Decimal('9')),
#  ('S0004', 'Clorox Bleach Large Jugs', Decimal('12')),
#  ('S0004', 'Clorox Disinfecting Wipes ', Decimal('34')),
#  ('S0004', 'Coffee-Mate French Vanilla Cold', Decimal('26')),
#  ('S0004', 'Coffee-Mate Original Flavor Cold', Decimal('30')),
#  ('S0004', 'Coffee-mate Original Powdered Creamer', Decimal('38')),
#  ('S0004', 'Coke Classic 12 oz cans', Decimal('29')),
#  ('S0004', 'Coke Zero Sugar 12 oz cans', Decimal('29')),
#  ('S0004', 'Community Coffee Dark Roast', Decimal('18')),
#  ('S0004', 'Crunchy Granola Bars Oats & Honey', Decimal('31')),
#  ('S0004', 'Dark Chocolate Mint Patties', Decimal('36')),
#  ('S0004', 'Dasani Bottled Water 16.9 oz', Decimal('26')),
#  ('S0004', 'Dawn Ultra Dish Detergent, Original Scent ', Decimal('34')),
#  ('S0004', 'Deluxe Mixed Nuts with Seasalt', Decimal('8')),
#  ('S0004', 'Detour Lower Sugar Protein Bar', Decimal('45')),
#  ('S0004', 'Dial Anti-bacterial  Foam 7.5oz', Decimal('50')),
#  ('S0004', 'Diet Coke - 12 oz cans', Decimal('25')),
#  ('S0004', 'Diet Coke Caffeine Free 12oz cans', Decimal('37')),
#  ('S0004', 'Diet Dr. Pepper - 12 oz cans', Decimal('28')),
#  ('S0004', 'Diet Fuze Iced Tea', Decimal('9')),
#  ('S0004', 'Diet Gingerale 12 oz cans', Decimal('36')),
#  ('S0004', 'Diet Mountain Dew 12oz cans', Decimal('43')),
#  ('S0004', 'Diet Pepsi - 12 oz cans', Decimal('45')),
#  ('S0004', 'Dixie Perfecttouch Paper Cups 12oz', Decimal('4')),
#  ('S0004', 'Dole Fruit in Gel Cups 4.3 oz', Decimal('25')),
#  ('S0004', 'Doritos Nacho Cheese 1 oz', Decimal('47')),
#  ('S0004', 'Double Bubble Variety Tub', Decimal('61')),
#  ('S0004', 'Dr. Pepper - 12 oz cans', Decimal('13')),
#  ('S0004', 'Dunkin Donuts Original Blend', Decimal('31')),
#  ('S0004', 'Equal Sweetener', Decimal('51')),
#  ('S0004', 'Extra Variety Packs Sugar Free', Decimal('14')),
#  ('S0004', 'Famous Amos Cookies ', Decimal('35')),
#  ('S0004', 'Fiber One 90 Calorie Fudge Brownies', Decimal('36')),
#  ('S0004', 'Fiber One Bars Oats and Chocolate', Decimal('50')),
#  ('S0004', 'Flamin Hot Chip Mix 1oz', Decimal('12')),
#  ('S0004', 'Foam Coffee Cups - 08 ounce', Decimal('23')),
#  ('S0004', 'Foam Coffee Cups - 12 ounce', Decimal('29')),
#  ('S0004', 'Foam Coffee Cups - 16 ounce', Decimal('28')),
#  ('S0004', 'Foam Coffee Cups - 20 ounce', Decimal('44')),
#  ('S0004', 'Folgers 100% Colombian Coffee', Decimal('15')),
#  ('S0004', 'Folgers Classic Roast Coffee', Decimal('21')),
#  ('S0004', 'ForceFlex Trash Bags 13 Gal ', Decimal('26')),
#  ('S0004', 'French Vanilla International Delight', Decimal('15')),
#  ('S0004', 'Fresca Black Cherry - 12 oz cans', Decimal('10')),
#  ('S0004', 'Fresca Original - 12 oz cans', Decimal('67')),
#  ('S0004', 'Fresca Peach Citrus - 12 oz cans', Decimal('13')),
#  ('S0004', 'Frito Big Grab Variety 1.5-2.0 oz', Decimal('43')),
#  ('S0004', 'Frito Bold Flavors Variety', Decimal('30')),
#  ('S0004', 'Frito BOLD Flavors Variety Pack', Decimal('37')),
#  ('S0004', 'Frito Classic Mix Variety', Decimal('11')),
#  ('S0004', 'Frito Fiesta Flavors Variety', Decimal('43')),
#  ('S0004', 'Fuze Iced Tea', Decimal('27')),
#  ('S0004', 'G2 Lo Calorie Variety 20 oz', Decimal('28')),
#  ('S0004', 'Gardettos Snacks', Decimal('50')),
#  ('S0004', 'Gatorade Frost Variety 12 oz', Decimal('14')),
#  ('S0004', 'Gatorade Frost Variety 20 oz ', Decimal('10')),
#  ('S0004', 'Gatorade Lemon Lime 12oz', Decimal('8')),
#  ('S0004', 'Gatorade Liberty Variety 20 oz ', Decimal('36')),
#  ('S0004', 'Gatorade Original Variety 12 oz', Decimal('35')),
#  ('S0004', 'Gatorade Variety 20 oz ', Decimal('43')),
#  ('S0004', 'Gatorade X-Factor Fierce Variety 20 oz', Decimal('8')),
#  ('S0004', 'Gatorade Zero Variety 20 oz', Decimal('13')),
#  ('S0004', 'Ginger Ale - 12 oz cans', Decimal('11')),
#  ('S0004', 'Go-Gurt Low Fat Yogurt, Strwbry & Berry ', Decimal('67')),
#  ('S0004', 'Goldfish Pepperidge Farm Cheddar 1.5oz ', Decimal('24')),
#  ('S0004', 'Goldfish Variety Bags, cheddar, pretzels', Decimal('12')),
#  ('S0004', "Half & Half -Land o Lakes Mini Moo's", Decimal('18')),
#  ('S0004', 'Hand Sanitizer Refill Pump', Decimal('48')),
#  ('S0004', 'Hawaiian Punch - 12 oz cans', Decimal('11')),
#  ('S0004', 'Hazelnut International Delight', Decimal('63')),
#  ('S0004', "Hefty Cmprtmnt Plates Foam 10'", Decimal('40')),
#  ('S0004', 'Hefty Supreme Foam Bowls 12oz', Decimal('43')),
#  ('S0004', 'Hefty Supreme Foam Plates 6 inch', Decimal('16')),
#  ('S0004', 'Hefty Supreme Foam Plates 9 inch', Decimal('27')),
#  ('S0004', 'Hershey Chocoalte Minatures Assort.', Decimal('26')),
#  ('S0004', 'Hershey Factory Favorites Mix', Decimal('46')),
#  ('S0004', 'Hershey Kisses ', Decimal('58')),
#  ('S0004', 'Hershey Nuggets', Decimal('23')),
#  ('S0004', 'Honey Packets  ', Decimal('47')),
#  ('S0004', 'Ice Breaker Mints Sugar Free ', Decimal('32')),
#  ('S0004', 'Jolly Ranchers Variety Hard Candy', Decimal('36')),
#  ('S0004', 'K Cups - Green Tea', Decimal('50')),
#  ('S0004', 'K Cups - McCafe Premium Roast', Decimal('33')),
#  ('S0004', "K Cups – Starbuck's Pike Place", Decimal('20')),
#  ('S0004', 'K Cups –Organic Breakfast Blend', Decimal('1')),
#  ('S0004', 'K Cups Daily Chef Columbian Supremo', Decimal('26')),
#  ('S0004', 'K Cups Dunkin Donuts Medium Roast', Decimal('41')),
#  ('S0004', 'K Cups Folgers Lively Columbian', Decimal('17')),
#  ('S0004', 'K Cups Hot Cocoa', Decimal('27')),
#  ('S0004', 'K Cups Original Donut Shop Med. Roast', Decimal('11')),
#  ('S0004', 'Keebler Cookie & Cracker Variety', Decimal('26')),
#  ('S0004', "Kellogg's Cereals Assortment Pack ", Decimal('20')),
#  ('S0004', "Kellogg's Fruity Snacks", Decimal('7')),
#  ('S0004', 'Kellogg Fun Mix Cheez it, Prngls, Fam Amos', Decimal('47')),
#  ('S0004', 'Kind  Bars Mini Variety Pack 0.7 oz ', Decimal('39')),
#  ('S0004', 'Kind  Bars Variety Pack 1.4 oz ', Decimal('79')),
#  ('S0004', 'Kleenex Tissue Rectangle Boxes 160/box', Decimal('22')),
#  ('S0004', 'Kleenex Tissue Square Boxes 75/box', Decimal('18')),
#  ('S0004', 'La Croix Sparkling Berry 12 ozv', Decimal('27')),
#  ('S0004', 'La Croix Sparkling Coconut 12 oz', Decimal('36')),
#  ('S0004', 'La Croix Sparkling Cran-Raspberry 12 oz', Decimal('42')),
#  ('S0004', 'La Croix Sparkling Grapefruit 12 oz', Decimal('26')),
#  ('S0004', 'La Croix Sparkling Lemon 12 oz', Decimal('43')),
#  ('S0004', 'La Croix Sparkling Lime 12 oz', Decimal('26')),
#  ('S0004', 'La Croix Sparkling Orange 12 oz', Decimal('32')),
#  ('S0004', 'La Croix Sparkling Pure 12 oz', Decimal('42')),
#  ('S0004', 'Lance Variety Cracker Packs ', Decimal('28')),
#  ('S0004', 'Large Trash Bags Black 33 gal', Decimal('61')),
#  ('S0004', 'Lunchables Variety Pack Oscar Meyer', Decimal('29')),
#  ('S0004', 'Lysol Disinfectant Spray 19 oz', Decimal('40')),
#  ('S0004', 'Lysol Wipes 100 ct', Decimal('32')),
#  ('S0004', 'M&M Peanut Butter 1.6 oz', Decimal('38')),
#  ('S0004', 'M&M Peanut Candy 1.7 oz', Decimal('3')),
#  ('S0004', 'M&M Variety Full Size Bags', Decimal('52')),
#  ('S0004', 'Mars Chocolate Favorites', Decimal('2')),
#  ('S0004', 'Mars Mini Mix', Decimal('24')),
#  ('S0004', 'Miss Vickies Chips', Decimal('33')),
#  ('S0004', 'Monster Java 15 oz', Decimal('13')),
#  ('S0004', 'Monster Lo-Carb 16 oz', Decimal('2')),
#  ('S0004', 'Monster Original Green 16 oz', Decimal('24')),
#  ('S0004', 'Monster Zero Ultra 16 oz', Decimal('7')),
#  ('S0004', 'Monster Zero Ultra Variety 16 oz', Decimal('53')),
#  ('S0004', 'Mountain Dew - 12 oz cans', Decimal('25')),
#  ('S0004', 'Muscle Milk Protein Shake Choc. 11oz', Decimal('55')),
#  ('S0004', 'Muscle Milk Protein Shake Strbry. 11oz', Decimal('35')),
#  ('S0004', 'Muscle Milk Protein Shake Van. 11oz', Decimal('69')),
#  ('S0004', 'Nabisco Classic Mix ccooki, cracker', Decimal('21')),
#  ('S0004', 'Nabisco Cookie Variety Pk Oreo/ChocChip', Decimal('23')),
#  ('S0004', 'Napkins Square Lunch', Decimal('22')),
#  ('S0004', 'Nature Valley Biscuit Sandwich Variety Pack ', Decimal('6')),
#  ('S0004', 'Nature Valley Chewy Trail Mix Bars', Decimal('25')),
#  ('S0004', 'Nature Valley Soft Oatmeal Squares   ', Decimal('22')),
#  ('S0004', 'Nature Valley Sweet/Salty Almond Bars      ', Decimal('28')),
#  ('S0004', 'Nature Valley Sweet/Salty Peanut Bars      ', Decimal('15')),
#  ('S0004', 'Nestle Purelife 16oz ', Decimal('26')),
#  ('S0004', 'Njoy Creamer Canister 16 oz', Decimal('35')),
#  ('S0004', 'Njoy Creamer Packs', Decimal('17')),
#  ('S0004', 'Njoy Sugar Canister 22 oz', Decimal('27')),
#  ('S0004', 'Ocean Spray Cranberry Juice Cocktail 15oz ', Decimal('59')),
#  ('S0004', 'Ozarka Spring Water 16.9 oz bottles', Decimal('22')),
#  ('S0004', 'Ozarka Spring Water 20 oz', Decimal('53')),
#  ('S0004', 'Ozarka Spring Water Mini 8oz', Decimal('58')),
#  ('S0004', 'Paper Bowls 20 oz Ultra Strong', Decimal('24')),
#  ('S0004', 'Paper Plate 10 inch Ultra Strong', Decimal('23')),
#  ('S0004', 'Paper Plates 7 inch  Ultra Strong', Decimal('22')),
#  ('S0004', 'Paper Plates 8.5 inch Ultra Strong', Decimal('48')),
#  ('S0004', 'Peanutbutter Filled Pretzels', Decimal('17')),
#  ('S0004', 'Peppermints Hard Candy', Decimal('4')),
#  ('S0004', 'Pepsi - 12 oz cans', Decimal('47')),
#  ('S0004', 'Perrier Flavors Sparkling Water 16.9oz', Decimal('10')),
#  ('S0004', 'Perrier Sparkling Water glass 11oz', Decimal('33')),
#  ('S0004', 'Perrier Sparkling Water plastic 16.9oz', Decimal('25')),
#  ('S0004', 'Planters Nut-trition 1.5 oz ', Decimal('25')),
#  ('S0004', 'Planters Nut Variety Packs', Decimal('26')),
#  ('S0004', 'Plastic Forks White Heavyweight', Decimal('39')),
#  ('S0004', 'Plastic Knives White  Heavyweight', Decimal('31')),
#  ('S0004', 'Plastic Spoons White  Heavyweight', Decimal('46')),
#  ('S0004', 'POM 2 ply paper towels', Decimal('36')),
#  ('S0004', 'Pop-Tarts, Brown Sugar Cinnamon ', Decimal('26')),
#  ('S0004', 'Pop-Tarts, Frosted Strawberry', Decimal('12')),
#  ('S0004', 'Pop Chips Variety bags', Decimal('14')),
#  ('S0004', 'Premier Protein Shake Choc. 11oz', Decimal('11')),
#  ('S0004', 'Pringles Snak Stacks Variety', Decimal('21')),
#  ('S0004', 'Propel Zero Variety 20 oz', Decimal('40')),
#  ('S0004', 'Pure Leaf Sweet Tea 8.5oz', Decimal('27')),
#  ('S0004', 'Pure Leaf Unsweetened Tea 18.5oz', Decimal('37')),
#  ('S0004', 'Pure White Sugar Packets', Decimal('37')),
#  ('S0004', 'Quaker Instant Oatmeal Maple Brn Sugar', Decimal('31')),
#  ('S0004', 'Quaker Instant Oatmeal Variety ', Decimal('15')),
#  ('S0004', 'Red Bull 12oz', Decimal('31')),
#  ('S0004', 'Red Bull 16oz', Decimal('25')),
#  ('S0004', 'Red Bull 8.4 oz', Decimal('42')),
#  ('S0004', 'Red Bull Sugar Free 8.4 oz', Decimal('16')),
#  ('S0004', 'Red Plastic Cups 18oz', Decimal('18')),
#  ('S0004', "Reese's Peanutbutter Cups 2/pk", Decimal('34')),
#  ('S0004', "Reese's Pieces Peanutbutter Candy", Decimal('43')),
#  ('S0004', 'San Pelligrino 16oz Plastic ', Decimal('41')),
#  ('S0004', 'Sargento Bal. Breaks (fruit, nut, cheese)', Decimal('27')),
#  ('S0004', 'Sargento String Cheese 0.75oz', Decimal('19')),
#  ('S0004', 'Seven Up - 12 oz cans', Decimal('32')),
#  ('S0004', 'Snapple Variety Pack 20oz', Decimal('27')),
#  ('S0004', 'Snickers Bars 1.8oz', Decimal('30')),
#  ('S0004', 'Snyders Pretzels Minis', Decimal('46')),
#  ('S0004', 'Sobe Zero Lifewater Variety 20 oz', Decimal('24')),
#  ('S0004', 'Splenda Sweetener', Decimal('37')),
#  ('S0004', 'Sprite - 12 oz cans', Decimal('68')),
#  ('S0004', 'Sprite Zero - 12 pack', Decimal('54')),
#  ('S0004', 'Spunkmeyer Muffin Variety', Decimal('27')),
#  ('S0004', "Starbuck's Pike Place", Decimal('5')),
#  ...]

# %%
df = pd.DataFrame(list(records), columns=['store_key', 'item_name','total_quantity'])
df.head(10)
# Out:
#   store_key                               item_name total_quantity
# 0     S0001         100% Juice Box Variety 6.75 oz              10
# 1     S0001              A&W Root Beer - 12 oz cans             60
# 2     S0001         A&W Root Beer Diet - 12 oz cans              8
# 3     S0001                    Advil 2 pill packets             28
# 4     S0001           All Purpose Cleaner 409 Spray             46
# 5     S0001             Altoids Small Packs Variety             13
# 6     S0001  Apple Sauce Variety GoGO Squeeze 3.2oz             37
# 7     S0001   AquaFina Purified Drinking Water 16oz             39
# 8     S0001           Austin Cookie Cracker Variety             10
# 9     S0001          Austin Toasty Crackers w/ PBtr             22

# %%
df.total_quantity.max()
# Out:
# Decimal('6000185')

# %%
grouped = df.groupby(['store_key','item_name']).agg({'total_quantity' : ['max']})
grouped
# Out:
#                                                 total_quantity
#                                                            max
# store_key item_name
# S0001     100% Juice Box Variety 6.75 oz                    10
#           A&W Root Beer - 12 oz cans                        60
#           A&W Root Beer Diet - 12 oz cans                    8
#           Advil 2 pill packets                              28
#           All Purpose Cleaner 409 Spray                     46
# ...                                                        ...
# S0099     Welch's 100% Juice Variety10 oz                   45
#           Wint O Green LifeSavers Sugar Free                47
#           Wonderful Pistachios (in shell)                   22
#           Yoplait Original Yogurt Variety Pack              29
#           Zoo Animal Cookies/Crackers                       45
#
# [187114 rows x 1 columns]

# %%
grouped.reset_index()
# Out:
#        store_key                              item_name total_quantity
#                                                                    max
# 0          S0001        100% Juice Box Variety 6.75 oz              10
# 1          S0001             A&W Root Beer - 12 oz cans             60
# 2          S0001        A&W Root Beer Diet - 12 oz cans              8
# 3          S0001                   Advil 2 pill packets             28
# 4          S0001          All Purpose Cleaner 409 Spray             46
# ...          ...                                    ...            ...
# 187109     S0099        Welch's 100% Juice Variety10 oz             45
# 187110     S0099     Wint O Green LifeSavers Sugar Free             47
# 187111     S0099        Wonderful Pistachios (in shell)             22
# 187112     S0099  Yoplait Original Yogurt Variety Pack              29
# 187113     S0099            Zoo Animal Cookies/Crackers             45
#
# [187114 rows x 3 columns]

# %% [markdown]
# ### What season(quarter) is the worst for each product item?

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "WITH grouped_sales AS (SELECT quarter, item_key, SUM(quantity) AS total_quantity FROM ecom_schema.fact_table f join ecom_schema.Time_dim t ON t.time_key = f.time_key GROUP BY item_key,quarter) SELECT CONCAT(s.item_key, '->',s.quarter, '(',total_quantity,')') FROM grouped_sales s JOIN (SELECT item_key, min(total_quantity) AS minq FROM grouped_sales s GROUP BY item_key) ss ON ss.item_key = s.item_key and s.total_quantity = ss.minq " 
        
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('I00001->Q2(5735)',),
#  ('I00002->Q4(5589)',),
#  ('I00003->Q3(5606)',),
#  ('I00004->Q4(5521)',),
#  ('I00005->Q2(5286)',),
#  ('I00006->Q2(5405)',),
#  ('I00007->Q2(5329)',),
#  ('I00008->Q1(5545)',),
#  ('I00009->Q4(5524)',),
#  ('I00010->Q4(5309)',),
#  ('I00011->Q1(5463)',),
#  ('I00012->Q1(5528)',),
#  ('I00013->Q2(5385)',),
#  ('I00014->Q3(5559)',),
#  ('I00015->Q4(5929)',),
#  ('I00016->Q4(5445)',),
#  ('I00017->Q1(5611)',),
#  ('I00018->Q1(5602)',),
#  ('I00019->Q4(5424)',),
#  ('I00020->Q2(5489)',),
#  ('I00021->Q4(5425)',),
#  ('I00022->Q1(5254)',),
#  ('I00023->Q2(5869)',),
#  ('I00024->Q4(5480)',),
#  ('I00025->Q1(5279)',),
#  ('I00026->Q2(5428)',),
#  ('I00027->Q1(5351)',),
#  ('I00028->Q4(5402)',),
#  ('I00029->Q2(5379)',),
#  ('I00030->Q3(5255)',),
#  ('I00031->Q4(5569)',),
#  ('I00032->Q2(5503)',),
#  ('I00033->Q1(5604)',),
#  ('I00034->Q3(5645)',),
#  ('I00035->Q4(5120)',),
#  ('I00036->Q4(5222)',),
#  ('I00037->Q2(5396)',),
#  ('I00038->Q2(5457)',),
#  ('I00039->Q1(5472)',),
#  ('I00040->Q1(5264)',),
#  ('I00041->Q4(5523)',),
#  ('I00042->Q1(5217)',),
#  ('I00043->Q1(5707)',),
#  ('I00044->Q1(5077)',),
#  ('I00045->Q4(5459)',),
#  ('I00046->Q1(5137)',),
#  ('I00047->Q1(5493)',),
#  ('I00048->Q4(5619)',),
#  ('I00049->Q4(5520)',),
#  ('I00050->Q1(5128)',),
#  ('I00051->Q2(5003)',),
#  ('I00052->Q4(5294)',),
#  ('I00053->Q4(5448)',),
#  ('I00054->Q2(5397)',),
#  ('I00055->Q1(5527)',),
#  ('I00056->Q1(5436)',),
#  ('I00057->Q4(5404)',),
#  ('I00058->Q1(5319)',),
#  ('I00059->Q3(5377)',),
#  ('I00060->Q1(5555)',),
#  ('I00061->Q1(5709)',),
#  ('I00062->Q1(5448)',),
#  ('I00063->Q3(5596)',),
#  ('I00064->Q2(5658)',),
#  ('I00065->Q2(5294)',),
#  ('I00066->Q1(5478)',),
#  ('I00067->Q2(5480)',),
#  ('I00068->Q3(5181)',),
#  ('I00069->Q1(5332)',),
#  ('I00070->Q3(5359)',),
#  ('I00071->Q2(5166)',),
#  ('I00072->Q1(5734)',),
#  ('I00073->Q1(5251)',),
#  ('I00074->Q2(5444)',),
#  ('I00075->Q4(5376)',),
#  ('I00076->Q4(5502)',),
#  ('I00077->Q1(5499)',),
#  ('I00078->Q2(5523)',),
#  ('I00079->Q1(5454)',),
#  ('I00080->Q3(5537)',),
#  ('I00081->Q2(5546)',),
#  ('I00082->Q1(5698)',),
#  ('I00083->Q3(5672)',),
#  ('I00084->Q1(5562)',),
#  ('I00085->Q1(5495)',),
#  ('I00086->Q4(5472)',),
#  ('I00087->Q4(5601)',),
#  ('I00088->Q2(5494)',),
#  ('I00089->Q1(5299)',),
#  ('I00090->Q2(5276)',),
#  ('I00091->Q3(5318)',),
#  ('I00092->Q1(5502)',),
#  ('I00093->Q4(5449)',),
#  ('I00094->Q4(5244)',),
#  ('I00095->Q1(5429)',),
#  ('I00096->Q1(5666)',),
#  ('I00097->Q1(5506)',),
#  ('I00098->Q4(5669)',),
#  ('I00099->Q1(5539)',),
#  ('I00100->Q2(5431)',),
#  ('I00101->Q3(5432)',),
#  ('I00102->Q1(5333)',),
#  ('I00103->Q4(5340)',),
#  ('I00104->Q2(5107)',),
#  ('I00105->Q1(5437)',),
#  ('I00106->Q1(5400)',),
#  ('I00107->Q2(5374)',),
#  ('I00108->Q4(5330)',),
#  ('I00109->Q2(5378)',),
#  ('I00110->Q4(5494)',),
#  ('I00111->Q1(5414)',),
#  ('I00112->Q1(5583)',),
#  ('I00113->Q2(5456)',),
#  ('I00114->Q3(5557)',),
#  ('I00115->Q3(5651)',),
#  ('I00116->Q2(5420)',),
#  ('I00117->Q2(5476)',),
#  ('I00118->Q4(5482)',),
#  ('I00119->Q1(5430)',),
#  ('I00120->Q2(5263)',),
#  ('I00121->Q1(5625)',),
#  ('I00122->Q3(5388)',),
#  ('I00123->Q1(5398)',),
#  ('I00124->Q2(5731)',),
#  ('I00125->Q2(5433)',),
#  ('I00126->Q4(5518)',),
#  ('I00127->Q2(5496)',),
#  ('I00128->Q1(5597)',),
#  ('I00129->Q4(5464)',),
#  ('I00130->Q1(5615)',),
#  ('I00131->Q4(5426)',),
#  ('I00132->Q4(5351)',),
#  ('I00133->Q3(5556)',),
#  ('I00134->Q1(5469)',),
#  ('I00135->Q2(5677)',),
#  ('I00136->Q2(5412)',),
#  ('I00137->Q3(5447)',),
#  ('I00138->Q3(5584)',),
#  ('I00139->Q2(5674)',),
#  ('I00140->Q2(5718)',),
#  ('I00141->Q1(5325)',),
#  ('I00142->Q2(5339)',),
#  ('I00143->Q4(5480)',),
#  ('I00144->Q1(5310)',),
#  ('I00145->Q4(5390)',),
#  ('I00146->Q1(5548)',),
#  ('I00147->Q2(5494)',),
#  ('I00148->Q1(5339)',),
#  ('I00149->Q4(5385)',),
#  ('I00150->Q2(5431)',),
#  ('I00151->Q2(5643)',),
#  ('I00152->Q1(5356)',),
#  ('I00153->Q4(5359)',),
#  ('I00154->Q2(5515)',),
#  ('I00155->Q2(5747)',),
#  ('I00156->Q4(5607)',),
#  ('I00157->Q1(5342)',),
#  ('I00158->Q3(5366)',),
#  ('I00159->Q2(5436)',),
#  ('I00160->Q3(5648)',),
#  ('I00161->Q1(5347)',),
#  ('I00162->Q1(5541)',),
#  ('I00163->Q1(5550)',),
#  ('I00164->Q3(5239)',),
#  ('I00165->Q3(5632)',),
#  ('I00166->Q1(5505)',),
#  ('I00167->Q4(5142)',),
#  ('I00168->Q1(5280)',),
#  ('I00169->Q4(5447)',),
#  ('I00170->Q1(5341)',),
#  ('I00171->Q1(5344)',),
#  ('I00172->Q3(5509)',),
#  ('I00173->Q2(5181)',),
#  ('I00174->Q1(5421)',),
#  ('I00175->Q3(5367)',),
#  ('I00176->Q4(5521)',),
#  ('I00177->Q1(5366)',),
#  ('I00178->Q2(5535)',),
#  ('I00179->Q2(5473)',),
#  ('I00180->Q1(5665)',),
#  ('I00181->Q2(5503)',),
#  ('I00182->Q4(5571)',),
#  ('I00183->Q2(5297)',),
#  ('I00184->Q1(5415)',),
#  ('I00185->Q4(5585)',),
#  ('I00186->Q4(5385)',),
#  ('I00187->Q1(5700)',),
#  ('I00188->Q3(5216)',),
#  ('I00189->Q2(5351)',),
#  ('I00190->Q1(5327)',),
#  ('I00191->Q2(5477)',),
#  ('I00192->Q1(5427)',),
#  ('I00193->Q1(5291)',),
#  ('I00194->Q1(5601)',),
#  ('I00195->Q2(5315)',),
#  ('I00196->Q4(5354)',),
#  ('I00197->Q3(5438)',),
#  ('I00198->Q2(5271)',),
#  ('I00199->Q4(5360)',),
#  ('I00200->Q2(5644)',),
#  ('I00201->Q2(5333)',),
#  ('I00202->Q2(5600)',),
#  ('I00203->Q2(5828)',),
#  ('I00204->Q3(5433)',),
#  ('I00205->Q2(5442)',),
#  ('I00206->Q1(5364)',),
#  ('I00207->Q1(5144)',),
#  ('I00208->Q1(5242)',),
#  ('I00209->Q2(5657)',),
#  ('I00210->Q1(5576)',),
#  ('I00211->Q1(5018)',),
#  ('I00212->Q2(5435)',),
#  ('I00213->Q1(5426)',),
#  ('I00214->Q3(5488)',),
#  ('I00215->Q4(5519)',),
#  ('I00216->Q1(5749)',),
#  ('I00217->Q1(5548)',),
#  ('I00218->Q4(5474)',),
#  ('I00219->Q1(5578)',),
#  ('I00220->Q1(5597)',),
#  ('I00221->Q2(5274)',),
#  ('I00222->Q1(5435)',),
#  ('I00223->Q1(5323)',),
#  ('I00224->Q2(5212)',),
#  ('I00225->Q3(5444)',),
#  ('I00226->Q3(5496)',),
#  ('I00227->Q2(5468)',),
#  ('I00228->Q2(5228)',),
#  ('I00229->Q2(5537)',),
#  ('I00230->Q3(5739)',),
#  ('I00231->Q2(5527)',),
#  ('I00232->Q2(5518)',),
#  ('I00233->Q1(5484)',),
#  ('I00234->Q1(5444)',),
#  ('I00235->Q1(5462)',),
#  ('I00236->Q3(5466)',),
#  ('I00237->Q2(5492)',),
#  ('I00238->Q3(5450)',),
#  ('I00239->Q4(5391)',),
#  ('I00240->Q2(5440)',),
#  ('I00241->Q4(5489)',),
#  ('I00242->Q4(5508)',),
#  ('I00243->Q1(5323)',),
#  ('I00244->Q1(5325)',),
#  ('I00245->Q4(5637)',),
#  ('I00246->Q2(5746)',),
#  ('I00247->Q1(5599)',),
#  ('I00248->Q3(5700)',),
#  ('I00249->Q3(5566)',),
#  ('I00250->Q2(5469)',),
#  ('I00251->Q4(5550)',),
#  ('I00252->Q1(5286)',),
#  ('I00253->Q1(5472)',),
#  ('I00254->Q1(5591)',),
#  ('I00255->Q1(5303)',),
#  ('I00256->Q1(5458)',),
#  ('I00257->Q2(5597)',),
#  ('I00258->Q1(5392)',),
#  ('I00259->Q2(5342)',),
#  ('I00260->Q3(5558)',),
#  ('I00261->Q2(5455)',),
#  ('I00262->Q2(5330)',),
#  ('I00263->Q1(5453)',),
#  ('I00264->Q3(5525)',)]

# %%
df = pd.DataFrame(list(records), columns=['worst season for each item'])
df.head(10)
# Out:
#   worst season for each item
# 0           I00001->Q2(5735)
# 1           I00002->Q4(5589)
# 2           I00003->Q3(5606)
# 3           I00004->Q4(5521)
# 4           I00005->Q2(5286)
# 5           I00006->Q2(5405)
# 6           I00007->Q2(5329)
# 7           I00008->Q1(5545)
# 8           I00009->Q4(5524)
# 9           I00010->Q4(5309)
