# %%
import psycopg2
import pandas as pd
import psycopg2.extras

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database = "ecomdb",
                                                  user = "postgres",
                                                  password = "sultanmahmud22",
                                                  host = "127.0.0.1",
                                                  port= "5432")
    def getConnection(self):
        print("Successfully connected to the database")
        return self.connection

# %%
con = PostgresConnection().getConnection()
# Out:
# Successfully connected to the database

# %%
Data_dir = "C:/Users/Nayan/Downloads/"

# %%
trans_dim = pd.read_excel(open(Data_dir + 'e-commerece_data.xlsx','rb'), sheet_name=1, engine='openpyxl')
trans_dim
# Out:
#    payment_key trans_type                                          bank_name
# 0         P001       cash                                               None
# 1         P002       card                                    AB Bank Limited
# 2         P003       card                   Bangladesh Commerce Bank Limited
# 3         P004       card                                  Bank Asia Limited
# 4         P005       card                                  BRAC Bank Limited
# 5         P006       card                              Citizens Bank Limited
# 6         P007       card                                  City Bank Limited
# 7         P008       card                  Community Bank Bangladesh Limited
# 8         P009       card                                 Dhaka Bank Limited
# 9         P010       card                          Dutch-Bangla Bank Limited
# 10        P011       card                               Eastern Bank Limited
# 11        P012       card                                  IFIC Bank Limited
# 12        P013       card                                Jamuna Bank Limited
# 13        P014       card                                Meghna Bank Limited
# 14        P015       card                            Mercantile Bank Limited
# 15        P016       card                               Midland Bank Limited
# 16        P017       card                             Modhumoti Bank Limited
# 17        P018       card                          Mutual Trust Bank Limited
# 18        P019       card                              National Bank Limited
# 19        P020       card            National Credit & Commerce Bank Limited
# 20        P021       card                                   NRB Bank Limited
# 21        P022       card                            NRB Commercial Bank Ltd
# 22        P023       card                                NRB Global Bank Ltd
# 23        P024       card                                   One Bank Limited
# 24        P025       card                                 Padma Bank Limited
# 25        P026       card                               Premier Bank Limited
# 26        P027       card                                 Prime Bank Limited
# 27        P028       card                                Pubali Bank Limited
# 28        P029       card                              Standard Bank Limited
# 29        P030       card                                  Shimanto Bank Ltd
# 30        P031       card                             Southeast Bank Limited
# 31        P032       card  South Bangla Agriculture and Commerce Bank Lim...
# 32        P033       card                                 Trust Bank Limited
# 33        P034       card                         United Commercial Bank Ltd
# 34        P035       card                                Uttara Bank Limited
# 35        P036       card                         Bengal Commercial Bank Ltd
# 36        P037     mobile                                              Bkash
# 37        P038     mobile                                             Rocket
# 38        P039     mobile                                              Nagad

# %%
insert_stmt = "INSERT INTO ecomdb_star_schema.Store_dim ( store_key, division, district, upazila)" \
            " VALUES (%s, %s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, trans_dim.values)
con.commit()
cur.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <module>
#       1 insert_stmt = "INSERT INTO ecomdb_star_schema.Store_dim ( store_key, division, district, upazila)" \
#       2             " VALUES (%s, %s, %s, %s)"
#       3 cur = con.cursor()
# ----> 4 psycopg2.extras.execute_batch(cur, insert_stmt, trans_dim.values)
#       5 con.commit()
#       6 cur.close()
#
# File ~\Desktop\myenv\lib\site-packages\psycopg2\extras.py:1186, in execute_batch(cur, sql, argslist, page_size)
#    1166 r"""Execute groups of statements in fewer server roundtrips.
#    1167
#    1168 Execute *sql* several times, against all parameters set (sequences or
#    (...)
#    1183
#    1184 """
#    1185 for page in _paginate(argslist, page_size=page_size):
# -> 1186     sqls = [cur.mogrify(sql, args) for args in page]
#    1187     cur.execute(b";".join(sqls))
#
# File ~\Desktop\myenv\lib\site-packages\psycopg2\extras.py:1186, in <listcomp>(.0)
#    1166 r"""Execute groups of statements in fewer server roundtrips.
#    1167
#    1168 Execute *sql* several times, against all parameters set (sequences or
#    (...)
#    1183
#    1184 """
#    1185 for page in _paginate(argslist, page_size=page_size):
# -> 1186     sqls = [cur.mogrify(sql, args) for args in page]
#    1187     cur.execute(b";".join(sqls))
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelbase.py", line 461, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelbase.py", line 450, in process_one
#     await dispatch(*args)
# TypeError: object NoneType can't be used in 'await' expression
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1101, in emit
#     stream.write(msg + self.terminator)
# OSError: [Errno 22] Invalid argument
# Call stack:
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelbase.py", line 463, in dispatch_queue
#     self.log.exception("Error in message handler")
# Message: 'Error in message handler'
# Arguments: ()

# %%
insert_stmt = "INSERT INTO ecomdb_star_schema.time_dim ( time_key, date, hour, day, week, month, quarter, year)" \
            " VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, trans_dim.values)
con.commit()
cur.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [9], in <module>
#       1 insert_stmt = "INSERT INTO ecomdb_star_schema.time_dim ( time_key, date, hour, day, week, month, quarter, year)" \
#       2             " VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
#       3 cur = con.cursor()
# ----> 4 psycopg2.extras.execute_batch(cur, insert_stmt, trans_dim.values)
#       5 con.commit()
#       6 cur.close()
#
# File ~\Desktop\myenv\lib\site-packages\psycopg2\extras.py:1186, in execute_batch(cur, sql, argslist, page_size)
#    1166 r"""Execute groups of statements in fewer server roundtrips.
#    1167
#    1168 Execute *sql* several times, against all parameters set (sequences or
#    (...)
#    1183
#    1184 """
#    1185 for page in _paginate(argslist, page_size=page_size):
# -> 1186     sqls = [cur.mogrify(sql, args) for args in page]
#    1187     cur.execute(b";".join(sqls))
#
# File ~\Desktop\myenv\lib\site-packages\psycopg2\extras.py:1186, in <listcomp>(.0)
#    1166 r"""Execute groups of statements in fewer server roundtrips.
#    1167
#    1168 Execute *sql* several times, against all parameters set (sequences or
#    (...)
#    1183
#    1184 """
#    1185 for page in _paginate(argslist, page_size=page_size):
# -> 1186     sqls = [cur.mogrify(sql, args) for args in page]
#    1187     cur.execute(b";".join(sqls))
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelbase.py", line 461, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelbase.py", line 450, in process_one
#     await dispatch(*args)
# TypeError: object NoneType can't be used in 'await' expression
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1101, in emit
#     stream.write(msg + self.terminator)
# OSError: [Errno 22] Invalid argument
# Call stack:
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\Nayan\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Nayan\Desktop\myenv\lib\site-packages\ipykernel\kernelbase.py", line 463, in dispatch_queue
#     self.log.exception("Error in message handler")
# Message: 'Error in message handler'
# Arguments: ()
