# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\administrator\.conda\envs\hda\lib\site-packages (2.9.3)Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\administrator\.conda\envs\hda\lib\site-packages (3.0.9)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: et-xmlfile in c:\users\administrator\.conda\envs\hda\lib\site-packages (from openpyxl) (1.1.0)

# %%
import psycopg2
import pandas as pd
import psycopg2.extras
import psycopg2

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database="ecomdb",
                                           user = "postgres",
                                           password = "123456",
                                           host = "127.0.0.1",
                                           port = "5433")

    def getConnection(self):
        print("successfully connected to database")
        return self.connection

# %%
con = PostgresConnection().getConnection()
# Out:
# successfully connected to database

# %%
cur = con.cursor()
select_stmt = "SELECT t.payment_key , t.trans_type, t.bank_name " \
              "FROM ecomdb_star_schema.trans_dim t"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# [('P001', 'cash', 'None'),
#  ('P002', 'card', 'AB Bank Limited'),
#  ('P003', 'card', 'Bangladesh Commerce Bank Limited'),
#  ('P004', 'card', 'Bank Asia Limited'),
#  ('P005', 'card', 'BRAC Bank Limited'),
#  ('P006', 'card', 'Citizens Bank Limited'),
#  ('P007', 'card', 'City Bank Limited'),
#  ('P008', 'card', 'Community Bank Bangladesh Limited'),
#  ('P009', 'card', 'Dhaka Bank Limited'),
#  ('P010', 'card', 'Dutch-Bangla Bank Limited'),
#  ('P011', 'card', 'Eastern Bank Limited'),
#  ('P012', 'card', 'IFIC Bank Limited'),
#  ('P013', 'card', 'Jamuna Bank Limited'),
#  ('P014', 'card', 'Meghna Bank Limited'),
#  ('P015', 'card', 'Mercantile Bank Limited'),
#  ('P016', 'card', 'Midland Bank Limited'),
#  ('P017', 'card', 'Modhumoti Bank Limited'),
#  ('P018', 'card', 'Mutual Trust Bank Limited'),
#  ('P019', 'card', 'National Bank Limited'),
#  ('P020', 'card', 'National Credit & Commerce Bank Limited'),
#  ('P021', 'card', 'NRB Bank Limited'),
#  ('P022', 'card', 'NRB Commercial Bank Ltd'),
#  ('P023', 'card', 'NRB Global Bank Ltd'),
#  ('P024', 'card', 'One Bank Limited'),
#  ('P025', 'card', 'Padma Bank Limited'),
#  ('P026', 'card', 'Premier Bank Limited'),
#  ('P027', 'card', 'Prime Bank Limited'),
#  ('P028', 'card', 'Pubali Bank Limited'),
#  ('P029', 'card', 'Standard Bank Limited'),
#  ('P030', 'card', 'Shimanto Bank Ltd'),
#  ('P031', 'card', 'Southeast Bank Limited'),
#  ('P032', 'card', 'South Bangla Agriculture and Commerce Bank Limited'),
#  ('P033', 'card', 'Trust Bank Limited'),
#  ('P034', 'card', 'United Commercial Bank Ltd'),
#  ('P035', 'card', 'Uttara Bank Limited'),
#  ('P036', 'card', 'Bengal Commercial Bank Ltd'),
#  ('P037', 'mobile', 'Bkash'),
#  ('P038', 'mobile', 'Rocket'),
#  ('P039', 'mobile', 'Nagad')]

# %%
trans_df = pd.DataFrame(list(records), columns=['payment_key', 'trans_type', 'bank_name'])
trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   payment_key  39 non-null     object
#  1   trans_type   39 non-null     object
#  2   bank_name    39 non-null     object
# dtypes: object(3)
# memory usage: 1.0+ KB

# %% [markdown]
# ### Simple queries

# %%
cur = con.cursor()
select_query = "select s.division , sum(f.total_price)\
                from ecomdb.fact_table f \
                join ecomdb.store_dim s on s.store_key = f.store_key \
                group by (s.division)\
                order by s.division"
cur.execute(select_query)
records = cur.fetchall()
records
# Out:
# [('BARISAL', Decimal('7520343.75')),
#  ('CHITTAGONG', Decimal('19763595.00')),
#  ('DHAKA', Decimal('40764619.75')),
#  ('KHULNA', Decimal('11311610.50')),
#  ('RAJSHAHI', Decimal('12099196.00')),
#  ('RANGPUR', Decimal('8429836.50')),
#  ('SYLHET', Decimal('5512234.25'))]

# %%
query_1 = pd.DataFrame(list(records),columns = ['division','total_price'])
query_1.head()
# query_1['total_price'] = query_1['total_price'].astype('Int64')
query_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   division     7 non-null      object
#  1   total_price  7 non-null      object
# dtypes: object(2)
# memory usage: 240.0+ bytes

# %%
query_1.head()
# Out:
#      division  total_price
# 0     BARISAL   7520343.75
# 1  CHITTAGONG  19763595.00
# 2       DHAKA  40764619.75
# 3      KHULNA  11311610.50
# 4    RAJSHAHI  12099196.00

# %%
query_1['total_price'] = query_1['total_price'].astype(int)
query_1.head()
# Out:
#      division  total_price
# 0     BARISAL      7520343
# 1  CHITTAGONG     19763595
# 2       DHAKA     40764619
# 3      KHULNA     11311610
# 4    RAJSHAHI     12099196

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.pie(query_1.total_price, labels = query_1.division)
# plt.pie(query_1.total_price,query_1.division)
plt.legend()
plt.show()

# %%
cur = con.cursor()
select_query = "select c.name , sum(f.total_price)\
                from ecomdb.fact_table f \
                join ecomdb.coustomer_dim c on c.coustomer_key = f.coustomer_key \
                group by (c.name)"
cur.execute(select_query)
records = cur.fetchall()
records
# Out:
# [('maina devi', Decimal('13636.50')),
#  ('pratibha devi', Decimal('12703.25')),
#  ('mohit maan', Decimal('11591.00')),
#  ('tumpa mundal', Decimal('14591.00')),
#  ('suman devi', Decimal('21477.75')),
#  ('vinod lal', Decimal('10491.00')),
#  ('rajinder kaur', Decimal('10767.75')),
#  ('smt shiya', Decimal('12024.75')),
#  ('sujanti', Decimal('9944.00')),
#  ('partima', Decimal('33390.50')),
#  ('amarjit kaur with a child keshav', Decimal('12527.25')),
#  ('labbhi', Decimal('11553.25')),
#  ('nikil mishra', Decimal('11684.75')),
#  ('prem bai', Decimal('12873.75')),
#  ('poneem', Decimal('24555.75')),
#  ('sazi', Decimal('10968.50')),
#  ('rozi sharma', Decimal('9240.00')),
#  ('phoolmani', Decimal('10045.25')),
#  ('rishab', Decimal('11160.00')),
#  ('smt. neelam', Decimal('13669.25')),
#  ('payal kanvar', Decimal('11588.25')),
#  ('kumari shilpa', Decimal('10500.50')),
#  ('laxmi deve', Decimal('11816.50')),
#  ('hailena', Decimal('11818.00')),
#  ('jyotsana @ jyoti', Decimal('20798.00')),
#  ('kalpeshwari devi', Decimal('12977.00')),
#  ('balraj', Decimal('12382.50')),
#  ('divya', Decimal('141108.25')),
#  ('tabwsum', Decimal('10555.25')),
#  ('kamala', Decimal('11397.50')),
#  ('fauina', Decimal('13267.00')),
#  ('kajal@sundri', Decimal('12202.00')),
#  ('rimzim', Decimal('8630.00')),
#  ('priti yadav', Decimal('12543.00')),
#  ('kanchan devi', Decimal('10365.50')),
#  ('anupam', Decimal('12371.75')),
#  ('muli', Decimal('11237.00')),
#  ('reeta kapkoti', Decimal('11753.50')),
#  ('km. pooja', Decimal('8787.75')),
#  ('reena @ laxmi', Decimal('10583.50')),
#  ('vishakha anand', Decimal('13556.00')),
#  ('aparna', Decimal('11133.50')),
#  ('nisha@neelam', Decimal('10354.75')),
#  ('bala devi', Decimal('33180.50')),
#  ('vivek auhari', Decimal('13172.50')),
#  ('geeta rani', Decimal('9073.75')),
#  ('ruksana bi', Decimal('10942.75')),
#  ('kumkum', Decimal('45060.00')),
#  ('varsha', Decimal('207774.50')),
#  ('kiran d/o suraj prashad', Decimal('12706.00')),
#  ('kali devi', Decimal('11977.50')),
#  ('nikhat', Decimal('14872.5')),
#  ('neharika @ neha', Decimal('11201.75')),
#  ('zahira', Decimal('9260.50')),
#  ('rishi kakdia', Decimal('12299.50')),
#  ('mohd. firoz', Decimal('11635.50')),
#  ('narbada', Decimal('10159.25')),
#  ('kamlesh gupta', Decimal('11575.25')),
#  ('diksha soni', Decimal('12496.50')),
#  ('w/o kundan kumar', Decimal('10560.25')),
#  ('mamta garg', Decimal('11330.75')),
#  ('champa karketta', Decimal('11673.00')),
#  ('chanchal @ komal', Decimal('10648.75')),
#  ('jasleen kaur', Decimal('14111.75')),
#  ('bhumika chettri', Decimal('12929.25')),
#  ('shiva singh', Decimal('9816.25')),
#  ('anuu', Decimal('12138.00')),
#  ('surti kumari', Decimal('8839.50')),
#  ('nandita', Decimal('15116.00')),
#  ('sukhdev', Decimal('10714.00')),
#  ('twinkle', Decimal('10830.25')),
#  ('dhana devi', Decimal('13092.00')),
#  ('manju roy', Decimal('10418.25')),
#  ('vinod kumar', Decimal('22981.00')),
#  ('kavit goyar', Decimal('10643.00')),
#  ('nirvat', Decimal('8400.00')),
#  ('chanda', Decimal('35412.00')),
#  ('pankaj', Decimal('22595.00')),
#  ('manita', Decimal('11254.50')),
#  ('prakul', Decimal('8267.75')),
#  ('manisha rani', Decimal('12999.25')),
#  ('inder dutt', Decimal('12150.00')),
#  ('charan jeet singh', Decimal('10110.00')),
#  ('bindiya', Decimal('13803.00')),
#  ('dhakhadevi', Decimal('11610.75')),
#  ('roshni kumari', Decimal('13375.75')),
#  ('azmira', Decimal('10917.25')),
#  ('kumari neha', Decimal('34344.00')),
#  ('ramesh  dutt', Decimal('9752.75')),
#  ('samman', Decimal('11926.75')),
#  ('badru nisha', Decimal('12509.25')),
#  ('kamini devi', Decimal('9643.75')),
#  ('tabssum @ gudiya', Decimal('11075.75')),
#  ('sudma aggarwal', Decimal('8672.25')),
#  ('mem', Decimal('11802.75')),
#  ('rizwana khatun', Decimal('12199.25')),
#  ('pooja kanwar', Decimal('22380.00')),
#  ('munna lal', Decimal('14139.25')),
#  ('kumari lelina', Decimal('11569.25')),
#  ('mandeep kaur', Decimal('10579.75')),
#  ('leena', Decimal('21102.00')),
#  ('kumari radha', Decimal('23106.50')),
#  ('suman uppal', Decimal('11555.25')),
#  ('tara d/o shivmurti', Decimal('10446.75')),
#  ('kooki', Decimal('9786.25')),
#  ('km simarjeet kaur', Decimal('10744.25')),
#  ('tulsi', Decimal('69190.00')),
#  ('hemlata @ pooja', Decimal('12291.00')),
#  ('monu', Decimal('23251.75')),
#  ('laxita', Decimal('9050.50')),
#  ('shikha rai', Decimal('12310.75')),
#  ('babita negi', Decimal('10792.75')),
#  ('chango uraon', Decimal('13139.75')),
#  ('punam kumari', Decimal('10706.25')),
#  ('smt meenakshi', Decimal('13361.75')),
#  ('preet', Decimal('11232.50')),
#  ('satnam kaur', Decimal('10404.25')),
#  ('priya kumar', Decimal('13260.25')),
#  ('smt seema', Decimal('22859.50')),
#  ('smt. vidhya tiwari', Decimal('11879.00')),
#  ('parbha devi', Decimal('9505.00')),
#  ('reeta @ rachna', Decimal('12435.50')),
#  ('gaurav sethi', Decimal('10467.25')),
#  ('zainab', Decimal('11423.75')),
#  ('hema sharma', Decimal('12183.25')),
#  ('gulfara', Decimal('10582.25')),
#  ('tanuja devi', Decimal('14587.75')),
#  ('krishna with two child', Decimal('15203.00')),
#  ('mukesh', Decimal('22141.00')),
#  ('arvind agarwal @ pinto', Decimal('11405.25')),
#  ('mukesh devi', Decimal('11973.25')),
#  ('smt puja', Decimal('24339.50')),
#  ('geeta kumari', Decimal('13106.00')),
#  ('smt. pinki bai', Decimal('13929.25')),
#  ('ruksana bano', Decimal('23973.75')),
#  ('kailash kumar', Decimal('12120.25')),
#  ('shsi kant', Decimal('10970.75')),
#  ('sheela', Decimal('84154.25')),
#  ('surjeet kaur', Decimal('9325.00')),
#  ('mayank chaudhary @ rahul', Decimal('11112.25')),
#  ('parash das', Decimal('9654.00')),
#  ('sujen manjhi', Decimal('10627.50')),
#  ('palvinder kaur', Decimal('11816.25')),
#  ('shrimati maya devi', Decimal('11651.00')),
#  ('mukhtyar hussain', Decimal('10844.25')),
#  ('samina', Decimal('12408.25')),
#  ('meenu devi', Decimal('11222.00')),
#  ('sita kumari', Decimal('13643.75')),
#  ('bina bai', Decimal('11717.00')),
#  ('luxmi', Decimal('8879.25')),
#  ('komal bharti', Decimal('22216.25')),
#  ('seekha', Decimal('13196.50')),
#  ('kumari rani', Decimal('25040.75')),
#  ('ku-pooja', Decimal('11631.25')),
#  ('sunarkali', Decimal('12054.25')),
#  ('sapana sharma', Decimal('12820.50')),
#  ('minkashi', Decimal('16154.50')),
#  ('binita', Decimal('12706.25')),
#  ('suhani singhal', Decimal('12009.25')),
#  ('anushka sharma @ pooja', Decimal('12582.00')),
#  ('aafrin @ dolly', Decimal('23529.75')),
#  ('kohinoor', Decimal('11231.75')),
#  ('honey', Decimal('10630.50')),
#  ('jatin @ sonu', Decimal('11169.00')),
#  ('kumari sabnam @ monu', Decimal('13377.50')),
#  ('nirmla', Decimal('50820.75')),
#  ('tina', Decimal('70276.50')),
#  ('long shree devi', Decimal('11918.00')),
#  ('smt saraswati devi', Decimal('9587.00')),
#  ('shipra', Decimal('35834.00')),
#  ('laxmi @ lalita', Decimal('12087.00')),
#  ('kiran bala', Decimal('8705.00')),
#  ('diksha gupta', Decimal('12830.25')),
#  ('hasina bano', Decimal('10703.50')),
#  ('dharmender', Decimal('20574.00')),
#  ('nabila', Decimal('9808.50')),
#  ('sheensar pal', Decimal('9922.00')),
#  ('nini', Decimal('12859.75')),
#  ('aarti diwakar', Decimal('10892.00')),
#  ('ravinder @ bacchi', Decimal('11482.50')),
#  ('vishal mishra', Decimal('12376.75')),
#  ('mony', Decimal('9250.75')),
#  ('geetanjali', Decimal('13483.75')),
#  ('manish kumar saket', Decimal('10043.25')),
#  ('mooli devi', Decimal('11240.75')),
#  ('-', Decimal('20643.50')),
#  ('jaydurga', Decimal('11873.50')),
#  ('shaheen', Decimal('11679.00')),
#  ('badami', Decimal('10743.25')),
#  ('sangeeta jan', Decimal('12830.00')),
#  ('bhawana @ shannu', Decimal('14496.75')),
#  ('ku. shabnam', Decimal('11284.25')),
#  ('annavi begam', Decimal('10893.75')),
#  ('sunita rani', Decimal('9991.50')),
#  ('susila rawat or arti rawat', Decimal('11499.25')),
#  ('payana nagar', Decimal('10350.25')),
#  ('radheshyam sen', Decimal('12875.50')),
#  ('anuradha @ anu', Decimal('11305.75')),
#  ('amiraka', Decimal('10471.00')),
#  ('smt lali devi', Decimal('11039.25')),
#  ('dharma devi', Decimal('13768.50')),
#  ('durga kumari', Decimal('23915.75')),
#  ('sunil', Decimal('21069.25')),
#  ('chandra kala', Decimal('20311.00')),
#  ('parvesh kumari', Decimal('10684.75')),
#  ('vimla devi', Decimal('11400.00')),
#  ('navita', Decimal('9631.50')),
#  ('vashudev', Decimal('13774.50')),
#  ('mala devi @ nisha', Decimal('12132.00')),
#  ('smt rukshana', Decimal('13173.50')),
#  ('mustki begam', Decimal('12371.00')),
#  ('shalini @ shallu', Decimal('13048.75')),
#  ('smt nargish', Decimal('10360.50')),
#  ('kafia', Decimal('12889.25')),
#  ('babli d/o suresh', Decimal('11489.00')),
#  ('maina d/o ratna lal  gurjar', Decimal('10300.25')),
#  ('aleesha', Decimal('10920.75')),
#  ('deepti bhargav', Decimal('12483.00')),
#  ('pooja gop', Decimal('13302.50')),
#  ('saral', Decimal('12090.50')),
#  ('gudiya kumari', Decimal('34948.75')),
#  ('shakeena', Decimal('13321.25')),
#  ('astha', Decimal('13235.50')),
#  ('malvika', Decimal('11204.50')),
#  ('kamlesh with her two child lucky & vanshika', Decimal('14194.00')),
#  ('teena', Decimal('12658.00')),
#  ('sonam', Decimal('283012.50')),
#  ('pinki chanda', Decimal('9985.50')),
#  ('monu kumar', Decimal('10408.50')),
#  ('sujata dhawan', Decimal('8095.75')),
#  ('manmeet kaur', Decimal('11675.00')),
#  ('puspa mintiz', Decimal('12818.25')),
#  ('priya gupta', Decimal('10899.25')),
#  ('kushum @ khushbu', Decimal('11050.75')),
#  ('rojmen', Decimal('11897.25')),
#  ('shahida', Decimal('12614.00')),
#  ('laxmi bai', Decimal('10483.50')),
#  ('shravani shah', Decimal('10415.00')),
#  ('mariyam @ sonam', Decimal('13479.00')),
#  ('iesha', Decimal('10816.00')),
#  ('anita kunwar', Decimal('8793.75')),
#  ('bahalen angriya', Decimal('14463.50')),
#  ('shamina', Decimal('9708.75')),
#  ('gona bai', Decimal('12139.25')),
#  ('km0 reena', Decimal('10452.00')),
#  ('rajmani', Decimal('13275.75')),
#  ('laxmi @ roma', Decimal('11232.25')),
#  ('kaushaliya', Decimal('12477.00')),
#  ('rupen gore', Decimal('12140.25')),
#  ('vibha', Decimal('11942.50')),
#  ('daulat banno', Decimal('12134.50')),
#  ('mehnaj', Decimal('9905.75')),
#  ('heera lal @ sunil kanojia', Decimal('10708.50')),
#  ('ranju kumari', Decimal('13422.50')),
#  ('arsi', Decimal('38193.25')),
#  ('santosh', Decimal('143206.00')),
#  ('jenifer', Decimal('10750.50')),
#  ('radha d/o', Decimal('10165.25')),
#  ('sanju urf sanjya', Decimal('10935.50')),
#  ('shikha soni', Decimal('8832.25')),
#  ('ram pyare', Decimal('10213.50')),
#  ('harishankar verma', Decimal('11801.50')),
#  ('antim', Decimal('10247.50')),
#  ('prinka jha', Decimal('11637.75')),
#  ('smt renu', Decimal('13263.50')),
#  ('heena parveen', Decimal('11864.00')),
#  ('khurshida bano', Decimal('11905.25')),
#  ('nesha', Decimal('13554.25')),
#  ('kumari deepa', Decimal('10341.00')),
#  ('kailash kour d/0 pooran r/o ghamudki ps sikri', Decimal('10239.25')),
#  ('devender kaur', Decimal('13407.50')),
#  ('milan', Decimal('12154.00')),
#  ('nagma', Decimal('93396.00')),
#  ('rajeshwari', Decimal('22339.75')),
#  ('manlisa bairwa', Decimal('10481.50')),
#  ('manju devi', Decimal('71865.75')),
#  ('utpana davi', Decimal('13750.25')),
#  ('jayanti @ pooja', Decimal('13269.00')),
#  ('razni', Decimal('12181.25')),
#  ('kumari praya', Decimal('12535.50')),
#  ('kanta devi', Decimal('23450.25')),
#  ('chandabai', Decimal('11621.50')),
#  ('mosmi sekh', Decimal('11210.00')),
#  ('lali', Decimal('33844.00')),
#  ('sangita devi with daughter sonia 3yrs 6month, and', Decimal('12185.25')),
#  ('sirish', Decimal('12244.25')),
#  ('shrabani saha', Decimal('13545.00')),
#  ('manisha patidar', Decimal('10369.50')),
#  ('kali charan', Decimal('14018.75')),
#  ('ranjana singh', Decimal('10799.50')),
#  ('ajju @ rubi', Decimal('13142.00')),
#  ('rekha meena', Decimal('8678.50')),
#  ('asha naidu', Decimal('12977.50')),
#  ('jaimati', Decimal('11507.25')),
#  ('kumari priyanka', Decimal('12529.50')),
#  ('koyali', Decimal('13793.75')),
#  ('rajni dhawan', Decimal('8280.00')),
#  ('preti', Decimal('9949.00')),
#  ('baita', Decimal('11485.25')),
#  ('simran dhawan', Decimal('13068.75')),
#  ('mohit @ himanshu', Decimal('11787.50')),
#  ('veeru kumari', Decimal('10525.50')),
#  ('shree susila bali', Decimal('11054.50')),
#  ('somi toddu', Decimal('10604.25')),
#  ('seetal', Decimal('22821.25')),
#  ('sachi', Decimal('12863.50')),
#  ('rehmati', Decimal('12287.00')),
#  ('renu joshi', Decimal('11830.50')),
#  ('bharti kumari', Decimal('11651.00')),
#  ('km0 shilpa', Decimal('14065.25')),
#  ('shabana begam', Decimal('9321.00')),
#  ('anwari', Decimal('10334.25')),
#  ('kaushar', Decimal('13754.50')),
#  ('sunita kumawat', Decimal('13360.50')),
#  ('shobha', Decimal('81525.00')),
#  ('kumari shri devi', Decimal('12035.50')),
#  ('kumari pallavi', Decimal('9161.50')),
#  ('sudesh', Decimal('35243.00')),
#  ('sunder', Decimal('11787.25')),
#  ('rozi', Decimal('24627.25')),
#  ('priya devi', Decimal('9230.0')),
#  ('smt. seema pandya', Decimal('8005.00')),
#  ('biwa kumari', Decimal('10478.25')),
#  ('anamika', Decimal('32869.25')),
#  ('shashi kala', Decimal('10837.25')),
#  ('mohsina begum', Decimal('9112.00')),
#  ('meti kumari', Decimal('36123.25')),
#  ('simmy m.no.-7206252659.', Decimal('11386.25')),
#  ('veera devi', Decimal('9603.25')),
#  ('vyelet moni', Decimal('10334.75')),
#  ('miss madhu meghwal', Decimal('11597.50')),
#  ('nandini devi (  with child 2 year shivam )', Decimal('10407.25')),
#  ('sushmita', Decimal('9743.25')),
#  ('smt gita', Decimal('23729.50')),
#  ('kali', Decimal('56673.75')),
#  ('rishma ali', Decimal('10091.25')),
#  ('gajender kumar', Decimal('11107.00')),
#  ('paramdeep kaur', Decimal('11928.25')),
#  ('bhagwati@shinnu', Decimal('23870.75')),
#  ('amit kumar', Decimal('33324.75')),
#  ('chuni devi', Decimal('13726.50')),
#  ('alisha loomba', Decimal('11646.75')),
#  ('isika', Decimal('9362.00')),
#  ('neelam with 4 years baby sukhmani', Decimal('9250.25')),
#  ('lalita kumari', Decimal('11090.50')),
#  ('diksha', Decimal('33496.00')),
#  ('shankar', Decimal('9946.00')),
#  ('smt premkanta', Decimal('11974.75')),
#  ('smt. susheela', Decimal('11314.75')),
#  ('naziya siddiqui', Decimal('11250.25')),
#  ('noor jah', Decimal('10018.00')),
#  ('puja kanvar', Decimal('9032.50')),
#  ('anju jain', Decimal('21292.25')),
#  ('savrin', Decimal('10971.75')),
#  ('anita vyas', Decimal('10469.00')),
#  ('ku. sandiya', Decimal('10689.75')),
#  ('sahna', Decimal('11794.00')),
#  ('ms. deepa', Decimal('12889.50')),
#  ('adnan', Decimal('11681.75')),
#  ('santosh singal', Decimal('13146.50')),
#  ('vibhuti shyamal', Decimal('10745.25')),
#  ('dropti raiger', Decimal('8138.50')),
#  ('rajiya', Decimal('22432.50')),
#  ('radhabai', Decimal('11763.00')),
#  ('sweta kumari', Decimal('10741.50')),
#  ('deepika age 18', Decimal('10584.00')),
#  ('mamoita rai', Decimal('9538.25')),
#  ('sandhya', Decimal('155772.25')),
#  ('kangana', Decimal('12520.75')),
#  ('saahin', Decimal('11072.50')),
#  ('saiesta', Decimal('11211.75')),
#  ('smt. shakuntla devi', Decimal('15922.00')),
#  ('matul  devi', Decimal('12134.75')),
#  ('annu sharma', Decimal('26798.00')),
#  ('puspha', Decimal('11461.25')),
#  ('hemlata', Decimal('157712.50')),
#  ('kumari nenu', Decimal('9624.00')),
#  ('vijayanta', Decimal('9504.25')),
#  ('laxami', Decimal('23530.50')),
#  ('safina malik', Decimal('11879.50')),
#  ('rita devi', Decimal('23997.75')),
#  ('smt dhakha devi', Decimal('11949.50')),
#  ('vijay lakshmi', Decimal('10531.75')),
#  ('sazia praveen', Decimal('12582.00')),
#  ('pooja panwar', Decimal('9394.50')),
#  ('smt. sushma', Decimal('23308.75')),
#  ('manish kumar', Decimal('9495.50')),
#  ('fakiha', Decimal('14436.00')),
#  ('gayatri @ rani', Decimal('11565.75')),
#  ('कु0 शशि रì', Decimal('8631.75')),
#  ('lad bai', Decimal('12114.00')),
#  ('farida', Decimal('18309.75')),
#  ('mitali sahu', Decimal('11944.00')),
#  ('niranjan', Decimal('24901.25')),
#  ('parmila', Decimal('11055.00')),
#  ('gaytri bai', Decimal('22826.00')),
#  ('mamuna @ dholi', Decimal('10621.25')),
#  ('parul', Decimal('55452.75')),
#  ('revti', Decimal('8144.75')),
#  ('ankit tiwari', Decimal('11817.75')),
#  ('chandni @ shabnam', Decimal('12880.75')),
#  ('sone lal shah', Decimal('10820.75')),
#  ('ankita', Decimal('23757.25')),
#  ('pinku devi with daughter mansi kumari', Decimal('12029.00')),
#  ('darshna', Decimal('10286.00')),
#  ('kuldeep', Decimal('32640.75')),
#  ('dev kanwar', Decimal('10702.25')),
#  ('vipol', Decimal('11495.00')),
#  ('manni @ manish', Decimal('11992.25')),
#  ('nazmin', Decimal('14319.75')),
#  ('sonu', Decimal('132820.50')),
#  ('anita @ manju', Decimal('11814.00')),
#  ('reema', Decimal('52517.25')),
#  ('arti devi with two child dhanraj & anushka', Decimal('10879.75')),
#  ('rinki', Decimal('225126.75')),
#  ('deep', Decimal('12199.00')),
#  ('felicia sequeira', Decimal('11385.50')),
#  ('lalita sharma', Decimal('10566.75')),
#  ('gopal sharma', Decimal('12722.75')),
#  ('ravita  @ shyamwati', Decimal('11531.75')),
#  ('bhateri @ bhawna', Decimal('9499.25')),
#  ('girishchandra', Decimal('11208.25')),
#  ('phalguni', Decimal('9915.25')),
#  ('sangeena', Decimal('11260.50')),
#  ('meera', Decimal('103227.00')),
#  ('neha kumari', Decimal('33620.75')),
#  ('smt suman', Decimal('23952.75')),
#  ('neha singh @ nanu', Decimal('12846.00')),
#  ('smt. dayavati', Decimal('12414.50')),
#  ('nahid @ shabia', Decimal('10139.25')),
#  ('versha chandera', Decimal('12083.75')),
#  ('bhavana', Decimal('23683.75')),
#  ('pooja ( with child )', Decimal('11348.25')),
#  ('mithi urf mamta', Decimal('11772.00')),
#  ('nisha', Decimal('685782.25')),
#  ('tehmina', Decimal('10926.00')),
#  ('smt nazama', Decimal('9099.25')),
#  ('kushmita', Decimal('14123.00')),
#  ('santosh with a child rishi kumar', Decimal('10319.00')),
#  ('ashman praveen', Decimal('9919.75')),
#  ('inderjeet', Decimal('10278.75')),
#  ('azruddin', Decimal('10852.00')),
#  ('laxmi narayan', Decimal('11728.00')),
#  ('pooja sharma', Decimal('20718.25')),
#  ('samreen', Decimal('53617.00')),
#  ('disi nang @ manju', Decimal('10642.00')),
#  ('rumal  kumari', Decimal('10394.50')),
#  ('abhishekh', Decimal('11776.00')),
#  ('gulafsha', Decimal('12589.00')),
#  ('megha alongwith daughter 6 month', Decimal('9406.00')),
#  ('shilpi kumari', Decimal('10094.25')),
#  ('karan', Decimal('35057.00')),
#  ('usha damor', Decimal('12099.25')),
#  ('bhola sarkar', Decimal('10300.75')),
#  ('darkash', Decimal('10639.75')),
#  ('gori', Decimal('22718.75')),
#  ('veena tandan', Decimal('11685.00')),
#  ('harprit', Decimal('12396.00')),
#  ('ritu', Decimal('200073.75')),
#  ('smt neelam', Decimal('21853.50')),
#  ('rashid@robhi', Decimal('10144.50')),
#  ('rekha rani', Decimal('11873.75')),
#  ('smt. balti', Decimal('11918.50')),
#  ('kulsum', Decimal('11302.00')),
#  ('amanjeet kour', Decimal('24521.75')),
#  ('nirjla devi', Decimal('9417.25')),
#  ('rukmani', Decimal('44442.25')),
#  ('navdeep kaur', Decimal('11386.00')),
#  ('ankita singh', Decimal('9222.50')),
#  ('anshika', Decimal('37625.75')),
#  ('babloo', Decimal('11489.25')),
#  ('gulista', Decimal('20016.50')),
#  ('chhotelal', Decimal('9726.75')),
#  ('miss. meera', Decimal('11986.00')),
#  ('anguri bai', Decimal('10959.00')),
#  ('pratibha', Decimal('21776.25')),
#  ('gyarsi devi', Decimal('12375.25')),
#  ('kushum', Decimal('23044.00')),
#  ('seema', Decimal('813087.75')),
#  ('bohati devi', Decimal('11692.25')),
#  ('sufiya', Decimal('12238.00')),
#  ('smt. kavita bai', Decimal('12580.00')),
#  ('dhamini', Decimal('12196.75')),
#  ('bhagwati @ bhagoti devi', Decimal('11602.25')),
#  ('silpi kumari', Decimal('13238.75')),
#  ('najma', Decimal('23131.75')),
#  ('priya mali', Decimal('10320.25')),
#  ('tamanna banu', Decimal('9693.50')),
#  ('senthia', Decimal('10138.50')),
#  ('prinka', Decimal('11738.50')),
#  ('pritam singh', Decimal('11024.00')),
#  ('gajana devi', Decimal('11368.50')),
#  ('satender', Decimal('11539.50')),
#  ('reena', Decimal('470304.25')),
#  ('poornima', Decimal('10934.00')),
#  ('mousam', Decimal('12196.00')),
#  ('manju jha', Decimal('11247.50')),
#  ('jyoti tiwari', Decimal('10269.75')),
#  ('ranjita devi and his son priyanshu age 2,1/2 yrs', Decimal('12047.00')),
#  ('sharda devi', Decimal('23678.25')),
#  ('shahnaz', Decimal('10769.50')),
#  ('parerna', Decimal('8240.00')),
#  ('imaman khatoon', Decimal('13307.00')),
#  ('ashu', Decimal('49442.75')),
#  ('smt. sheetal', Decimal('10897.25')),
#  ('shanti', Decimal('53408.00')),
#  ('gulam rashul', Decimal('10011.25')),
#  ('jareena', Decimal('11853.25')),
#  ('sushhmita dass and his son ayush dass', Decimal('12067.75')),
#  ('ku. reetu', Decimal('13047.75')),
#  ('km. rekha chilwal', Decimal('10547.25')),
#  ('sarla', Decimal('31270.25')),
#  ('durga devi', Decimal('24379.25')),
#  ('nancy', Decimal('13108.25')),
#  ('bilal malik', Decimal('9654.75')),
#  ('pryanka god', Decimal('10944.25')),
#  ('nirjala', Decimal('10250.50')),
#  ('faijina', Decimal('11253.25')),
#  ('bhuri vishnaw', Decimal('11338.25')),
#  ('poonam das', Decimal('10372.50')),
#  ('sanjay kumar s/o', Decimal('8869.25')),
#  ('dinesh singh rana', Decimal('10701.25')),
#  ('richa', Decimal('30173.00')),
#  ('ishika', Decimal('51217.75')),
#  ('chandni ( with two child vikash 3 yrs & sweta 8 yr', Decimal('14426.75')),
#  ('narayan parsad bhushal', Decimal('11916.75')),
#  ('megha', Decimal('34956.00')),
#  ('ku rikha', Decimal('9741.50')),
#  ('chhabi rani dass', Decimal('10927.50')),
#  ('susma', Decimal('13036.00')),
#  ('nursa khatoon', Decimal('11921.75')),
#  ('jyoti sharma', Decimal('23361.00')),
#  ('smt kristina', Decimal('10487.50')),
#  ('rani kumari', Decimal('10989.25')),
#  ('bhavna suthar', Decimal('11127.75')),
#  ('gora', Decimal('10742.00')),
#  ('smt ganga', Decimal('11554.25')),
#  ('punam shakya', Decimal('12831.50')),
#  ('momin', Decimal('13861.00')),
#  ('rikkenchi', Decimal('10129.75')),
#  ('reena jain', Decimal('11226.25')),
#  ('meenakshi', Decimal('90302.75')),
#  ('jyoti gosyami', Decimal('11886.75')),
#  ('mona verma', Decimal('10190.25')),
#  ('nosi', Decimal('21739.75')),
#  ('jasoda', Decimal('51563.75')),
#  ('yasmin banu', Decimal('11955.50')),
#  ('smt mholani', Decimal('10935.75')),
#  ('anju devi', Decimal('82276.50')),
#  ('prem lata', Decimal('55010.75')),
#  ('gulnaz', Decimal('11423.75')),
#  ('sanjay kumar @ pappu', Decimal('11086.75')),
#  ('gulshana', Decimal('10753.00')),
#  ('simran kaur', Decimal('21908.00')),
#  ('devender', Decimal('24729.00')),
#  ('abbas', Decimal('13951.50')),
#  ('sagrika @ versha', Decimal('11139.75')),
#  ('swati yadav', Decimal('13972.25')),
#  ('abhishek', Decimal('11160.75')),
#  ('samir mishra', Decimal('10590.50')),
#  ('smt. parul', Decimal('10647.25')),
#  ('amina begam', Decimal('10911.75')),
#  ('shetal rani', Decimal('10805.25')),
#  ('jitender rajak', Decimal('10504.50')),
#  ('seema uraf lalita', Decimal('9652.00')),
#  ('anju bala @ sunaina', Decimal('13696.00')),
#  ('sushmita mandal', Decimal('10369.75')),
#  ('aashma', Decimal('22078.75')),
#  ('nutan', Decimal('9513.25')),
#  ('sony parveen', Decimal('12793.00')),
#  ('chameli', Decimal('12286.25')),
#  ('seema verma', Decimal('11243.00')),
#  ('gitika', Decimal('35018.25')),
#  ('kanchan dev', Decimal('10563.00')),
#  ('sabba', Decimal('24322.75')),
#  ('muskan kaur', Decimal('11412.25')),
#  ('kumari monki', Decimal('9892.00')),
#  ('sudesh rani', Decimal('12593.25')),
#  ('santoshi', Decimal('24692.50')),
#  ('smt. baikunthi devi', Decimal('9502.25')),
#  ('hazu roat', Decimal('10605.25')),
#  ('gayatri @ babli', Decimal('11113.75')),
#  ('vijay laxmi', Decimal('13112.00')),
#  ('sayda begam', Decimal('10867.25')),
#  ('मन्जू', Decimal('10575.75')),
#  ('vidya devi', Decimal('11867.75')),
#  ('alka', Decimal('65765.25')),
#  ('anita kerketa', Decimal('12967.75')),
#  ('fiza khan', Decimal('11444.00')),
#  ('rajbir ahlawat', Decimal('12066.75')),
#  ('ankita kanwar rathore', Decimal('10905.25')),
#  ('madam sahnaj', Decimal('11855.75')),
#  ('anjali kiski', Decimal('9358.75')),
#  ('smt radha', Decimal('11953.75')),
#  ('babita kumari', Decimal('11929.25')),
#  ('kamta', Decimal('12803.25')),
#  ('smt. manju', Decimal('34867.50')),
#  ('husnara', Decimal('12874.25')),
#  ('najmin banu pathan', Decimal('10894.50')),
#  ('suma', Decimal('10843.50')),
#  ('bhag chand', Decimal('11530.50')),
#  ('sehran nisha', Decimal('10350.25')),
#  ('himansi', Decimal('22916.50')),
#  ('nahid', Decimal('10132.00')),
#  ('pooja pandya', Decimal('10772.25')),
#  ('gajwanti @ manju', Decimal('10651.75')),
#  ('yashsvi sharma', Decimal('11245.50')),
#  ('manisha kumari', Decimal('19571.25')),
#  ('pappy', Decimal('11702.00')),
#  ('mohini', Decimal('54841.75')),
#  ('kuntesh @ kunti', Decimal('10431.75')),
#  ('b vikjay kumar', Decimal('12484.00')),
#  ('arjina', Decimal('10821.50')),
#  ('sumitra bai', Decimal('12472.75')),
#  ('rekha varhat`', Decimal('9270.50')),
#  ('rinku malav', Decimal('10221.00')),
#  ('kherul nisha', Decimal('10381.75')),
#  ('ganga', Decimal('33213.25')),
#  ('barti', Decimal('9862.00')),
#  ('kavita harijan', Decimal('11384.75')),
#  ('smt. pujadevi', Decimal('11008.00')),
#  ('renu pal', Decimal('12741.25')),
#  ('kanti prshad', Decimal('11054.50')),
#  ('shahina @ moti', Decimal('10924.50')),
#  ('smt salni devi', Decimal('11462.50')),
#  ('sapana', Decimal('22370.75')),
#  ('neeraj', Decimal('24870.50')),
#  ('saista', Decimal('11178.00')),
#  ('swaliya', Decimal('11080.25')),
#  ('sunil ladkani', Decimal('11711.75')),
#  ('neha bhatia', Decimal('12289.00')),
#  ('himani @ payal', Decimal('45523.25')),
#  ('sonali', Decimal('80770.00')),
#  ('kumari kanta @ kajal', Decimal('8367.00')),
#  ('chanderkala', Decimal('11895.75')),
#  ('tamsa', Decimal('10087.25')),
#  ('ku. seetal rawat', Decimal('10104.25')),
#  ('gopal', Decimal('9644.75')),
#  ('rohit kumar', Decimal('35981.25')),
#  ('rukshana khatun', Decimal('10074.50')),
#  ('puspa', Decimal('21889.25')),
#  ('kanta', Decimal('47373.50')),
#  ('sonam kawar', Decimal('13972.50')),
#  ('smt. santosh with her four children', Decimal('12613.50')),
#  ('kamala devi', Decimal('8014.75')),
#  ('lata jain', Decimal('11106.00')),
#  ('nisha singh', Decimal('9822.50')),
#  ('baby devi', Decimal('11475.25')),
#  ('seema rathore', Decimal('11629.50')),
#  ('kalashi devi bairwa', Decimal('10537.75')),
#  ('maya', Decimal('169346.75')),
#  ('kusumlata', Decimal('9940.25')),
#  ('vishakha', Decimal('13528.25')),
#  ('inderpal', Decimal('10296.00')),
#  ('mahrul nisha', Decimal('11008.25')),
#  ('smt rani devi', Decimal('10755.50')),
#  ('kanchan @ rekha', Decimal('12124.25')),
#  ('chanchal kumari', Decimal('11504.25')),
#  ('kumari jeda', Decimal('10562.25')),
#  ('amrit patel', Decimal('10174.75')),
#  ('chanab', Decimal('15862.00')),
#  ('prem singh bidla', Decimal('13132.00')),
#  ('neha @ baby', Decimal('10632.75')),
#  ('piryanka', Decimal('13404.75')),
#  ('bhrat narayn', Decimal('12040.00')),
#  ('sushma devi', Decimal('10859.00')),
#  ('kumari mona', Decimal('11503.50')),
#  ('pryinka', Decimal('10334.00')),
#  ('sandeep kaur', Decimal('12542.00')),
#  ('anisha', Decimal('44584.75')),
#  ('shishram', Decimal('13753.75')),
#  ('munbura bibi', Decimal('14300.25')),
#  ('baljeet kaur', Decimal('25424.25')),
#  ('sandeep kumar', Decimal('22302.50')),
#  ('valentina anglika', Decimal('14044.25')),
#  ('kalawati', Decimal('12702.75')),
#  ('soni@ chunnu', Decimal('11564.00')),
#  ('diksha or beby', Decimal('12087.50')),
#  ('hema', Decimal('80527.50')),
#  ('lalita luthra', Decimal('13370.25')),
#  ('meenu chawla', Decimal('11736.25')),
#  ('rajbir', Decimal('10702.50')),
#  ('soam chokeyiyakra', Decimal('14584.75')),
#  ('aesha', Decimal('12907.50')),
#  ('ranjit kaur', Decimal('10265.25')),
#  ('manoj kanwar', Decimal('10904.00')),
#  ('rasida khan', Decimal('11446.75')),
#  ('sahar bano', Decimal('12362.25')),
#  ('ku. pushpa', Decimal('10886.75')),
#  ('ravinder kaur', Decimal('24505.25')),
#  ('yashoda', Decimal('66199.00')),
#  ('sonu dhakad', Decimal('11286.75')),
#  ('nusrant', Decimal('11582.75')),
#  ('indra', Decimal('52366.50')),
#  ('shifali roshan', Decimal('13448.00')),
#  ('nainshi', Decimal('12654.00')),
#  ('asmit kaur', Decimal('12454.00')),
#  ('mushrraf', Decimal('9878.25')),
#  ('sangeeta devi', Decimal('21955.25')),
#  ('rajia', Decimal('11754.50')),
#  ('neeraj kandari', Decimal('10674.50')),
#  ('aasu', Decimal('11003.50')),
#  ('rada', Decimal('11107.25')),
#  ('deepak rana', Decimal('13329.75')),
#  ('smt. divya @ chhoti', Decimal('11652.25')),
#  ('bilkis', Decimal('10117.25')),
#  ('sangeta', Decimal('12904.00')),
#  ('kumari himanshi', Decimal('10742.00')),
#  ('gulnaj', Decimal('20692.50')),
#  ('avdhesh', Decimal('12922.25')),
#  ('anwar', Decimal('10323.75')),
#  ('laxman', Decimal('11850.25')),
#  ('beauty', Decimal('23789.75')),
#  ('shakti kumari', Decimal('12276.25')),
#  ('sukhbir kaur', Decimal('13606.50')),
#  ('amarin', Decimal('14262.00')),
#  ('komal kumari', Decimal('10234.50')),
#  ('harvindra singh', Decimal('11988.50')),
#  ('b. vinothini', Decimal('11346.50')),
#  ('soniya @ soni kumari', Decimal('11215.75')),
#  ('jenab parvin', Decimal('10177.75')),
#  ('shabanm', Decimal('11290.00')),
#  ('leela kumari', Decimal('9612.00')),
#  ('asha kashyap', Decimal('11779.25')),
#  ('ruhi khatoon', Decimal('9829.25')),
#  ('saroj', Decimal('205270.75')),
#  ('imamudeen', Decimal('12216.75')),
#  ('wilkish', Decimal('10316.25')),
#  ('himanshi', Decimal('67282.50')),
#  ('bhupender', Decimal('9974.00')),
#  ('ku. meena', Decimal('11882.75')),
#  ('priya kaur sandhu', Decimal('11021.75')),
#  ('oma', Decimal('12556.25')),
#  ('nency', Decimal('13874.25')),
#  ('sabana @ sabbo', Decimal('11517.00')),
#  ('manbhar bai', Decimal('10783.50')),
#  ('jyotsana mohti', Decimal('12537.50')),
#  ('deepti', Decimal('33855.75')),
#  ('manvi', Decimal('11416.50')),
#  ('rawi devi', Decimal('11605.25')),
#  ('hardeep @ hunny', Decimal('9583.00')),
#  ('mubarik', Decimal('10441.00')),
#  ('karamjeet kour @ sagandeep kour', Decimal('13441.75')),
#  ('gulafsa', Decimal('11415.75')),
#  ('smt. keshar devi', Decimal('12380.50')),
#  ('vivek sharma', Decimal('9827.50')),
#  ('ismaliye @ khusbu', Decimal('13927.00')),
#  ('rachna', Decimal('140899.00')),
#  ('rakhi soni', Decimal('12774.75')),
#  ('akash gupta', Decimal('20230.25')),
#  ('shajiya', Decimal('9021.50')),
#  ('smt. jhamaku', Decimal('11951.25')),
#  ('raja ram', Decimal('12521.50')),
#  ('phulkana', Decimal('8524.25')),
#  ('pooja saini', Decimal('8611.75')),
#  ('amandeep kaur', Decimal('21108.50')),
#  ('lalita  devi', Decimal('10542.25')),
#  ('saaniya', Decimal('9862.25')),
#  ('bala', Decimal('34317.25')),
#  ('ram kali', Decimal('10622.00')),
#  ('parveen khatun', Decimal('12805.50')),
#  ('noorjhan', Decimal('12330.50')),
#  ('shabnur', Decimal('12112.75')),
#  ('guddi with her son  anand', Decimal('12245.50')),
#  ('shehnaz @ ravina', Decimal('9581.00')),
#  ('shruti', Decimal('25931.75')),
#  ('pooja @ puspa', Decimal('8689.00')),
#  ('pawan', Decimal('41796.50')),
#  ('deepa', Decimal('342986.50')),
#  ('rekha @ muskan', Decimal('9723.50')),
#  ('poonam mishra', Decimal('9764.25')),
#  ('jasvinder kaur w/ gurbeg singh', Decimal('10699.50')),
#  ('manisha khandelwal', Decimal('12119.00')),
#  ('raju meena', Decimal('12574.50')),
#  ('rajesh agarwal', Decimal('12527.25')),
#  ('krishana', Decimal('22747.50')),
#  ('pulita', Decimal('9643.50')),
#  ('farah', Decimal('23357.25')),
#  ('tanushri', Decimal('10394.75')),
#  ('khushnuma', Decimal('22437.00')),
#  ('smt. anju', Decimal('11134.00')),
#  ('sonia kapoor', Decimal('10367.25')),
#  ('majidunisha', Decimal('11061.00')),
#  ('saheen', Decimal('12468.25')),
#  ('smt. bhanwari ,nahar singh', Decimal('14583.50')),
#  ('kayamuddin', Decimal('10732.00')),
#  ('lakhe sari gaur', Decimal('9840.75')),
#  ('sashi pal', Decimal('12523.75')),
#  ('kumari joyti', Decimal('10711.75')),
#  ('priya sexena', Decimal('14295.75')),
#  ('ilma', Decimal('11596.00')),
#  ('ku. seema', Decimal('12221.50')),
#  ('chanda devi', Decimal('20495.00')),
#  ('geeta saini', Decimal('10089.75')),
#  ('sunder munni kumari', Decimal('21105.00')),
#  ('kalpna singh', Decimal('9918.25')),
#  ('pooja garg', Decimal('10558.00')),
#  ('raj rani', Decimal('34319.50')),
#  ('sumirta', Decimal('9237.25')),
#  ('harpreet gil', Decimal('11644.00')),
#  ('rekha bai', Decimal('21736.50')),
#  ('lila', Decimal('33044.00')),
#  ('vimla kumari', Decimal('12317.25')),
#  ('rimmi singh', Decimal('11843.50')),
#  ('dali devi', Decimal('12644.25')),
#  ('poonam @ neelam', Decimal('8999.00')),
#  ('smt  deepmala', Decimal('10646.00')),
#  ('kanya bai with her 1,1/2 yr. child(girl)', Decimal('10118.25')),
#  ('nanagram', Decimal('12568.75')),
#  ('annu @ anita', Decimal('10195.00')),
#  ('anjum devi', Decimal('12301.75')),
#  ('smt.kiswar jahan', Decimal('8472.75')),
#  ('puja yadav', Decimal('12719.75')),
#  ('nirmala kumari', Decimal('11863.75')),
#  ('aaysha', Decimal('35911.00')),
#  ('sharda kharadi', Decimal('9758.00')),
#  ('ritika', Decimal('12086.50')),
#  ('gaura kuletha', Decimal('9569.75')),
#  ('inderjit kaur', Decimal('11380.75')),
#  ('rekha davi', Decimal('11946.50')),
#  ('pooja @ rajiya', Decimal('11320.00')),
#  ('babita pandey', Decimal('12493.50')),
#  ('faimuddin', Decimal('9758.75')),
#  ('paramjeet kaur', Decimal('24315.25')),
#  ('manjula @ riya', Decimal('13115.25')),
#  ('fazia', Decimal('11084.75')),
#  ('munni devi', Decimal('100623.50')),
#  ('raziya', Decimal('24870.50')),
#  ('heena praveen', Decimal('12351.75')),
#  ('marjina', Decimal('32036.25')),
#  ('laxmikant @kaka', Decimal('10030.75')),
#  ('soni devi', Decimal('58345.75')),
#  ('babita @ binny', Decimal('10573.75')),
#  ('akhilesh', Decimal('9714.00')),
#  ('anjali', Decimal('435580.25')),
#  ('jincy varghese', Decimal('10594.25')),
#  ('roshan bai', Decimal('25114.00')),
#  ('priyanka @ khushboo', Decimal('18701.25')),
#  ('kasim', Decimal('13566.75')),
#  ('priyanka das', Decimal('8975.25')),
#  ('hema devi with with his daughter nalini age 4yrs', Decimal('12525.25')),
#  ('smt asha', Decimal('11408.75')),
#  ('smt. gyattri bai', Decimal('10721.00')),
#  ('tabassum urf mona', Decimal('12109.50')),
#  ('shallu', Decimal('33003.75')),
#  ('sapna porwal', Decimal('12916.75')),
#  ('gauri', Decimal('48079.25')),
#  ('shila devi', Decimal('12033.00')),
#  ('smt. sangeeta  urf sonu', Decimal('12171.25')),
#  ('rekha  devi', Decimal('13769.25')),
#  ('damanjeet singh', Decimal('10177.50')),
#  ('sunita haddu', Decimal('12405.00')),
#  ('shiya', Decimal('11257.50')),
#  ('nashrin and her daughter jannat (both)', Decimal('11325.25')),
#  ('manpreet @ simaran', Decimal('12666.50')),
#  ('vakila', Decimal('10825.25')),
#  ('smt ritu devi', Decimal('9881.50')),
#  ('neha suman', Decimal('9668.25')),
#  ('mooli', Decimal('8849.25')),
#  ('anita alongwith her child prince', Decimal('10686.75')),
#  ('madhubala', Decimal('11514.50')),
#  ('sosri bai', Decimal('13701.50')),
#  ('rimpy', Decimal('20156.00')),
#  ('lila kumari', Decimal('11086.25')),
#  ('moti devi', Decimal('10429.75')),
#  ('km sarika  kothari', Decimal('13800.75')),
#  ('neetu @ gaytri', Decimal('11798.50')),
#  ('alisha khan', Decimal('11872.50')),
#  ('kamni devi', Decimal('13935.75')),
#  ('lal chand', Decimal('10622.00')),
#  ('ajra with child kadir', Decimal('11609.25')),
#  ('nisha @ chinu', Decimal('11598.00')),
#  ('mukul verma', Decimal('10643.25')),
#  ('km preeti', Decimal('9631.75')),
#  ('nilam sharma', Decimal('10826.25')),
#  ('ekta chauhan', Decimal('9839.25')),
#  ('smt. savita devi', Decimal('9813.25')),
#  ('farid', Decimal('11913.50')),
#  ('saira bano', Decimal('10320.75')),
#  ('usha parmanand', Decimal('12029.50')),
#  ('sulekha', Decimal('20698.00')),
#  ('shkundla devi', Decimal('10791.50')),
#  ('aanya @ china', Decimal('11443.50')),
#  ('priyaki rav', Decimal('10508.25')),
#  ('babita bajali', Decimal('12676.25')),
#  ('smt. mema devi', Decimal('12869.75')),
#  ('aamir hussain', Decimal('10892.50')),
#  ('nikki kumari', Decimal('13078.25')),
#  ('seema @ devki', Decimal('14424.50')),
#  ('aradhana @ radha', Decimal('14278.25')),
#  ('sanjay', Decimal('80966.75')),
#  ('kashis', Decimal('11590.75')),
#  ('shivani', Decimal('452026.75')),
#  ('neema rebari', Decimal('11462.50')),
#  ('sandhya pranak', Decimal('12201.00')),
#  ('shashi @ kajal', Decimal('11978.00')),
#  ('rama sharma', Decimal('13950.50')),
#  ('anita vohra', Decimal('11785.75')),
#  ('lalita gameti', Decimal('10163.75')),
#  ('sabhana', Decimal('12123.00')),
#  ('miss aanu megwal', Decimal('12008.00')),
#  ('lakhsmi @ rekha', Decimal('13386.00')),
#  ('pooja soni', Decimal('25007.00')),
#  ('jameela', Decimal('10463.75')),
#  ('arshi', Decimal('23563.75')),
#  ('mira devi', Decimal('11483.75')),
#  ('rekha with two doughters pooja, lakhsmi', Decimal('12221.25')),
#  ('sania parveen', Decimal('31182.75')),
#  ('prity', Decimal('10619.25')),
#  ('danista paveen', Decimal('8932.25')),
#  ('kumari rohini', Decimal('13688.00')),
#  ('sashi', Decimal('44106.25')),
#  ('jamee', Decimal('10135.00')),
#  ('varsa', Decimal('22743.25')),
#  ('shehnaz', Decimal('36780.50')),
#  ('poonam soni', Decimal('11017.75')),
#  ('smt. shweta gupta', Decimal('9748.50')),
#  ('neha @ neelam', Decimal('8797.00')),
#  ('sobha veshy', Decimal('10821.75')),
#  ('rekha harijan', Decimal('11506.00')),
#  ('nagma begam', Decimal('12808.75')),
#  ('rukhsona', Decimal('11318.25')),
#  ('namen khatun', Decimal('10702.75')),
#  ('saziya', Decimal('11104.75')),
#  ('tumpa das with a child roma das', Decimal('11962.50')),
#  ('kela kanwar', Decimal('12017.25')),
#  ('groti @ rati', Decimal('11285.25')),
#  ('sadhana @ jyoti', Decimal('15336.00')),
#  ('khanchan', Decimal('9898.25')),
#  ('ajay', Decimal('43418.25')),
#  ('shama', Decimal('38065.25')),
#  ('gajala parveen', Decimal('10025.75')),
#  ('meena  pawar', Decimal('13247.00')),
#  ('smt gulkasha', Decimal('11496.75')),
#  ('seeta', Decimal('57741.50')),
#  ('mamta bai', Decimal('22758.00')),
#  ('ku. anshita singh', Decimal('10276.50')),
#  ('kosalya with a child ashu', Decimal('11079.25')),
#  ('shanta koul', Decimal('11335.00')),
#  ('sudhama', Decimal('12265.00')),
#  ('kirpa', Decimal('13321.75')),
#  ('rampayari', Decimal('10837.75')),
#  ('md noori', Decimal('14338.00')),
#  ('jharna', Decimal('11229.00')),
#  ('ashtha', Decimal('10545.50')),
#  ('jayoti', Decimal('11044.50')),
#  ('manda bai', Decimal('12186.75')),
#  ('smt. bholi devi', Decimal('10057.50')),
#  ('rizwana', Decimal('33373.75')),
#  ('smt sunita', Decimal('35609.75')),
#  ('ashwani chhabra', Decimal('10751.75')),
#  ('asha @ mamta', Decimal('11948.00')),
#  ('sarika panjawani', Decimal('12486.50')),
#  ('ratmo devi', Decimal('17104.50')),
#  ('sheela bhanat', Decimal('12586.50')),
#  ('isnesh', Decimal('12577.00')),
#  ('smt. kushma devi', Decimal('10255.25')),
#  ('smt. krishana devi', Decimal('10667.00')),
#  ('smt ranjna verma', Decimal('14251.75')),
#  ('km0 anjli', Decimal('12763.75')),
#  ('aansi devi', Decimal('9909.00')),
#  ('pankaj chand', Decimal('12578.50')),
#  ('amasi munda', Decimal('9715.75')),
#  ('smt vimla', Decimal('23175.25')),
#  ('maya devi', Decimal('109276.25')),
#  ('shyama', Decimal('12243.25')),
#  ('najma  & asma', Decimal('23435.00')),
#  ('renu parcha', Decimal('9070.25')),
#  ('neetu sain', Decimal('10847.25')),
#  ('naseeba', Decimal('10666.50')),
#  ('rajenderi', Decimal('11099.50')),
#  ('rakhi chauhan', Decimal('11622.50')),
#  ('smt. kamla devi', Decimal('10515.50')),
#  ('durgash urf mahi', Decimal('10737.75')),
#  ('mira', Decimal('12100.25')),
#  ('mehwish', Decimal('9845.00')),
#  ('sazya', Decimal('10684.00')),
#  ('megha das', Decimal('13694.50')),
#  ('reshma khatoon', Decimal('10469.25')),
#  ('dinesh kumar', Decimal('10621.25')),
#  ('smt ranu', Decimal('12601.25')),
#  ('anjana kumari', Decimal('11217.00')),
#  ('smt. soni', Decimal('10676.25')),
#  ('smt meena devi', Decimal('10970.75')),
#  ('sona bai', Decimal('13390.50')),
#  ('shobina', Decimal('12151.00')),
#  ('nimmy', Decimal('15442.25')),
#  ('abdul kadir', Decimal('11117.25')),
#  ('monika tyagi', Decimal('10800.50')),
#  ('shumita', Decimal('11338.00')),
#  ('shilpa', Decimal('70325.50')),
#  ('sosan devi', Decimal('9357.00')),
#  ('kiran', Decimal('467918.50')),
#  ('sunita verma', Decimal('12304.75')),
#  ('kusum meena', Decimal('11779.25')),
#  ('trannum', Decimal('13250.75')),
#  ('rinky devi', Decimal('8980.25')),
#  ('sahista @ ruksar', Decimal('9168.25')),
#  ('ranju sharma', Decimal('12183.50')),
#  ('smt sita devi', Decimal('13102.25')),
#  ...]

# %%
query_2 = pd.DataFrame(list(records),columns = ['Customer_name','total_price'])
query_2.head()
# Out:
#    Customer_name total_price
# 0     maina devi    13636.50
# 1  pratibha devi    12703.25
# 2     mohit maan    11591.00
# 3   tumpa mundal    14591.00
# 4     suman devi    21477.75

# %%
# plt.bar(query_2.Customer_name,query_2.total_price)

# %%
cur = con.cursor()
select_query = "select s.division , sum(f.total_price)\
                from ecomdb.fact_table f \
                join ecomdb.store_dim s on s.store_key = f.store_key \
                where s.division = 'BARISAL'\
                group by (s.division)"
cur.execute(select_query)
records = cur.fetchall()
records
# Out:
# [('BARISAL', Decimal('7520343.75'))]

# %%
query_3 = pd.DataFrame(list(records),columns=['district','total_sales'])
query_3.head()
# Out:
#   district total_sales
# 0  BARISAL  7520343.75

# %%
# plt.bar(query_3.district , query_3.total_sales)

# %%
cur = con.cursor()
select_query = "select  t.year, sum(f.total_price) \
                from ecomdb.fact_table f \
                join ecomdb.time_dim t on f.time_key=t.time_key \
                where t.year=2015 \
                group by t.year"
cur.execute(select_query)
records = cur.fetchall()
records
# Out:
# [(Decimal('2015'), Decimal('15095720.25'))]

# %%
query_4 = pd.DataFrame(list(records),columns = ['year','total_sales'])
query_4.head()
# Out:
#    year  total_sales
# 0  2015  15095720.25

# %%
cur = con.cursor()
select_query = "select  s.division , t.year, sum(f.total_price) \
                from ecomdb.fact_table f \
                join ecomdb.time_dim t on f.time_key=t.time_key \
                join ecomdb.store_dim s on s.store_key = f.store_key \
                where t.year=2015  and s.division = 'BARISAL' \
                group by (t.year,s.division)"
cur.execute(select_query)
records = cur.fetchall()
records
# Out:
# [

#  ('MAESA SAS', 'Premier Protein Shake Choc. 11oz', 1420),
#  ('MAESA SAS', 'Red Bull 12oz', 1492),
#  ('MAESA SAS', 'Bounty Paper Towels Select a Size ', 1356),
#  ('MAESA SAS', 'Diet Gingerale 12 oz cans', 1540),
#  ('MAESA SAS', 'Wint O Green LifeSavers Sugar Free', 1368),
#  ('MAESA SAS', 'Pop Chips Variety bags', 1424),
#  ('MAESA SAS', 'Breath Savers Peppermints 12/roll ', 1380),
#  ('MAESA SAS', 'Lysol Disinfectant Spray 19 oz', 1336),
#  ('MAESA SAS', 'K Cups Dunkin Donuts Medium Roast', 1352),
#  ('MAESA SAS', 'Ice Breaker Mints Sugar Free ', 1380),
#  ('MAESA SAS', 'Breath Savers Peppermints 12/roll ', 999),
#  ('MAESA SAS', 'Topo Chico 12 oz glass', 939),
#  ('MAESA SAS', 'K Cups Dunkin Donuts Medium Roast', 1152),
#  ('MAESA SAS', 'Cascade Gel w/ Dawn Dishwasher', 1077),
#  ('MAESA SAS', 'Bounty Paper Towels Select a Size ', 1002),
#  ('MAESA SAS', 'Clear Plastic Cups 9oz', 960),
#  ('MAESA SAS', 'Gatorade Liberty Variety 12 oz', 1080),
#  ('MAESA SAS', 'Brisk Lemon Iced Tea - 12 oz cans', 1014),
#  ('MAESA SAS', 'Chinet Comfort Hot Cups with Lids 16oz', 915),
#  ('MAESA SAS', 'Pop Chips Variety bags', 1065),
#  ('MAESA SAS', 'Red Bull 12oz', 1020),
#  ('MAESA SAS', 'La Croix Sparkling Lime 12 oz', 1086),
#  ('MAESA SAS', 'Ice Breaker Mints Sugar Free ', 969),
#  ('MAESA SAS', 'Lysol Disinfectant Spray 19 oz', 966),
#  ('MAESA SAS', 'Premier Protein Shake Choc. 11oz', 1041),
#  ('MAESA SAS', 'Lysol Wipes 100 ct', 990),
#  ('MAESA SAS', 'Clorox Disinfecting Wipes ', 1083),
#  ('MAESA SAS', 'Wint O Green LifeSavers Sugar Free', 924),
#  ('MAESA SAS', 'Diet Gingerale 12 oz cans', 1044),
#  ('MAESA SAS', 'Foam Coffee Cups - 08 ounce', 1089),
#  ('MAESA SAS', 'Clorox Disinfecting Wipes ', 686),
#  ('MAESA SAS', 'Breath Savers Peppermints 12/roll ', 762),
#  ('MAESA SAS', 'Lysol Wipes 100 ct', 696),
#  ('MAESA SAS', 'Diet Gingerale 12 oz cans', 664),
#  ('MAESA SAS', 'Chinet Comfort Hot Cups with Lids 16oz', 726),
#  ('MAESA SAS', 'Brisk Lemon Iced Tea - 12 oz cans', 706),
#  ('MAESA SAS', 'Ice Breaker Mints Sugar Free ', 700),
#  ('MAESA SAS', 'Red Bull 12oz', 706),
#  ('MAESA SAS', 'Foam Coffee Cups - 08 ounce', 682),
#  ('MAESA SAS', 'Pop Chips Variety bags', 650),
#  ('MAESA SAS', 'Gatorade Liberty Variety 12 oz', 716),
#  ('MAESA SAS', 'Clear Plastic Cups 9oz', 686),
#  ('MAESA SAS', 'Bounty Paper Towels Select a Size ', 684),
#  ('MAESA SAS', 'K Cups Dunkin Donuts Medium Roast', 688),
#  ('MAESA SAS', 'Wint O Green LifeSavers Sugar Free', 696),
#  ('MAESA SAS', 'Lysol Disinfectant Spray 19 oz', 672),
#  ('MAESA SAS', 'Topo Chico 12 oz glass', 756),
#  ('MAESA SAS', 'La Croix Sparkling Lime 12 oz', 692),
#  ('MAESA SAS', 'Cascade Gel w/ Dawn Dishwasher', 728),
#  ('MAESA SAS', 'Premier Protein Shake Choc. 11oz', 690),
#  ('MAESA SAS', 'Diet Gingerale 12 oz cans', 351),
#  ('MAESA SAS', 'Chinet Comfort Hot Cups with Lids 16oz', 351),
#  ('MAESA SAS', 'Clorox Disinfecting Wipes ', 341),
#  ('MAESA SAS', 'Bounty Paper Towels Select a Size ', 364),
#  ('MAESA SAS', 'Ice Breaker Mints Sugar Free ', 355),
#  ('MAESA SAS', 'Brisk Lemon Iced Tea - 12 oz cans', 339),
#  ('MAESA SAS', 'Pop Chips Variety bags', 337),
#  ('MAESA SAS', 'Cascade Gel w/ Dawn Dishwasher', 329),
#  ('MAESA SAS', 'La Croix Sparkling Lime 12 oz', 306),
#  ('MAESA SAS', 'Red Bull 12oz', 341),
#  ('MAESA SAS', 'Breath Savers Peppermints 12/roll ', 350),
#  ('MAESA SAS', 'Foam Coffee Cups - 08 ounce', 319),
#  ('MAESA SAS', 'Wint O Green LifeSavers Sugar Free', 332),
#  ('MAESA SAS', 'Premier Protein Shake Choc. 11oz', 326),
#  ('MAESA SAS', 'Lysol Disinfectant Spray 19 oz', 322),
#  ('MAESA SAS', 'Topo Chico 12 oz glass', 361),
#  ('MAESA SAS', 'K Cups Dunkin Donuts Medium Roast', 360),
#  ('MAESA SAS', 'Lysol Wipes 100 ct', 357),
#  ('MAESA SAS', 'Clear Plastic Cups 9oz', 349),
#  ('MAESA SAS', 'Gatorade Liberty Variety 12 oz', 352),
#  ('Indo Count Industries Ltd', 'K Cups Daily Chef Columbian Supremo', 4081),
#  ('Indo Count Industries Ltd',
#   'Cliff Builders Protein Bar Variety Pack',
#   3619),
#  ('Indo Count Industries Ltd', 'Deluxe Mixed Nuts with Seasalt', 3828),
#  ('Indo Count Industries Ltd', 'Coke Zero Sugar 12 oz cans', 4015),
#  ('Indo Count Industries Ltd', 'Waterloo Sparkling Lime 12oz', 3663),
#  ('Indo Count Industries Ltd', 'Swiss Miss Hot Cocoa Mix 1 oz', 3619),
#  ('Indo Count Industries Ltd', 'Crunchy Granola Bars Oats & Honey', 3520),
#  ('Indo Count Industries Ltd', 'Frito Classic Mix Variety', 4081),
#  ('Indo Count Industries Ltd', 'Sun Chips Variety Pack', 3960),
#  ('Indo Count Industries Ltd', 'Zoo Animal Cookies/Crackers', 3784),
#  ('Indo Count Industries Ltd', 'Paper Plates 7 inch  Ultra Strong', 3795),
#  ('Indo Count Industries Ltd', 'Apple Sauce Variety GoGO Squeeze 3.2oz', 3707),
#  ('Indo Count Industries Ltd', 'Fiber One Bars Oats and Chocolate', 3564),
#  ('Indo Count Industries Ltd', 'Tylenol Extra Strength 2 pill packets', 3762),
#  ('Indo Count Industries Ltd', 'Double Bubble Variety Tub', 4004),
#  ('Indo Count Industries Ltd', 'Kind  Bars Mini Variety Pack 0.7 oz ', 3850),
#  ('Indo Count Industries Ltd', 'Gatorade Liberty Variety 20 oz ', 3564),
#  ('Indo Count Industries Ltd', 'Hefty Supreme Foam Plates 9 inch', 3828),
#  ('Indo Count Industries Ltd', 'Pop-Tarts, Frosted Strawberry', 3729),
#  ('Indo Count Industries Ltd', 'Doritos Nacho Cheese 1 oz', 3773),
#  ('Indo Count Industries Ltd', 'Belvita Hard Biscuits Blueberry', 3520),
#  ('Indo Count Industries Ltd', 'Diet Pepsi - 12 oz cans', 4301),
#  ('Indo Count Industries Ltd', 'Pringles Snak Stacks Variety', 3861),
#  ('Indo Count Industries Ltd', 'K Cups Original Donut Shop Med. Roast', 3498),
#  ('Indo Count Industries Ltd', 'K Cups - McCafe Premium Roast', 3872),
#  ('Indo Count Industries Ltd', 'Fresca Original - 12 oz cans', 3751),
#  ('Indo Count Industries Ltd', 'Baked Chips Variety Mix Frito', 4004),
#  ('Indo Count Industries Ltd', 'Hefty Supreme Foam Plates 6 inch', 3883),
#  ('Indo Count Industries Ltd', 'Vita Coconut Water 10oz ', 3806),
#  ('Indo Count Industries Ltd', 'Quaker Instant Oatmeal Maple Brn Sugar', 4202),
#  ('Indo Count Industries Ltd', 'Cheez It White Cheddar 1.5 oz', 3806),
#  ('Indo Count Industries Ltd', 'Coke Classic 12 oz cans', 3784),
#  ('Indo Count Industries Ltd', 'K Cups Original Donut Shop Med. Roast', 3700),
#  ('Indo Count Industries Ltd', 'Swiss Miss Hot Cocoa Mix 1 oz', 4040),
#  ('Indo Count Industries Ltd', 'Sun Chips Variety Pack', 3160),
#  ('Indo Count Industries Ltd', 'Doritos Nacho Cheese 1 oz', 3230),
#  ('Indo Count Industries Ltd', 'Vita Coconut Water 10oz ', 3420),
#  ('Indo Count Industries Ltd', 'Quaker Instant Oatmeal Maple Brn Sugar', 3200),
#  ('Indo Count Industries Ltd', 'Crunchy Granola Bars Oats & Honey', 3560),
#  ('Indo Count Industries Ltd', 'Cheez It White Cheddar 1.5 oz', 3780),
#  ('Indo Count Industries Ltd', 'Apple Sauce Variety GoGO Squeeze 3.2oz', 3470),
#  ('Indo Count Industries Ltd', 'Waterloo Sparkling Lime 12oz', 3380),
#  ('Indo Count Industries Ltd', 'Tylenol Extra Strength 2 pill packets', 3450),
#  ('Indo Count Industries Ltd', 'Fiber One Bars Oats and Chocolate', 3320),
#  ('Indo Count Industries Ltd', 'Pringles Snak Stacks Variety', 3620),
#  ('Indo Count Industries Ltd', 'K Cups - McCafe Premium Roast', 3690),
#  ('Indo Count Industries Ltd', 'Belvita Hard Biscuits Blueberry', 3540),
#  ('Indo Count Industries Ltd',
#   'Cliff Builders Protein Bar Variety Pack',
#   3280),
#  ('Indo Count Industries Ltd', 'Baked Chips Variety Mix Frito', 3300),
#  ('Indo Count Industries Ltd', 'Double Bubble Variety Tub', 3290),
#  ('Indo Count Industries Ltd', 'Paper Plates 7 inch  Ultra Strong', 3670),
#  ('Indo Count Industries Ltd', 'Gatorade Liberty Variety 20 oz ', 3360),
#  ('Indo Count Industries Ltd', 'Frito Classic Mix Variety', 3690),
#  ('Indo Count Industries Ltd', 'Fresca Original - 12 oz cans', 3550),
#  ('Indo Count Industries Ltd', 'Diet Pepsi - 12 oz cans', 3500),
#  ('Indo Count Industries Ltd', 'Coke Zero Sugar 12 oz cans', 3530),
#  ('Indo Count Industries Ltd', 'Pop-Tarts, Frosted Strawberry', 3550),
#  ('Indo Count Industries Ltd', 'Zoo Animal Cookies/Crackers', 3340),
#  ('Indo Count Industries Ltd', 'Deluxe Mixed Nuts with Seasalt', 3420),
#  ('Indo Count Industries Ltd', 'Kind  Bars Mini Variety Pack 0.7 oz ', 3410),
#  ('Indo Count Industries Ltd', 'Coke Classic 12 oz cans', 3500),
#  ('Indo Count Industries Ltd', 'Hefty Supreme Foam Plates 9 inch', 3210),
#  ('Indo Count Industries Ltd', 'Hefty Supreme Foam Plates 6 inch', 3260),
#  ('Indo Count Industries Ltd', 'K Cups Daily Chef Columbian Supremo', 3620),
#  ('Indo Count Industries Ltd', 'Tylenol Extra Strength 2 pill packets', 3132),
#  ('Indo Count Industries Ltd', 'Fiber One Bars Oats and Chocolate', 3114),
#  ('Indo Count Industries Ltd', 'Gatorade Liberty Variety 20 oz ', 2817),
#  ('Indo Count Industries Ltd', 'Cheez It White Cheddar 1.5 oz', 3402),
#  ('Indo Count Industries Ltd', 'K Cups Original Donut Shop Med. Roast', 2997),
#  ('Indo Count Industries Ltd', 'Zoo Animal Cookies/Crackers', 2844),
#  ('Indo Count Industries Ltd', 'Belvita Hard Biscuits Blueberry', 2853),
#  ('Indo Count Industries Ltd', 'Pop-Tarts, Frosted Strawberry', 2763),
#  ('Indo Count Industries Ltd', 'Coke Classic 12 oz cans', 3123),
#  ('Indo Count Industries Ltd', 'Waterloo Sparkling Lime 12oz', 3321),
#  ('Indo Count Industries Ltd',
#   'Cliff Builders Protein Bar Variety Pack',
#   3033),
#  ('Indo Count Industries Ltd', 'Frito Classic Mix Variety', 3312),
#  ('Indo Count Industries Ltd', 'Swiss Miss Hot Cocoa Mix 1 oz', 3195),
#  ('Indo Count Industries Ltd', 'Vita Coconut Water 10oz ', 2979),
#  ('Indo Count Industries Ltd', 'Double Bubble Variety Tub', 3186),
#  ('Indo Count Industries Ltd', 'Apple Sauce Variety GoGO Squeeze 3.2oz', 3105),
#  ('Indo Count Industries Ltd', 'Doritos Nacho Cheese 1 oz', 3366),
#  ('Indo Count Industries Ltd', 'Pringles Snak Stacks Variety', 2997),
#  ('Indo Count Industries Ltd', 'Hefty Supreme Foam Plates 9 inch', 2880),
#  ('Indo Count Industries Ltd', 'Paper Plates 7 inch  Ultra Strong', 3168),
#  ('Indo Count Industries Ltd', 'Kind  Bars Mini Variety Pack 0.7 oz ', 3096),
#  ('Indo Count Industries Ltd', 'Coke Zero Sugar 12 oz cans', 2862),
#  ('Indo Count Industries Ltd', 'K Cups - McCafe Premium Roast', 2979),
#  ('Indo Count Industries Ltd', 'Quaker Instant Oatmeal Maple Brn Sugar', 3321),
#  ('Indo Count Industries Ltd', 'Crunchy Granola Bars Oats & Honey',

#  ('Indo Count Industries Ltd', 'Hefty Supreme Foam Plates 9 inch', 308),
#  ('Indo Count Industries Ltd', 'Cheez It White Cheddar 1.5 oz', 341),
#  ('Indo Count Industries Ltd', 'Gatorade Liberty Variety 20 oz ', 348),
#  ('Indo Count Industries Ltd', 'Sun Chips Variety Pack', 330),
#  ('Indo Count Industries Ltd', 'Fiber One Bars Oats and Chocolate', 344),
#  ('Indo Count Industries Ltd', 'Paper Plates 7 inch  Ultra Strong', 329),
#  ('Indo Count Industries Ltd', 'Zoo Animal Cookies/Crackers', 318),
#  ('Indo Count Industries Ltd', 'K Cups - McCafe Premium Roast', 381),
#  ('Indo Count Industries Ltd', 'Fresca Original - 12 oz cans', 346),
#  ('Indo Count Industries Ltd', 'Tylenol Extra Strength 2 pill packets', 336),
#  ('Indo Count Industries Ltd', 'Vita Coconut Water 10oz ', 355),
#  ('Indo Count Industries Ltd', 'Cliff Builders Protein Bar Variety Pack', 347),
#  ('Indo Count Industries Ltd', 'Belvita Hard Biscuits Blueberry', 352),
#  ('Indo Count Industries Ltd', 'Diet Pepsi - 12 oz cans', 346),
#  ('Indo Count Industries Ltd', 'Kind  Bars Mini Variety Pack 0.7 oz ', 346),
#  ('Indo Count Industries Ltd', 'Quaker Instant Oatmeal Maple Brn Sugar', 337),
#  ('Indo Count Industries Ltd', 'Hefty Supreme Foam Plates 6 inch', 334),
#  ('Indo Count Industries Ltd', 'Baked Chips Variety Mix Frito', 347),
#  ('Indo Count Industries Ltd', 'Swiss Miss Hot Cocoa Mix 1 oz', 353),
#  ('Indo Count Industries Ltd', 'Pop-Tarts, Frosted Strawberry', 333),
#  ('HARDFORD AB', 'Coffee-Mate French Vanilla Cold', 3608),
#  ('HARDFORD AB', 'La Croix Sparkling Berry 12 ozv', 3784),
#  ('HARDFORD AB', 'K Cups –Organic Breakfast Blend', 3971),
#  ('HARDFORD AB', 'Hazelnut International Delight', 3399),
#  ('HARDFORD AB', 'Miss Vickies Chips', 3685),
#  ('HARDFORD AB', 'Frito Big Grab Variety 1.5-2.0 oz', 3872),
#  ('HARDFORD AB', 'Paper Plate 10 inch Ultra Strong', 3608),
#  ('HARDFORD AB', 'Njoy Sugar Canister 22 oz', 3817),
#  ('HARDFORD AB', 'Propel Zero Variety 20 oz', 3707),
#  ('HARDFORD AB', 'Lunchables Variety Pack Oscar Meyer', 3553),
#  ('HARDFORD AB', 'Chex Mix Original', 3883),
#  ('HARDFORD AB', 'Gatorade Lemon Lime 12oz', 3993),
#  ('HARDFORD AB', 'San Pelligrino 16oz Plastic ', 3597),
#  ('HARDFORD AB', 'Fresca Peach Citrus - 12 oz cans', 3795),
#  ('HARDFORD AB', 'Kleenex Tissue Square Boxes 75/box', 3949),
#  ('HARDFORD AB', 'Hefty Supreme Foam Bowls 12oz', 3861),
#  ('HARDFORD AB', 'Diet Mountain Dew 12oz cans', 3828),
#  ('HARDFORD AB', 'Cherry Coke Zero 12 pack', 3905),
#  ('HARDFORD AB', 'La Croix Sparkling Pure 12 oz', 3872),
#  ('HARDFORD AB', 'Plastic Spoons White  Heavyweight', 3751),
#  ('HARDFORD AB', 'Yoplait Original Yogurt Variety Pack ', 3454),
#  ('HARDFORD AB', 'Trident Original Flavor 18/pk', 3751),
#  ('HARDFORD AB', 'Jolly Ranchers Variety Hard Candy', 3454),
#  ('HARDFORD AB', 'Ocean Spray Cranberry Juice Cocktail 15oz ', 3817),
#  ('HARDFORD AB', 'Nature Valley Biscuit Sandwich Variety Pack ', 3927),
#  ('HARDFORD AB', 'Mars Mini Mix', 3971),
#  ('HARDFORD AB', 'Dark Chocolate Mint Patties', 3784),
#  ('HARDFORD AB', 'Miss Vickies Chips', 3580),
#  ('HARDFORD AB', 'Chex Mix Original', 3520),
#  ('HARDFORD AB', 'Trident Original Flavor 18/pk', 3320),
#  ('HARDFORD AB', 'Dark Chocolate Mint Patties', 3490),
#  ('HARDFORD AB', 'Lunchables Variety Pack Oscar Meyer', 3500),
#  ('HARDFORD AB', 'Plastic Spoons White  Heavyweight', 3240),
#  ('HARDFORD AB', 'Paper Plate 10 inch Ultra Strong', 3450),
#  ('HARDFORD AB', 'Fresca Peach Citrus - 12 oz cans', 3240),
#  ('HARDFORD AB', 'Kleenex Tissue Square Boxes 75/box', 3650),
#  ('HARDFORD AB', 'Nature Valley Biscuit Sandwich Variety Pack ', 3470),
#  ('HARDFORD AB', 'Jolly Ranchers Variety Hard Candy', 3530),
#  ('HARDFORD AB', 'Propel Zero Variety 20 oz', 3490),
#  ('HARDFORD AB', 'Gatorade Lemon Lime 12oz', 3240),
#  ('HARDFORD AB', 'Ocean Spray Cranberry Juice Cocktail 15oz ', 3660),
#  ('HARDFORD AB', 'Diet Mountain Dew 12oz cans', 3250),
#  ('HARDFORD AB', 'Yoplait Original Yogurt Variety Pack ', 3350),
#  ('HARDFORD AB', 'Cherry Coke Zero 12 pack', 3560),
#  ('HARDFORD AB', 'La Croix Sparkling Pure 12 oz', 3410),
#  ('HARDFORD AB', 'Njoy Sugar Canister 22 oz', 3430),
#  ('HARDFORD AB', 'Mars Mini Mix', 3300),
#  ('HARDFORD AB', 'San Pelligrino 16oz Plastic ', 3420),
#  ('HARDFORD AB', 'Hazelnut International Delight', 3140),
#  ('HARDFORD AB', 'La Croix Sparkling Berry 12 ozv', 3400),
#  ('HARDFORD AB', 'K Cups –Organic Breakfast Blend', 3740),
#  ('HARDFORD AB', 'Coffee-Mate French Vanilla Cold', 3580),
#  ('HARDFORD AB', 'Hefty Supreme Foam Bowls 12oz', 3480),
#  ('HARDFORD AB', 'Frito Big Grab Variety 1.5-2.0 oz', 2840),
#  ('HARDFORD AB', 'Hazelnut International Delight', 3123),
#  ('HARDFORD AB', 'K Cups –Organic Breakfast Blend', 2835),
#  ('HARDFORD AB', 'Lunchables Variety Pack Oscar Meyer', 3204),
#  ('HARDFORD AB', 'La Croix Sparkling Pure 12 oz', 2880),
#  ('HARDFORD AB', 'Kleenex Tissue Square Boxes 75/box', 2988),
#  ('HARDFORD AB', 'Miss Vickies Chips', 3276),
#  ('HARDFORD AB', 'Njoy Sugar Canister 22 oz', 3159),
#  ('HARDFORD AB', 'Plastic Spoons White  Heavyweight', 3069),
#  ('HARDFORD AB', 'Nature Valley Biscuit Sandwich Variety Pack ', 3087),
#  ('HARDFORD AB', 'Coffee-Mate French Vanilla Cold', 3339),
#  ('HARDFORD AB', 'La Croix Sparkling Berry 12 ozv', 3096),
#  ('HARDFORD AB', 'Chex Mix Original', 3105),
#  ('HARDFORD AB', 'Fresca Peach Citrus - 12 oz cans', 3339),
#  ('HARDFORD AB', 'San Pelligrino 16oz Plastic ', 3159),
#  ('HARDFORD AB', 'Frito Big Grab Variety 1.5-2.0 oz', 3177),
#  ('HARDFORD AB', 'Propel Zero Variety 20 oz', 2970),
#  ('HARDFORD AB', 'Paper Plate 10 inch Ultra Strong', 3123),
#  ('HARDFORD AB', 'Yoplait Original Yogurt Variety Pack ', 3303),
#  ('HARDFORD AB', 'Diet Mountain Dew 12oz cans', 3015),
#  ('HARDFORD AB', 'Hefty Supreme Foam Bowls 12oz', 3249),
#  ('HARDFORD AB', 'Dark Chocolate Mint Patties', 2997),
#  ('HARDFORD AB', 'Ocean Spray Cranberry Juice Cocktail 15oz ', 3006),
#  ('HARDFORD AB', 'Cherry Coke Zero 12 pack', 2799),
#  ('HARDFORD AB', 'Jolly Ranchers Variety Hard Candy', 3096),
#  ('HARDFORD AB', 'Trident Original Flavor 18/pk', 3105),
#  ('HARDFORD AB', 'Mars Mini Mix', 3267),
#  ('HARDFORD AB', 'Gatorade Lemon Lime 12oz', 3033),
#  ('HARDFORD AB', 'La Croix Sparkling Pure 12 oz', 2544),
#  ('HARDFORD AB', 'Plastic Spoons White  Heavyweight', 2744),
#  ('HARDFORD AB', 'Frito Big Grab Variety 1.5-2.0 oz', 2624),
#  ('HARDFORD AB', 'Trident Original Flavor 18/pk', 2432),
#  ('HARDFORD AB', 'Mars Mini Mix', 2816),
#  ('HARDFORD AB', 'Kleenex Tissue Square Boxes 75/box', 2504),
#  ('HARDFORD AB', 'Jolly Ranchers Variety Hard Candy', 2744),
#  ('HARDFORD AB', 'Cherry Coke Zero 12 pack', 2760),
#  ('HARDFORD AB', 'Diet Mountain Dew 12oz cans', 2664),
#  ('HARDFORD AB', 'Njoy Sugar Canister 22 oz', 2984),
#  ('HARDFORD AB', 'La Croix Sparkling Berry 12 ozv', 2608),
#  ('HARDFORD AB', 'San Pelligrino 16oz Plastic ', 2792),
#  ('HARDFORD AB', 'Miss Vickies Chips', 2736),
#  ('HARDFORD AB', 'Ocean Spray Cranberry Juice Cocktail 15oz ', 2832),
#  ('HARDFORD AB', 'Coffee-Mate French Vanilla Cold', 3160),
#  ('HARDFORD AB', 'Propel Zero Variety 20 oz', 2648),
#  ('HARDFORD AB', 'Hazelnut International Delight', 2880),
#  ('HARDFORD AB', 'Dark Chocolate Mint Patties', 2800),
#  ('HARDFORD AB', 'K Cups –Organic Breakfast Blend', 3104),
#  ('HARDFORD AB', 'Hefty Supreme Foam Bowls 12oz', 2384),
#  ('HARDFORD AB', 'Gatorade Lemon Lime 12oz', 2952),
#  ('HARDFORD AB', 'Lunchables Variety Pack Oscar Meyer', 2888),
#  ('HARDFORD AB', 'Paper Plate 10 inch Ultra Strong', 2872),
#  ('HARDFORD AB', 'Fresca Peach Citrus - 12 oz cans', 2712),
#  ('HARDFORD AB', 'Yoplait Original Yogurt Variety Pack ', 2576),
#  ('HARDFORD AB', 'Chex Mix Original', 2592),
#  ('HARDFORD AB', 'Nature Valley Biscuit Sandwich Variety Pack ', 2552),
#  ('HARDFORD AB', 'Hazelnut International Delight', 2268),
#  ('HARDFORD AB', 'Trident Original Flavor 18/pk', 2457),
#  ('HARDFORD AB', 'Lunchables Variety Pack Oscar Meyer', 2534),
#  ('HARDFORD AB', 'Frito Big Grab Variety 1.5-2.0 oz', 2352),
#  ('HARDFORD AB', 'Cherry Coke Zero 12 pack', 2275),
#  ('HARDFORD AB', 'K Cups –Organic Breakfast Blend', 2275),
#  ('HARDFORD AB', 'Jolly Ranchers Variety Hard Candy', 2450),
#  ('HARDFORD AB', 'Coffee-Mate French Vanilla Cold', 2380),
#  ('HARDFORD AB', 'Plastic Spoons White  Heavyweight', 2401),
#  ('HARDFORD AB', 'Chex Mix Original', 2317),
#  ('HARDFORD AB', 'Yoplait Original Yogurt Variety Pack ', 2478),
#  ('HARDFORD AB', 'Nature Valley Biscuit Sandwich Variety Pack ', 2492),
#  ('HARDFORD AB', 'Kleenex Tissue Square Boxes 75/box', 2485),
#  ('HARDFORD AB', 'Gatorade Lemon Lime 12oz', 2422),
#  ('HARDFORD AB', 'Propel Zero Variety 20 oz', 2457),
#  ('HARDFORD AB', 'Fresca Peach Citrus - 12 oz cans', 2282),
#  ('HARDFORD AB', 'Paper Plate 10 inch Ultra Strong', 2415),
#  ('HARDFORD AB', 'Njoy Sugar Canister 22 oz', 2450),
#  ('HARDFORD AB', 'Diet Mountain Dew 12oz cans', 2695),
#  ('HARDFORD AB', 'Hefty Supreme Foam Bowls 12oz', 2254),
#  ('HARDFORD AB', 'La Croix Sparkling Berry 12 ozv', 2254),
#  ('HARDFORD AB', 'Ocean Spray Cranberry Juice Cocktail 15oz ', 2457),
#  ('HARDFORD AB', 'La Croix Sparkling Pure 12 oz', 2282),
#  ('HARDFORD AB', 'Miss Vickies Chips', 2541),
#  ('HARDFORD AB', 'Dark Chocolate Mint Patties', 2513),
#  ('HARDFORD AB', 'Mars Mini Mix', 2485),
#  ('HARDFORD AB', 'San Pelligrino 16oz Plastic ', 2604),
#  ('HARDFORD AB', 'Frito Big Grab Variety 1.5-2.0 oz', 2106),
#  ('HARDFORD AB', 'Chex Mix Original', 2004),
#  ('HARDFORD AB', 'Hefty Supreme Foam Bowls 12oz', 2274),
#  ('HARDFORD AB', 'Yoplait Original Yogurt Variety Pack ', 2112),
#  ('HARDFORD AB', 'Diet Mountain Dew 12oz cans', 1962),
#  ('HARDFORD AB', 'Gatorade Lemon Lime 12oz', 2094),
#  ('HARDFORD AB', 'Cherry Coke Zero 12 pack', 1908),
#  ('HARDFORD AB', 'La Croix Sparkling Berry 12 ozv', 2100),
#  ('HARDFORD AB', 'San Pelligrino 16oz Plastic ', 2130),
#  ('HARDFORD AB', 'Paper Plate 10 inch Ultra Strong', 2142),
#  ('HARDFORD AB', 'Hazelnut International Delight', 2310),
#  ('HARDFORD AB', 'Nature Valley Biscuit Sandwich Variety Pack ', 1824),
#  ('HARDFORD AB', 'Plastic Spoons White  Heavyweight', 2154),
#  ('HARDFORD AB', 'Mars Mini Mix', 2022),
#  ('HARDFORD AB', 'La Croix Sparkling Pure 12 oz', 2268),
#  ('HARDFORD AB', 'Coffee-Mate French Vanilla Cold', 2052),
#  ('HARDFORD AB', 'Miss Vickies Chips', 2142),
#  ('HARDFORD AB', 'Njoy Sugar Canister 22 oz', 2058),
#  ('HARDFORD AB', 'Dark Chocolate Mint Patties', 1968),
#  ('HARDFORD AB', 'Lunchables Variety Pack Oscar Meyer', 2010),
#  ('HARDFORD AB', 'Trident Original Flavor 18/pk', 2064),
#  ('HARDFORD AB', 'Propel Zero Variety 20 oz', 2142),
#  ('HARDFORD AB', 'Fresca Peach Citrus - 12 oz cans', 2028),
#  ('HARDFORD AB', 'Jolly Ranchers Variety Hard Candy', 2022),
#  ('HARDFORD AB', 'Kleenex Tissue Square Boxes 75/box', 2046),
#  ('HARDFORD AB', 'K Cups –Organic Breakfast Blend', 1950),
#  ('HARDFORD AB', 'Ocean Spray Cranberry Juice Cocktail 15oz ', 2136),
#  ('HARDFORD AB', 'Chex Mix Original', 1685),
#  ('HARDFORD AB', 'Jolly Ranchers Variety Hard Candy', 1815),
#  ...]

# %%
query_6 = pd.DataFrame(list(records),columns = ['supplier','item_name','quantity'])
query_6.head()
# Out:
#                          supplier                               item_name  \
# 0  NINGBO SEDUNO IMP & EXP CO.LTD                Sugar in the Raw Packets
# 1  NINGBO SEDUNO IMP & EXP CO.LTD       Sobe Zero Lifewater Variety 20 oz
# 2  NINGBO SEDUNO IMP & EXP CO.LTD        Fresca Black Cherry - 12 oz cans
# 3  NINGBO SEDUNO IMP & EXP CO.LTD  Perrier Sparkling Water plastic 16.9oz
# 4  NINGBO SEDUNO IMP & EXP CO.LTD                Truvia Natural Sweetener
#
#    quantity
# 0      3850
# 1      4026
# 2      3773
# 3      3839
# 4      3894

# %%
query_6 = query_6.set_index('item_name').groupby("supplier")['quantity'].nlargest(3).reset_index()
query_6
# Out:
#                           supplier  \
# 0                         BIGSO AB
# 1                         BIGSO AB
# 2                         BIGSO AB
# 3                  Bolsius Boxmeer
# 4                  Bolsius Boxmeer
# 5                  Bolsius Boxmeer
# 6             CHERRY GROUP CO.,LTD
# 7             CHERRY GROUP CO.,LTD
# 8             CHERRY GROUP CO.,LTD
# 9               CHROMADURLIN S.A.S
# 10              CHROMADURLIN S.A.S
# 11              CHROMADURLIN S.A.S
# 12                    DENIMACH LTD
# 13                    DENIMACH LTD
# 14                    DENIMACH LTD
# 15              Friedola 1888 GmbH
# 16              Friedola 1888 GmbH
# 17              Friedola 1888 GmbH
# 18                     HARDFORD AB
# 19                     HARDFORD AB
# 20                     HARDFORD AB
# 21       Indo Count Industries Ltd
# 22       Indo Count Industries Ltd
# 23       Indo Count Industries Ltd
# 24                       MAESA SAS
# 25                       MAESA SAS
# 26                       MAESA SAS
# 27  NINGBO SEDUNO IMP & EXP CO.LTD
# 28  NINGBO SEDUNO IMP & EXP CO.LTD
# 29  NINGBO SEDUNO IMP & EXP CO.LTD
#
#                                      item_name  quantity
# 0              Kind  Bars Variety Pack 1.4 oz       4191
# 1      La Croix Sparkling Cran-Raspberry 12 oz      4125
# 2   Dawn Ultra Dish Detergent, Original Scent       4114
# 3                       Diet Coke - 12 oz cans      4422
# 4            Reese's Pieces Peanutbutter Candy      4081
# 5                    Pure Leaf Sweet Tea 8.5oz      4026
# 6              Wonderful Pistachios (in shell)      4004
# 7                  Stirrers Coffee Stirs 7inch      3960
# 8          Tejava Unsweetened Black Tea 16.9oz      3905
# 9                   Planters Nut Variety Packs      4114
# 10                          K Cups - Green Tea      4070
# 11             A&W Root Beer Diet - 12 oz cans      4037
# 12               Large Trash Bags Black 33 gal      4301
# 13                   Charmin Ultra Bath Tissue      4125
# 14            La Croix Sparkling Coconut 12 oz      4059
# 15                 Foam Coffee Cups - 16 ounce      4125
# 16          Kellogg's Cereals Assortment Pack       4092
# 17                Folgers Classic Roast Coffee      4081
# 18                    Gatorade Lemon Lime 12oz      3993
# 19             K Cups –Organic Breakfast Blend      3971
# 20                               Mars Mini Mix      3971
# 21                     Diet Pepsi - 12 oz cans      4301
# 22      Quaker Instant Oatmeal Maple Brn Sugar      4202
# 23         K Cups Daily Chef Columbian Supremo      4081
# 24                               Red Bull 12oz      4059
# 25                      Clear Plastic Cups 9oz      4026
# 26           K Cups Dunkin Donuts Medium Roast      3993
# 27                       Starbuck's Pike Place      4114
# 28           Sobe Zero Lifewater Variety 20 oz      4026
# 29         Nabisco Classic Mix ccooki, cracker      3982

# %%
x = input('enter a number : ')
# Out:
# enter a number : 50

# %%
cur = con.cursor()
select_query = "select  i.item_name,\
                tr.trans_type,\
                t.date\
                from ecomdb.fact_table f\
                join ecomdb.item_dim i on f.item_key=i.item_key\
                join ecomdb.trans_dim tr on tr.payment_key = f.payment_key\
                join ecomdb.time_dim t on t.time_key = f.time_key\
                where t.date > now() - interval ' day' and   tr.trans_type = 'card'\
                group by cube(i.item_name,tr.trans_type,t.date) "
# -- order by (i.item_name) desc "
cur.execute(select_query)
records = cur.fetchall()
records
# Out:
# [('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 20, 14, 7)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 22, 2, 57)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 22, 10, 16)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 23, 6, 13)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 23, 23, 44)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 25, 4, 29)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 25, 9, 1)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 27, 2, 6)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 28, 0, 29)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 28, 1, 34)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 28, 12, 21)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 29, 3, 2)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 29, 3, 7)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 29, 4, 46)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 29, 17, 29)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 30, 15, 35)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 30, 19, 18)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 31, 3, 22)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 31, 5, 31)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 1, 31, 8, 43)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 1, 23, 39)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 2, 20, 33)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 3, 7, 17)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 3, 11, 2)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 4, 13, 57)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 4, 22, 24)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 6, 3, 16)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 7, 0, 2)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 7, 19, 17)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 8, 2, 25)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 9, 1, 32)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 9, 12, 31)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 10, 0, 4)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 10, 19, 11)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 11, 2, 16)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 11, 13, 8)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 13, 17, 30)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 14, 12, 9)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 17, 0, 46)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 17, 14, 28)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 17, 14, 53)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 18, 16, 14)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 18, 22, 30)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 19, 21, 22)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 19, 22, 27)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 21, 17, 1)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 23, 0, 45)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 25, 5, 0)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 25, 19, 21)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 25, 22, 38)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 26, 8, 22)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 26, 11, 33)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 26, 23, 16)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 2, 27, 19, 23)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 1, 0, 55)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 1, 18, 21)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 1, 20, 13)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 2, 4, 17)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 2, 5, 55)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 5, 14, 49)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 6, 4, 47)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 6, 9, 19)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 6, 10, 42)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 8, 8, 31)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 8, 17, 58)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 9, 17, 42)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 11, 10, 9)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 11, 19, 45)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 12, 2, 27)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 12, 9, 37)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 12, 10, 0)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 13, 5, 12)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 13, 12, 5)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 13, 23, 9)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 15, 2, 21)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 16, 14, 35)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 17, 19, 37)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 19, 13, 37)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 19, 17, 15)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 19, 20, 54)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 21, 21, 24)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 24, 1, 4)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 25, 11, 14)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 25, 18, 52)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 26, 15, 46)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 26, 16, 31)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 26, 16, 54)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 27, 1, 54)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 27, 6, 22)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 27, 19, 16)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 28, 0, 1)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 28, 7, 7)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 28, 10, 13)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 28, 19, 0)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 29, 22, 12)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 3, 31, 14, 5)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 1, 8, 8)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 2, 20, 33)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 4, 15, 29)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 6, 10, 21)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 6, 15, 31)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 7, 5, 14)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 9, 18, 19)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 9, 19, 54)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 11, 2, 46)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 11, 13, 2)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 11, 19, 18)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 12, 18, 49)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 13, 3, 33)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 14, 18, 12)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 15, 1, 58)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 15, 6, 52)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 16, 9, 15)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 17, 1, 32)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 17, 9, 27)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 17, 10, 41)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 18, 4, 24)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 18, 10, 55)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 19, 6, 52)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 19, 20, 7)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 20, 1, 7)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 20, 11, 7)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 23, 19, 39)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 24, 21, 31)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 24, 21, 32)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 24, 22, 23)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 25, 4, 45)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 25, 21, 0)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 26, 8, 17)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 27, 2, 30)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 27, 4, 32)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 28, 21, 8)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 28, 22, 38)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 28, 22, 44)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 29, 3, 55)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 4, 29, 13, 13)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 2, 2, 13)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 2, 23, 46)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 4, 9, 47)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 4, 19, 37)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 5, 11, 24)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 6, 17, 36)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 7, 10, 51)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5, 7, 15, 22)),
#  ('100% Juice Box Variety 6.75 oz ',
#   'card',
#   datetime.datetime(2014, 5,