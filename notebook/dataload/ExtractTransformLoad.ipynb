# %% [markdown]
# ### Package installation

# %%
pip install psycopg2

# %%
pip install pandas

# %%
pip install openpyxl

# %% [markdown]
# ### Package call

# %%
import psycopg2
import pandas as pd
import psycopg2.extras

# %% [markdown]
# ### Extract

# %% [markdown]
# ***Read from excel file***

# %%
DATA_DIR = "H:/Vinternship/"

# %%
trans_dim = pd.read_excel(open(DATA_DIR + 'e-commerece_data.xlsx','rb'), sheet_name=1, engine='openpyxl')
trans_dim
# Out:
#    payment_key trans_type                                          bank_name
# 0         P001       cash                                               None
# 1         P002       card                                    AB Bank Limited
# 2         P003       card                   Bangladesh Commerce Bank Limited
# 3         P004       card                                  Bank Asia Limited
# 4         P005       card                                  BRAC Bank Limited
# 5         P006       card                              Citizens Bank Limited
# 6         P007       card                                  City Bank Limited
# 7         P008       card                  Community Bank Bangladesh Limited
# 8         P009       card                                 Dhaka Bank Limited
# 9         P010       card                          Dutch-Bangla Bank Limited
# 10        P011       card                               Eastern Bank Limited
# ...

# %%
item_dim = pd.read_excel(open(DATA_DIR + 'e-commerece_data.xlsx','rb'), sheet_name=2, engine='openpyxl')
item_dim
# Out:
#     item_key                              item_name                desc  \
# 0     I00001             A&W Root Beer - 12 oz cans  a. Beverage - Soda
# 1     I00002        A&W Root Beer Diet - 12 oz cans  a. Beverage - Soda
# 2     I00003          Barq's Root Beer - 12 oz cans  a. Beverage - Soda
# 3     I00004                       Cherry Coke 12oz  a. Beverage - Soda
# 4     I00005               Cherry Coke Zero 12 pack  a. Beverage - Soda
# ..       ...                                    ...                 ...
# 259   I00260                   Napkins Square Lunch    Kitchen Supplies
# 260   I00261                 POM 2 ply paper towels    Kitchen Supplies
# 261   I00262                Strong Everyday Napkins    Kitchen Supplies
# 262   I00263                   Advil 2 pill packets            Medicine
# 263   I00264  Tylenol Extra Strength 2 pill packets            Medicine
#
#      unit_price  man_country                        supplier  unit
# ...

# %%
customer_dim = pd.read_excel(open(DATA_DIR + 'e-commerece_data.xlsx','rb'), sheet_name=3, engine='openpyxl')
customer_dim
# Out:
#      coustomer_key             name     contact_no            nid
# 0          C000001            sumit  8801920345851  7505075708899
# 1          C000002         tammanne  8801817069329  1977731324842
# 2          C000003    kailash kumar  8801663795774  3769494056318
# 3          C000004  bhagwati prasad  8801533627961  9378834712725
# 4          C000005             ajay  8801943715786  3540815556323
# ...            ...              ...            ...            ...
# 9186       C009187        smt radha  8801563029753  1057824928189
# 9187       C009188     tulsi sharma  8801794982266  7970880905205
# 9188       C009189        madhubala  8801890032435  3101930298150
# 9189       C009190       pintu devi  8801563290767  7234328323528
# 9190       C009191            roopa  8801524507359  5682728390307
#
# [9191 rows x 4 columns]

# %%
time_dim = pd.read_excel(open(DATA_DIR + 'e-commerece_data.xlsx','rb'), sheet_name=4, engine='openpyxl')
time_dim
# Out:
#       time_key              date  hour  day      week  month quarter  year
# 0       T00001  20-05-2017 14:56    14   20  3rd Week      5      Q2  2017
# 1       T00002  30-01-2015 22:14    22   30  4th Week      1      Q1  2015
# 2       T00003  14-03-2020 02:34     2   14  2nd Week      3      Q1  2020
# 3       T00004  27-04-2018 12:19    12   27  4th Week      4      Q2  2018
# 4       T00005  14-04-2018 10:43    10   14  2nd Week      4      Q2  2018
# ...        ...               ...   ...  ...       ...    ...     ...   ...
# 99994  T099995  04-01-2015 17:22    17    4  1st Week      1      Q1  2015
# 99995  T099996  17-01-2015 21:09    21   17  3rd Week      1      Q1  2015
# 99996  T099997  23-01-2020 14:42    14   23  4th Week      1      Q1  2020
# 99997  T099998  31-10-2015 13:52    13   31  4th Week     10      Q4  2015
# 99998  T099999  08-06-2017 08:59     8    8  2nd Week      6      Q2  2017
#
# [99999 rows x 8 columns]

# %%
store_dim = pd.read_excel(open(DATA_DIR + 'e-commerece_data.xlsx','rb'), sheet_name=5, engine='openpyxl')
store_dim
# Out:
#     store_key division  district                  upazila
# 0       S0001   SYLHET  HABIGANJ               AJMIRIGANJ
# 1       S0002   SYLHET  HABIGANJ                  BAHUBAL
# 2       S0003   SYLHET  HABIGANJ               BANIACHONG
# 3       S0004   SYLHET  HABIGANJ              CHUNARUGHAT
# 4       S0005   SYLHET  HABIGANJ           HABIGANJ SADAR
# ..        ...      ...       ...                      ...
# 721    S00722  BARISAL   BARISAL                    HIZLA
# 722    S00723  BARISAL   BARISAL  BARISAL SADAR (KOTWALI)
# 723    S00724  BARISAL   BARISAL              MEHENDIGANJ
# 724    S00725  BARISAL   BARISAL                   MULADI
# 725    S00726  BARISAL   BARISAL                 WAZIRPUR
#
# [726 rows x 4 columns]

# %%
fact_table= pd.read_excel(open(DATA_DIR + 'e-commerece_data.xlsx','rb'), sheet_name=0, engine='openpyxl')
fact_table
# Out:
#        payment_key coustomer_key time_key item_key store_key  quantity   unit  \
# 0             P026       C004510  T049189   I00177    S00307         1     ct
# 1             P022       C008967  T041209   I00248    S00595         1  rolls
# 2             P030       C007261   T03633   I00195    S00496         8     ct
# 3             P032       C007048  T084631   I00131     S0086         8     ct
# 4             P014       C006430  T071276   I00050    S00488         8   cans
# ...            ...           ...      ...      ...       ...       ...    ...
# 999995        P010       C003726   T09247   I00063    S00502         5   cans
# 999996        P021       C002581  T023483   I00252    S00225         1     ct
# 999997        P035       C006133  T039372   I00119    S00555         7     ct
# 999998        P031       C008735  T097975   I00257    S00440         2     ct
# 999999        P032       C004067  T018028   I00044    S00326        10   cans
#
#         unit_price  total_price
# ...

# %% [markdown]
# ### Data type

# %%
trans_dim.dtypes
# Out:
# payment_key    object
# trans_type     object
# bank_name      object
# dtype: object

# %%
item_dim.dtypes
# Out:
# item_key        object
# item_name       object
# desc            object
# unit_price     float64
# man_country     object
# supplier        object
# unit            object
# dtype: object

# %%
customer_dim.dtypes
# Out:
# coustomer_key    object
# name             object
# contact_no        int64
# nid               int64
# dtype: object

# %%
time_dim.dtypes
# Out:
# time_key    object
# date        object
# hour         int64
# day          int64
# week        object
# month        int64
# quarter     object
# year         int64
# dtype: object

# %%
store_dim.dtypes
# Out:
# store_key    object
# division     object
# district     object
# upazila      object
# dtype: object

# %%
fact_table.dtypes
# Out:
# payment_key       object
# coustomer_key     object
# time_key          object
# item_key          object
# store_key         object
# quantity           int64
# unit              object
# unit_price       float64
# total_price      float64
# dtype: object

# %% [markdown]
# ### Checking null values

# %%
trans_dim.columns[trans_dim.isna().any()]
# Out:
# Index([], dtype='object')

# %%
item_dim.columns[item_dim.isna().any()]
# Out:
# Index(['unit'], dtype='object')

# %%
customer_dim.columns[customer_dim.isna().any()]
# Out:
# Index(['name'], dtype='object')

# %%
time_dim.columns[time_dim.isna().any()]
# Out:
# Index([], dtype='object')

# %%
store_dim.columns[store_dim.isna().any()]
# Out:
# Index([], dtype='object')

# %%
fact_table.columns[fact_table.isna().any()]
# Out:
# Index(['unit'], dtype='object')

# %% [markdown]
# ### Fill null values

# %%
item_dim.unit = item_dim.unit.fillna('')
item_dim.columns[item_dim.isna().any()]
# Out:
# Index([], dtype='object')

# %%
customer_dim.name = customer_dim.name.fillna('')
customer_dim.columns[customer_dim.isna().any()]
# Out:
# Index([], dtype='object')

# %%
fact_table.unit = fact_table.unit.fillna('')
fact_table.columns[fact_table.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### Load

# %% [markdown]
# ***Connect to the database***

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database="ecomdb",
                                           user = "postgres",
                                           password = "Nabila12345@",
                                           host = "127.0.0.1",
                                           port = "5432")

    def getConnection(self):
        print("successfully connected to database"),
        return self.connection

# %%
con = PostgresConnection().getConnection()
# Out:
# successfully connected to database

# %% [markdown]
# ### Data Insertion

# %% [markdown]
# ***Trans_dim***

# %%
insert_stmt = "INSERT INTO ecomdb_star_schema.trans_dim( payment_key, trans_type, bank_name)" \
              " VALUES (%s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, trans_dim.values);
con.commit()
cur.close()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Input In [61], in <module>
#       1 insert_stmt = "INSERT INTO ecomdb_star_schema.trans_dim( payment_key, trans_type, bank_name)" \
#       2               " VALUES (%s, %s, %s)"
#       3 cur = con.cursor()
# ----> 4 psycopg2.extras.execute_batch(cur, insert_stmt, trans_dim.values);
#       5 con.commit()
#
# File H:\Vinternship\eCommerce\lib\site-packages\psycopg2\extras.py:1187, in execute_batch(cur, sql, argslist, page_size)
#    1185 for page in _paginate(argslist, page_size=page_size):
#    1186     sqls = [cur.mogrify(sql, args) for args in page]
# -> 1187     cur.execute(b";".join(sqls))
#
# UniqueViolation: duplicate key value violates unique constraint "pk_22"
# DETAIL:  Key (payment_key)=(P001) already exists.

# %% [markdown]
# ***item_dim***

# %%
insert_stmt2 = "INSERT INTO ecomdb_star_schema.item_dim(item_key, item_name, description, unit_price, man_country, supplier, unit)" \
              " VALUES (%s, %s, %s, %s, %s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt2, item_dim.values);
con.commit()
cur.close()

# %% [markdown]
# ***Customer_dim***

# %%
insert_stmt3 = "INSERT INTO ecomdb_star_schema.coustomer_dim(coustomer_key, name, contact_no, nid)"\
              " VALUES (%s, %s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt3, customer_dim.values);
con.commit()
cur.close()

# %% [markdown]
# ***Time_dim***

# %%
time_dim['date'] = time_dim['date'].replace('/', '-');
time_dim.dtypes
# Out:
# time_key    object
# date        object
# hour         int64
# day          int64
# week        object
# month        int64
# quarter     object
# year         int64
# dtype: object

# %%
time_dim['date']=time_dim['date'].astype('datetime64[ns]')
time_dim['date']
# Out:
# 0       2017-05-20 14:56:00
# 1       2015-01-30 22:14:00
# 2       2020-03-14 02:34:00
# 3       2018-04-27 12:19:00
# 4       2018-04-14 10:43:00
#                 ...
# 99994   2015-04-01 17:22:00
# 99995   2015-01-17 21:09:00
# 99996   2020-01-23 14:42:00
# 99997   2015-10-31 13:52:00
# 99998   2017-08-06 08:59:00
# Name: date, Length: 99999, dtype: datetime64[ns]

# %%
insert_stmt4 = "INSERT INTO ecomdb_star_schema.time_dim(time_key, date, hour, day, week, month, quarter, year)"\
              " VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt4, time_dim.values);
con.commit()
cur.close()

# %% [markdown]
# ***Store_dim***

# %%
insert_stmt = "INSERT INTO ecomdb_star_schema.store_dim(store_key, division, district, upazila)" \
              " VALUES (%s, %s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, store_dim.values);
con.commit()
cur.close()

# %%
insert_stmt5 = "INSERT INTO ecomdb_star_schema.fact_table(payment_key, coustomer_key, time_key, item_key, store_key, quantity, unit, unit_price, total_price)" \
                "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt5, fact_table.values)
con.commit()
cur.close()

# %% [markdown]
# ### Data Selection

# %% [markdown]
# ***Trans_dim***

# %%
cur = con.cursor()
select_stmt = "SELECT t.payment_key , t.trans_type, t.bank_name " \
              "FROM ecomdb_star_schema.trans_dim t"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# [('P001', 'cash', 'None'),
#  ('P002', 'card', 'AB Bank Limited'),
#  ('P003', 'card', 'Bangladesh Commerce Bank Limited'),
#  ('P004', 'card', 'Bank Asia Limited'),
#  ('P005', 'card', 'BRAC Bank Limited'),
#  ('P006', 'card', 'Citizens Bank Limited'),
#  ('P007', 'card', 'City Bank Limited'),
#  ('P008', 'card', 'Community Bank Bangladesh Limited'),
#  ('P009', 'card', 'Dhaka Bank Limited'),
#  ('P010', 'card', 'Dutch-Bangla Bank Limited'),
#  ('P011', 'card', 'Eastern Bank Limited'),
#  ('P012', 'card', 'IFIC Bank Limited'),
#  ('P013', 'card', 'Jamuna Bank Limited'),
#  ('P014', 'card', 'Meghna Bank Limited'),
#  ('P015', 'card', 'Mercantile Bank Limited'),
#  ('P016', 'card', 'Midland Bank Limited'),
#  ('P017', 'card', 'Modhumoti Bank Limited'),
#  ('P018', 'card', 'Mutual Trust Bank Limited'),
#  ('P019', 'card', 'National Bank Limited'),
#  ('P020', 'card', 'National Credit & Commerce Bank Limited'),
#  ('P021', 'card', 'NRB Bank Limited'),
# ...

# %%
trans_df = pd.DataFrame(list(records), columns=['payment_key', 'trans_type', 'bank_name'])
trans_df
# Out:
#    payment_key trans_type                                          bank_name
# 0         P001       cash                                               None
# 1         P002       card                                    AB Bank Limited
# 2         P003       card                   Bangladesh Commerce Bank Limited
# 3         P004       card                                  Bank Asia Limited
# 4         P005       card                                  BRAC Bank Limited
# 5         P006       card                              Citizens Bank Limited
# 6         P007       card                                  City Bank Limited
# 7         P008       card                  Community Bank Bangladesh Limited
# 8         P009       card                                 Dhaka Bank Limited
# 9         P010       card                          Dutch-Bangla Bank Limited
# 10        P011       card                               Eastern Bank Limited
# ...

# %% [markdown]
# ***Item_dim***

# %%
cur = con.cursor()
select_stmt = "SELECT t.item_key , t.item_name, t.description, t.unit_price, t.man_country, t.supplier, t.unit " \
              "FROM ecomdb_star_schema.item_dim t"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# [('I00001',
#   'A&W Root Beer - 12 oz cans',
#   'a. Beverage - Soda',
#   Decimal('11.5'),
#   'Netherlands',
#   'Bolsius Boxmeer',
#   'cans'),
#  ('I00002',
#   'A&W Root Beer Diet - 12 oz cans',
#   'a. Beverage - Soda',
#   Decimal('6.75'),
#   'poland',
#   'CHROMADURLIN S.A.S',
#   'cans'),
#  ('I00003',
#   "Barq's Root Beer - 12 oz cans",
#   'a. Beverage - Soda',
#   Decimal('6.75'),
#   'Bangladesh',
#   'DENIMACH LTD',
#   'cans'),
#  ('I00004',
#   'Cherry Coke 12oz',
#   'a. Beverage - Soda',
#   Decimal('6.75'),
#   'Netherlands',
#   'Bolsius Boxmeer',
#   'cans'),
#  ('I00005',
#   'Cherry Coke Zero 12 pack',
#   'a. Beverage - Soda',
#   Decimal('6.75'),
#   'Finland',
#   'HARDFORD AB',
#   'cans'),
#  ('I00006',
#   'Coke Classic 12 oz cans',
#   'a. Beverage - Soda',
#   Decimal('16.25'),
#   'Lithuania',
#   'BIGSO AB',
#   'cans'),
#  ('I00007',
#   'Coke Classic 12 oz cans',
#   'a. Beverage - Soda',
#   Decimal('6.75'),
#   'India',
# ...

# %%
item_df = pd.DataFrame(list(records), columns=['item_key', 'item_name', 'description', 'unit_price', 'man_country', 'supplier','unit'])
item_df
# Out:
#     item_key                              item_name         description  \
# 0     I00001             A&W Root Beer - 12 oz cans  a. Beverage - Soda
# 1     I00002        A&W Root Beer Diet - 12 oz cans  a. Beverage - Soda
# 2     I00003          Barq's Root Beer - 12 oz cans  a. Beverage - Soda
# 3     I00004                       Cherry Coke 12oz  a. Beverage - Soda
# 4     I00005               Cherry Coke Zero 12 pack  a. Beverage - Soda
# ..       ...                                    ...                 ...
# 259   I00260                   Napkins Square Lunch    Kitchen Supplies
# 260   I00261                 POM 2 ply paper towels    Kitchen Supplies
# 261   I00262                Strong Everyday Napkins    Kitchen Supplies
# 262   I00263                   Advil 2 pill packets            Medicine
# 263   I00264  Tylenol Extra Strength 2 pill packets            Medicine
#
#     unit_price  man_country                        supplier  unit
# ...

# %% [markdown]
# ***Time_dim***

# %%
cur = con.cursor()
select_stmt = "SELECT t.time_key, t.date, t.hour, t.day, t.week, t.month, t.quarter, t.year " \
              "FROM ecomdb_star_schema.time_dim t"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# [('T00001',
#   datetime.datetime(2017, 5, 20, 14, 56),
#   14,
#   20,
#   '3rd Week',
#   5,
#   'Q2',
#   2017),
#  ('T00002',
#   datetime.datetime(2015, 1, 30, 22, 14),
#   22,
#   30,
#   '4th Week',
#   1,
#   'Q1',
#   2015),
#  ('T00003',
#   datetime.datetime(2020, 3, 14, 2, 34),
#   2,
#   14,
#   '2nd Week',
#   3,
#   'Q1',
#   2020),
#  ('T00004',
#   datetime.datetime(2018, 4, 27, 12, 19),
#   12,
#   27,
#   '4th Week',
#   4,
#   'Q2',
#   2018),
#  ('T00005',
#   datetime.datetime(2018, 4, 14, 10, 43),
#   10,
#   14,
#   '2nd Week',
#   4,
#   'Q2',
#   2018),
#  ('T00006',
#   datetime.datetime(2017, 10, 2, 6, 56),
#   6,
#   10,
#   '2nd Week',
#   2,
#   'Q1',
#   2017),
#  ('T00007',
#   datetime.datetime(2015, 6, 5, 17, 52),
#   17,
#   6,
#   '1st Week',
#   5,
#   'Q2',
#   2015),
#  ('T00008',
#   datetime.datetime(2014, 9, 23, 13, 59),
#   13,
#   23,
#   '4th Week',
#   9,
#   'Q3',
#   2014),
#  ('T00009',
#   datetime.datetime(2016, 4, 16, 6, 45),
# ...

# %%
time_df = pd.DataFrame(list(records), columns=['time_key', 'date', 'hour', 'day', 'week','month','quarter','year'])
time_df
# Out:
#       time_key                date  hour  day      week  month quarter  year
# 0       T00001 2017-05-20 14:56:00    14   20  3rd Week      5      Q2  2017
# 1       T00002 2015-01-30 22:14:00    22   30  4th Week      1      Q1  2015
# 2       T00003 2020-03-14 02:34:00     2   14  2nd Week      3      Q1  2020
# 3       T00004 2018-04-27 12:19:00    12   27  4th Week      4      Q2  2018
# 4       T00005 2018-04-14 10:43:00    10   14  2nd Week      4      Q2  2018
# ...        ...                 ...   ...  ...       ...    ...     ...   ...
# 99994  T099995 2015-04-01 17:22:00    17    4  1st Week      1      Q1  2015
# 99995  T099996 2015-01-17 21:09:00    21   17  3rd Week      1      Q1  2015
# 99996  T099997 2020-01-23 14:42:00    14   23  4th Week      1      Q1  2020
# 99997  T099998 2015-10-31 13:52:00    13   31  4th Week     10      Q4  2015
# 99998  T099999 2017-08-06 08:59:00     8    8  2nd Week      6      Q2  2017
#
# [99999 rows x 8 columns]

# %% [markdown]
# ***Fact_table***

# %%
cur = con.cursor()
select_stmt = "SELECT t.payment_key, t.coustomer_key, t.time_key, t.store_key, t.quantity, t.unit, t.unit_price, t.total_price " \
              "FROM ecomdb_star_schema.fact_table t"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# [('P026',
#   'C004510',
#   'T049189',
#   'S00307',
#   1,
#   'ct',
#   Decimal('35.0'),
#   Decimal('35.0')),
#  ('P022',
#   'C008967',
#   'T041209',
#   'S00595',
#   1,
#   'rolls',
#   Decimal('26.0'),
#   Decimal('26.0')),
#  ('P030',
#   'C007261',
#   'T03633',
#   'S00496',
#   8,
#   'ct',
#   Decimal('12.5'),
#   Decimal('100.0')),
#  ('P032',
#   'C007048',
#   'T084631',
#   'S0086',
#   8,
#   'ct',
#   Decimal('14.0'),
#   Decimal('112.0')),
#  ('P014',
#   'C006430',
#   'T071276',
#   'S00488',
#   8,
#   'cans',
#   Decimal('8.0'),
#   Decimal('64.0')),
#  ('P006',
#   'C007574',
#   'T026950',
#   'S00328',
#   5,
#   'bottles',
#   Decimal('22.0'),
#   Decimal('110.0')),
#  ('P023',
#   'C005695',
#   'T096704',
#   'S00196',
#   2,
#   'cans',
#   Decimal('15.5'),
#   Decimal('31.0')),
#  ('P027',
#   'C008728',
#   'T010756',
#   'S0010',
#   1,
#   'ct',
#   Decimal('14.0'),
#   Decimal('14.0')),
#  ('P025',
#   'C002764',
#   'T017598',
#   'S00164',
# ...

# %%
fact_table_df = pd.DataFrame(list(records), columns=['payment_key', 'coustomer_key', 'time_key', 'item_key','store_key', 'quantity', 'unit_price','total_price'])
fact_table_df
